# %% [markdown]
# <a href="https://colab.research.google.com/github/Gianuzzi/Ausentismo-DD2020-Final/blob/master/Notebooks/Analisis_y_Curacion/Practico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Análisis-y-Curación-de-Datos" data-toc-modified-id="Análisis-y-Curación-de-Datos-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><strong>Análisis y Curación de Datos</strong></a></span><ul class="toc-item"><li><span><a href="#Actividades" data-toc-modified-id="Actividades-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span><strong>Actividades</strong></a></span><ul class="toc-item"><li><span><a href="#Unificación-de-los-reportes" data-toc-modified-id="Unificación-de-los-reportes-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span><strong>Unificación de los reportes</strong></a></span><ul class="toc-item"><li><span><a href="#Chequeos-puntuales-por-campo" data-toc-modified-id="Chequeos-puntuales-por-campo-1.1.1.1"><span class="toc-item-num">1.1.1.1&nbsp;&nbsp;</span><strong>Chequeos puntuales por campo</strong></a></span></li><li><span><a href="#Tests-de-integridad" data-toc-modified-id="Tests-de-integridad-1.1.1.2"><span class="toc-item-num">1.1.1.2&nbsp;&nbsp;</span><strong>Tests de integridad</strong></a></span></li><li><span><a href="#Creación-de-campos-nuevos" data-toc-modified-id="Creación-de-campos-nuevos-1.1.1.3"><span class="toc-item-num">1.1.1.3&nbsp;&nbsp;</span><strong>Creación de campos nuevos</strong></a></span></li></ul></li><li><span><a href="#Incorporación-de-información-climática" data-toc-modified-id="Incorporación-de-información-climática-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span><strong>Incorporación de información climática</strong></a></span></li><li><span><a href="#Opcional" data-toc-modified-id="Opcional-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span><strong>Opcional</strong></a></span></li></ul></li><li><span><a href="#Referencias" data-toc-modified-id="Referencias-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Referencias</a></span></li></ul></li><li><span><a href="#Primera-Parte" data-toc-modified-id="Primera-Parte-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Primera Parte</a></span><ul class="toc-item"><li><span><a href="#Importamos-paquetes" data-toc-modified-id="Importamos-paquetes-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Importamos paquetes</a></span></li><li><span><a href="#Definimos-funciones-auxiliares" data-toc-modified-id="Definimos-funciones-auxiliares-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Definimos funciones auxiliares</a></span></li><li><span><a href="#Definimos-funciones-de-Integridad" data-toc-modified-id="Definimos-funciones-de-Integridad-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Definimos funciones de Integridad</a></span></li></ul></li><li><span><a href="#Datasets" data-toc-modified-id="Datasets-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Datasets</a></span><ul class="toc-item"><li><span><a href="#Carga" data-toc-modified-id="Carga-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Carga</a></span><ul class="toc-item"><li><span><a href="#Datasets-clínicos" data-toc-modified-id="Datasets-clínicos-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Datasets clínicos</a></span></li><li><span><a href="#Datasets-de-información-climática" data-toc-modified-id="Datasets-de-información-climática-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Datasets de información climática</a></span></li></ul></li><li><span><a href="#Primera-re-estructuración-de-datos" data-toc-modified-id="Primera-re-estructuración-de-datos-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Primera re-estructuración de datos</a></span><ul class="toc-item"><li><span><a href="#Con-paciente" data-toc-modified-id="Con-paciente-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Con paciente</a></span></li><li><span><a href="#Sin-paciente" data-toc-modified-id="Sin-paciente-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Sin paciente</a></span></li><li><span><a href="#Clima2018-y-Clima2019" data-toc-modified-id="Clima2018-y-Clima2019-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Clima2018 y Clima2019</a></span><ul class="toc-item"><li><span><a href="#Concatenación-de-Datasets-de-Clima" data-toc-modified-id="Concatenación-de-Datasets-de-Clima-3.2.3.1"><span class="toc-item-num">3.2.3.1&nbsp;&nbsp;</span>Concatenación de Datasets de Clima</a></span></li><li><span><a href="#Reestrucitación-de-Dataset-de-Clima" data-toc-modified-id="Reestrucitación-de-Dataset-de-Clima-3.2.3.2"><span class="toc-item-num">3.2.3.2&nbsp;&nbsp;</span>Reestrucitación de Dataset de Clima</a></span></li></ul></li></ul></li><li><span><a href="#Merge-de-Datasets" data-toc-modified-id="Merge-de-Datasets-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Merge de Datasets</a></span><ul class="toc-item"><li><span><a href="#Con-Paciente-+-Sin-Paciente" data-toc-modified-id="Con-Paciente-+-Sin-Paciente-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Con Paciente + Sin Paciente</a></span></li><li><span><a href="#Turnos-+-Clima" data-toc-modified-id="Turnos-+-Clima-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Turnos + Clima</a></span></li></ul></li><li><span><a href="#Segunda-re-estructuración-de-Datos" data-toc-modified-id="Segunda-re-estructuración-de-Datos-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Segunda re-estructuración de Datos</a></span></li></ul></li><li><span><a href="#Limpieza-de-Datos" data-toc-modified-id="Limpieza-de-Datos-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Limpieza de Datos</a></span><ul class="toc-item"><li><span><a href="#Reemplazos" data-toc-modified-id="Reemplazos-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Reemplazos</a></span><ul class="toc-item"><li><span><a href="#Estado-Del-Turno" data-toc-modified-id="Estado-Del-Turno-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Estado Del Turno</a></span></li><li><span><a href="#Nombre-Del-Canal" data-toc-modified-id="Nombre-Del-Canal-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Nombre Del Canal</a></span></li><li><span><a href="#Sexo" data-toc-modified-id="Sexo-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Sexo</a></span></li><li><span><a href="#Localidad-y-Provincia" data-toc-modified-id="Localidad-y-Provincia-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Localidad y Provincia</a></span></li></ul></li><li><span><a href="#Duplicados" data-toc-modified-id="Duplicados-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Duplicados</a></span></li><li><span><a href="#Orden" data-toc-modified-id="Orden-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Orden</a></span></li></ul></li><li><span><a href="#Análisis-rápido" data-toc-modified-id="Análisis-rápido-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Análisis rápido</a></span><ul class="toc-item"><li><span><a href="#Centro-de-Atención" data-toc-modified-id="Centro-de-Atención-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Centro de Atención</a></span></li><li><span><a href="#Prestador" data-toc-modified-id="Prestador-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Prestador</a></span></li><li><span><a href="#Recurso" data-toc-modified-id="Recurso-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Recurso</a></span></li><li><span><a href="#Servicio" data-toc-modified-id="Servicio-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Servicio</a></span></li><li><span><a href="#Estado-Del-Turno" data-toc-modified-id="Estado-Del-Turno-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Estado Del Turno</a></span></li><li><span><a href="#Sexo" data-toc-modified-id="Sexo-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Sexo</a></span></li><li><span><a href="#Tipo-De-Turno-Asignado" data-toc-modified-id="Tipo-De-Turno-Asignado-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Tipo De Turno Asignado</a></span></li><li><span><a href="#Prestación-Asignada" data-toc-modified-id="Prestación-Asignada-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Prestación Asignada</a></span></li><li><span><a href="#Localidad" data-toc-modified-id="Localidad-5.9"><span class="toc-item-num">5.9&nbsp;&nbsp;</span>Localidad</a></span></li><li><span><a href="#Provincia" data-toc-modified-id="Provincia-5.10"><span class="toc-item-num">5.10&nbsp;&nbsp;</span>Provincia</a></span></li><li><span><a href="#Nombre-Del-Canal" data-toc-modified-id="Nombre-Del-Canal-5.11"><span class="toc-item-num">5.11&nbsp;&nbsp;</span>Nombre Del Canal</a></span></li><li><span><a href="#Es-Sobre-Turno" data-toc-modified-id="Es-Sobre-Turno-5.12"><span class="toc-item-num">5.12&nbsp;&nbsp;</span>Es Sobre Turno</a></span></li></ul></li><li><span><a href="#PACIENTES-EXISTENTES" data-toc-modified-id="PACIENTES-EXISTENTES-6"><span class="toc-item-num">6&nbsp;&nbsp;</span><em><strong>PACIENTES EXISTENTES</strong></em></a></span><ul class="toc-item"><li><span><a href="#Creación-de-Nuevo-dataset-(dfnn)" data-toc-modified-id="Creación-de-Nuevo-dataset-(dfnn)-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Creación de <em>Nuevo dataset (<strong>dfnn</strong>)</em></a></span></li><li><span><a href="#Análisis,-limpieza-y-categorización-rápidas" data-toc-modified-id="Análisis,-limpieza-y-categorización-rápidas-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Análisis, limpieza y categorización rápidas</a></span><ul class="toc-item"><li><span><a href="#Estado-del-Turno" data-toc-modified-id="Estado-del-Turno-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Estado del Turno</a></span><ul class="toc-item"><li><span><a href="#Ausentes-y-Atendidos" data-toc-modified-id="Ausentes-y-Atendidos-6.2.1.1"><span class="toc-item-num">6.2.1.1&nbsp;&nbsp;</span><strong>Ausentes y Atendidos</strong></a></span></li></ul></li><li><span><a href="#Centro-de-Atención" data-toc-modified-id="Centro-de-Atención-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Centro de Atención</a></span></li><li><span><a href="#Prestador" data-toc-modified-id="Prestador-6.2.3"><span class="toc-item-num">6.2.3&nbsp;&nbsp;</span>Prestador</a></span><ul class="toc-item"><li><span><a href="#Agrupación" data-toc-modified-id="Agrupación-6.2.3.1"><span class="toc-item-num">6.2.3.1&nbsp;&nbsp;</span>Agrupación</a></span></li></ul></li><li><span><a href="#Servicio" data-toc-modified-id="Servicio-6.2.4"><span class="toc-item-num">6.2.4&nbsp;&nbsp;</span>Servicio</a></span><ul class="toc-item"><li><span><a href="#Guardia" data-toc-modified-id="Guardia-6.2.4.1"><span class="toc-item-num">6.2.4.1&nbsp;&nbsp;</span>Guardia</a></span></li><li><span><a href="#Agrupación" data-toc-modified-id="Agrupación-6.2.4.2"><span class="toc-item-num">6.2.4.2&nbsp;&nbsp;</span>Agrupación</a></span></li></ul></li><li><span><a href="#Sexo" data-toc-modified-id="Sexo-6.2.5"><span class="toc-item-num">6.2.5&nbsp;&nbsp;</span>Sexo</a></span></li><li><span><a href="#Tipo-de-Turno-Asignado" data-toc-modified-id="Tipo-de-Turno-Asignado-6.2.6"><span class="toc-item-num">6.2.6&nbsp;&nbsp;</span>Tipo de Turno Asignado</a></span></li><li><span><a href="#Prestación-Asignada" data-toc-modified-id="Prestación-Asignada-6.2.7"><span class="toc-item-num">6.2.7&nbsp;&nbsp;</span>Prestación Asignada</a></span><ul class="toc-item"><li><span><a href="#Agrupación" data-toc-modified-id="Agrupación-6.2.7.1"><span class="toc-item-num">6.2.7.1&nbsp;&nbsp;</span>Agrupación</a></span></li></ul></li><li><span><a href="#Localidad" data-toc-modified-id="Localidad-6.2.8"><span class="toc-item-num">6.2.8&nbsp;&nbsp;</span>Localidad</a></span></li><li><span><a href="#Provincia" data-toc-modified-id="Provincia-6.2.9"><span class="toc-item-num">6.2.9&nbsp;&nbsp;</span>Provincia</a></span></li><li><span><a href="#Nombre-de-Canal" data-toc-modified-id="Nombre-de-Canal-6.2.10"><span class="toc-item-num">6.2.10&nbsp;&nbsp;</span>Nombre de Canal</a></span></li><li><span><a href="#Sobre-Turno" data-toc-modified-id="Sobre-Turno-6.2.11"><span class="toc-item-num">6.2.11&nbsp;&nbsp;</span>Sobre Turno</a></span></li><li><span><a href="#Fecha" data-toc-modified-id="Fecha-6.2.12"><span class="toc-item-num">6.2.12&nbsp;&nbsp;</span>Fecha</a></span><ul class="toc-item"><li><span><a href="#Día-Semanal" data-toc-modified-id="Día-Semanal-6.2.12.1"><span class="toc-item-num">6.2.12.1&nbsp;&nbsp;</span>Día Semanal</a></span></li><li><span><a href="#Momento-del-día" data-toc-modified-id="Momento-del-día-6.2.12.2"><span class="toc-item-num">6.2.12.2&nbsp;&nbsp;</span>Momento del día</a></span></li><li><span><a href="#Diferencia-temporal-entre-Otorgado-y-Oficial" data-toc-modified-id="Diferencia-temporal-entre-Otorgado-y-Oficial-6.2.12.3"><span class="toc-item-num">6.2.12.3&nbsp;&nbsp;</span>Diferencia temporal entre <em>Otorgado</em> y <em>Oficial</em></a></span></li><li><span><a href="#Estación-meteorológica-del-año" data-toc-modified-id="Estación-meteorológica-del-año-6.2.12.4"><span class="toc-item-num">6.2.12.4&nbsp;&nbsp;</span>Estación <em>meteorológica</em> del año</a></span></li></ul></li><li><span><a href="#Clima" data-toc-modified-id="Clima-6.2.13"><span class="toc-item-num">6.2.13&nbsp;&nbsp;</span>Clima</a></span><ul class="toc-item"><li><span><a href="#Lluvia" data-toc-modified-id="Lluvia-6.2.13.1"><span class="toc-item-num">6.2.13.1&nbsp;&nbsp;</span>Lluvia</a></span></li><li><span><a href="#Temperatura" data-toc-modified-id="Temperatura-6.2.13.2"><span class="toc-item-num">6.2.13.2&nbsp;&nbsp;</span>Temperatura</a></span></li></ul></li><li><span><a href="#Edad" data-toc-modified-id="Edad-6.2.14"><span class="toc-item-num">6.2.14&nbsp;&nbsp;</span>Edad</a></span><ul class="toc-item"><li><span><a href="#Binneamos-(cada-10-años)" data-toc-modified-id="Binneamos-(cada-10-años)-6.2.14.1"><span class="toc-item-num">6.2.14.1&nbsp;&nbsp;</span>Binneamos (cada 10 años)</a></span></li></ul></li><li><span><a href="#HC" data-toc-modified-id="HC-6.2.15"><span class="toc-item-num">6.2.15&nbsp;&nbsp;</span>HC</a></span></li></ul></li></ul></li><li><span><a href="#Despersonalización-de-campos-sensibles" data-toc-modified-id="Despersonalización-de-campos-sensibles-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Despersonalización de campos sensibles</a></span><ul class="toc-item"><li><span><a href="#HC-y-Recurso" data-toc-modified-id="HC-y-Recurso-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>HC y Recurso</a></span></li></ul></li><li><span><a href="#Aesthetic" data-toc-modified-id="Aesthetic-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Aesthetic</a></span><ul class="toc-item"><li><span><a href="#Índice" data-toc-modified-id="Índice-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Índice</a></span></li><li><span><a href="#Columnas" data-toc-modified-id="Columnas-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Columnas</a></span></li><li><span><a href="#Tipos" data-toc-modified-id="Tipos-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Tipos</a></span></li></ul></li><li><span><a href="#Test-de-Integridad-FINAL" data-toc-modified-id="Test-de-Integridad-FINAL-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Test de Integridad FINAL</a></span><ul class="toc-item"><li><span><a href="#Edad-(Excepción)" data-toc-modified-id="Edad-(Excepción)-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Edad (Excepción)</a></span></li></ul></li><li><span><a href="#Guardado" data-toc-modified-id="Guardado-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Guardado</a></span></li></ul></div>

# %% [markdown]
# # **Análisis y Curación de Datos**

# %% [markdown]
# ## **Actividades**
#
# En este práctico partiremos de datos un poco más crudos que los que usamos para el práctico de visualización, e incluiremos algunos más. La idea general es dejar preparado un único dataset que nos permita alimentar futuros modelos de aprendizaje automático.
#
# En primer lugar, partiremos de tres datasets diferentes. Dos de ellos corresponden a información obtenida de la institución médica. Cada uno de ellos consiste en un reporte distinto, que ustedes tendrán que unificar. El tercer dataset contiene información meteorológica, que usaremos en forma complementaria a los datos clínicos. La idea es que una vez que hayan unificado los dos reportes, incluyan la información meteorológica pertinente en el dataset final.
#
# Es importante que cada decisión que tomen sobre los datos quede debidamente documentada.
#
# Se recomienda trabajar empleando algún checklist para asegurarse de cumplir todas las etapas del proceso de curación. Pueden utilizar el checklist que vieron en clase, o algún otro que consideren más apropiado (en las referencias tienen uno a modo de ejemplo).

# %% [markdown]
# ### **Unificación de los reportes**
#
# La información clínica está dividida en los datasets "turnos_sin_pacientes_2018-2019_despersonalizado.csv" y "turnos_con_pacientes_2018-2019_despersonalizado.csv". Como el nombre lo indica, el primer reporte no contiene información de pacientes, sino sólo información correspondiente a los turnos. El segundo, en cambio, contiene datos de pacientes, pero tiene a su vez menos información sobre los turnos con respecto al primero. Los nombres de los campos en los dos reportes no siempre coinciden. Deberán renombrarlos para que coincidan antes de realizar la unificación. Para unificar los reportes, se recomienda utilizar el método "merge" de pandas.
#
# Nota: En lugar del nombre del paciente, como teníamos en el práctico anterior, ahora contamos con el campo **"HC"** (historia clínica), el cual es un ID único para cada paciente.

# %% [markdown]
# #### **Chequeos puntuales por campo**
#
# - Campo **"Estado del Turno"**: Verán que en este campo aparecen categorías que no estaban presentes en el práctico de visualización. Las categorías "Atendidendo", "Asignado" y "Receptado" están asociadas a turnos que estuvieron teniendo lugar en el momento en que se realizó el reporte, o bien, son defectos del sistema. Todas ellas deberán ser recategorizadas como "Atendido". Por otro lado, como nuestro objetivo final es estudiar el ausentismo en pacientes, el cual se define a partir del cociente "Ausentes" / ("Ausentes" + "Atendidos"), sólo nos quedaremos con los turnos que contengan alguna de estas dos categorías.
#
# - Campo **"Edad"**: Este campo puede contiene outliers. Deberán determinarlos y decidir qué hacer con ellos. Por ejemplo, una opción sería descartar los valores que no se encuentren en un determinado rango. Sea cual sea la decisión tomada, es importante que dejen clara cuál es su justificación para tomarla.
#
# - Campo **"Sexo"**: Este campo sólo debería contener las categorías "M" y "F". En caso de que exista otra categoría (por ejemplo, "I"), se la considera un error en la carga de datos, y se le dará el mismo tratamiento que si fuera un valor nulo.
#
# - Campos **"Dirección (localidad y provincia)"**: Van a ver que estos campos son muy sucios (la carga se efectúa manualmente). Acá la recomendación es distinguir sólo si pertenece a la localidad de Córdoba o no, y hacer lo mismo con la provincia de Córdoba.
#
# - Campo **"Nombre del canal"**: Las categorías "Teléfono" y "Call Center" deben ser unificadas, ya que representan lo mismo. La categoría "No definido" debe tratarse de la misma manera que los valores nulos (noten que este campo en particular contiene muchos valores nulos).
#
# - Campo **"Prestador"**: Verificar si hay obras sociales o prepagas que aparezcan con distintos nombres, identificar si hay una categoría que represente a pacientes que no tiene obra social/prepaga, y si hay alguna categoría dudosa.
#
# - Campo **"Fecha"**: Verificar que las fechas pertenecen al rango temporal correspondiente (en este caso, años 2018 y 2019).
#
# - Campo **"Fecha otorgado"**: Esta es la fecha en la que se otorgó el turno. Corroborar que la misma es anterior a la fecha correspondiente al turno.
#
# - Campo **"Prestación Asignada"**: Como vimos en el práctico anterior, este campo tiene categorías con frecuencias muy heterogéneas. La categoría "CONSULTA MEDICA" es por lejos la más frecuente, seguida por "Prestaciones múltiples". Acá deberán evaluar si conviene modificar el campo. Por ejemplo, mantener las categorías más frecuentes y recategorizar las demás como "Otras". En cualquier caso, justifiquen la decisión tomada.
#
# - Campo **"Servicio"**: Identificar los registros correspondientes a consultas de guardia y descartarlos. Explicitar cuál fue el criterio empleado para identificar estos registros.

# %% [markdown]
# #### **Tests de integridad**
#
# Escriban una función que realice los tests de integridad descriptos anteriormente, y otros que crean correspondientes. La función deberá tomar un dataset, realizar uno por uno los tests, e informar cuáles de ellos fueron exitosos y cuáles no. En el código más adelante hay un template para que les sirva de guía, pero pueden modificarlo a gusto.

# %% [markdown]
# #### **Creación de campos nuevos**
#
# Deberán incorporar al dataset al menos un campo nuevo, que crean relevante a la hora de abordar la problemática de la mentoría. Por ejemplo, día de la semana que corresponde al turno, si el paciente es consumidor final o cuenta con obra social/prepaga, etc.

# %% [markdown]
# ### **Incorporación de información climática**
#
# Los datasets "clima_2018.csv" y "clima_2019.csv" contienen información climática segmentada por día. Esta información es de carácter público y fue obtenida realizando webscrapping del dominio Ogimet (https://www.ogimet.com/gsynres.phtml). Determinen qué información puede ser relevante para la problemática de la mentoría (al menos un campo) e incorporenla al dataset clínico unificado.

# %% [markdown]
# ### **Opcional**
#
# Los campos **"Recurso"** y **"HC"** en la base de datos original contienen información sensible. En el primer caso, pueden aparecer nombres de personal médico, mientras que el segundo permite identificar unívocamente a los pacientes. En la versión del dataset que tienen ustedes, ambos campos se encuentran codificados. La idea de este opcional es que hagan de cuenta que no están codificados, y que les apliquen algún método de despersonalización. Además de eso, sería bueno que chequeen que no haya otros datos sensibles en otras columnas del dataset.

# %% [markdown]
# ## Referencias
#
# https://dimewiki.worldbank.org/wiki/Checklist:_Data_Cleaning

# %% [markdown]
# **Integrantes:**
#
#   + Gianuzzi Emmanuel
#   + Lascano Lucas
#   + Salgado Cristian

# %% [markdown]
# # Primera Parte

# %% [markdown]
# ## Importamos paquetes

# %%
import os
import sys
import pkg_resources
in_colab = 'google.colab' in sys.modules
import gc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from IPython.display import display_html
from hashlib import md5
if 'sidetable' not in {pkg.key for pkg in pkg_resources.working_set}:
    # !pip install sidetable==0.6.0
import sidetable
if 'unidecode' not in {pkg.key for pkg in pkg_resources.working_set}:
    # !pip install unidecode
import unidecode
if 'psutil' not in {pkg.key for pkg in pkg_resources.working_set}:
    # !pip install psutil
import psutil

#Reproducibilidad
np.random.seed(0)

#Aesthetic
sns.set()
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["legend.shadow"]    = True

BLUE   = '#5DADE2'
RED    = '#ff7043'
ORANGE = '#F5B041'
GREEN  = '#58D68D'
YELLOW = '#F4D03F'

pd.options.display.max_columns = 30
pd.options.display.max_rows    = 20

# %%
#Vemos versiones
from platform import python_version
print('python                       ', python_version())
# !pip list | grep  -E "Unidecode |numpy |pandas |seaborn |sidetable |psutil |ipython |scipy |matplotlib "
# Out:
# python                        3.8.5
# ipython                           7.18.1
# matplotlib                        3.3.1
# numpy                             1.19.1
# pandas                            1.1.3
# psutil                            5.7.2
# scipy                             1.5.2
# seaborn                           0.11.0
# sidetable                         0.6.0
# Unidecode                         1.1.1

# %%
process = psutil.Process(os.getpid())
print('Memoria inicial utilizada: %.2f GB' %(process.memory_full_info().rss*1e-9))
# Out:
# Memoria inicial utilizada: 0.15 GB

# %% [markdown]
# ## Definimos funciones auxiliares

# %%
class display_side_by_side(object):
    """Display HTML representation of multiple objects."""
    template = """<div style="float: left; padding: 10px;">
    <p style='font-family:"Courier New", Courier, monospace'>{0}</p>{1}
    </div>"""
    def __init__(self, *args):
        self.args = args
        
    def _repr_html_(self):
        return '\n'.join(self.template.format(a, eval(a)._repr_html_())
                         for a in self.args)
    
    def __repr__(self):
        return '\n\n'.join(a + '\n' + repr(eval(a))
                           for a in self.args)

def get_null_fraction(df, col):
    """Fracción nula."""
    return df[col].isnull().sum() / float(df.shape[0])

def get_null_percent(df, col):
    """Porcentaje nulo."""
    return 'NULL = {:.2f}%'.format(100*get_null_fraction(df, col))

def Memory():
    """Imprime la cantidad de memoria RAM utilizada por el proceso 
    hasta el momento, en GB"""
    gc.collect()
    process = psutil.Process(os.getpid())
    print('Memoria actual utilizada: %.2f GB' %(process.memory_full_info().rss*1e-9))
    return

def hashit(val):
    """Función de despersonalización.
    Uso: df.Col.astype(str).apply(hashit)"""
    return md5(val.encode('utf-8')).hexdigest()

def Outliers(df, col, n_stds=3, mask_only: bool=False, 
             outl_only: bool=False, verbose: bool=True):
    """Devuelve el dataset sin outliers para la columna indicada.
    Criterio: {Outlier < Media +- 3*Std < Outlier}
    
    Parámetros
    ----------
    df  : DataFrame
    col : string
    \t Nombre de columna a remover outliers.
    std : float, optional (Default = 3)
    mask_only : bool, optional (Default = False)
    \t Devolver SOLO la máscara con los outliers.
    outl_only : bool, optional (Default = False)
    \t Si es True, devuelve el dataset con SOLAMENTE los outliers,
    \t si es False, devuelve el dataset SIN los outliers.
    verbose : bool, optional (Default = True)
    \t Imprimir la cantidad (y porcentaje) de outliers.
    """
    valores  = df[col]
    outliers = np.abs(valores - valores.mean()) > valores.std()*n_stds
    if verbose:
        print('Cantidad de Outliers en %s : %i (%.4f%%)' 
              %(col, outliers.sum(), outliers.sum()*100/len(df)))
    if mask_only:
        return outliers
    if outl_only:
        return df[outliers]
    return df[~outliers] 

def Ploteo(Tot, Dif, name=None, h: bool=False, size=(20,5), row: bool=True, order=None, yticks: bool=False):
    """Función para plotear las tablas 'Tot' y 'Dif' (Provenientes de 'Tablas')
    Parámetros
    ----------
    Tot : DataFrame
    \t Dataframe con los porcentajes totales.
    Dif : DataFrame
    \t Dataframe con los porcentajes diferenciados.
    name : string, optional (Default = str(col))
    \t Nombre a colocar en el eje principal.
    h : bool, optional (Default = False)
    \t Si el barplot es horizontal o no.
    size : tuple, optional (Default = (20,5))
    \t Tamaño de la figura.
    row : bool, optional(Default = True)
    \t Si la figura posee 3 columnas (True) o 3 filas (False).
    order : list, optional (Default=np.sort(values))
    \t El orden de ploteo de los valores.
    yticks : bool, optional (Default=False)
    \t Si plotear o no los ticks en caso de que h==True.
    """
    col = Tot.index.name
    if not name:
        name = str(col)
    if not order:
        order = Tot.index
    elif order==True:
        order = np.sort(Tot.index)
    kind  = 'bar'
    if h:
        kind  = 'barh'
        order = order[::-1]
    if row:
        fig, ax = plt.subplots(1,3, figsize=size)
    else:
        fig, ax = plt.subplots(3,1, figsize=size)
    Tot.Porcentaje[order].plot(kind=kind, color=BLUE, ax=ax[0], label='Todos')
    Dif.Porcentaje.unstack(level=1).loc[order].plot(kind=kind, subplots=False, color=[RED, ORANGE], ax=ax[1])
    Tot.Ausentismo[order].plot(kind=kind, color=GREEN, ax=ax[2])
    if not h:
        plt.setp(ax[0], ylabel='Frecuencia')
        plt.setp([ax[0],ax[1],ax[2]], xlabel=name)
        ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=0)
        ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=0)
        ax[2].set_xticklabels(ax[2].get_xticklabels(), rotation=0)
    else:
        plt.setp([ax[0], ax[1], ax[2]], xlabel='Frecuencia')
        plt.setp(ax[0], ylabel=name)
        plt.setp([ax[1], ax[2]], ylabel='')
        if not yticks:
            ax[1].set_yticklabels('')
            ax[2].set_yticklabels('')
    ax[0].legend(loc=(1,1), bbox_to_anchor=(0.4, 1.05))
    ax[1].legend(loc=(1,1), bbox_to_anchor=(0.2, 1.05),  ncol=2)
    ax[2].legend(loc=(1,1), bbox_to_anchor=(0.35, 1.05))
    plt.show()  

def Porcent(x):
    """Devuelve un string pasando de ratio a porcentaje."""
    return "%.2f%%"%(x*100)

def Tablas(df, col, order=None, name=None):
    """Función para generar tablas 'Total' y 'Diferenciado'.
    Parámetros
    ----------
    df  : DataFrame
    \t Dataframe con los datos.
    col : string
    \t Nombre de la columna a operar.
    order : list, optional (Default="Mayor a menor frecuencia")
    \t Lista con el order de los índices de las tablas.
    name : string, optional (Default=str(col))
    \t Nombre a introducir en como título de las tablas.
    """
    if not name:
        name = str(col)
    Values = df[col].value_counts()
    if not order:
        order = Values.index
    elif order==True:
        order = np.sort(df[col].unique())
    Diferen = pd.DataFrame(df[[col, 'EstadoDelTurno']].groupby([col, 'EstadoDelTurno']).size()).rename(
        columns={0: 'Cantidad'}).reindex(order, level=0)
    Diferen['Porcentaje'] = Diferen.Cantidad.div(Diferen.Cantidad.sum(level=0), level=0)
    Ausent  = Diferen.unstack().Cantidad.Ausente.div(Diferen.unstack().Cantidad.Atendido)
    Values  = Values.loc[order]
    ValuesN = df[col].value_counts(normalize=True).loc[order]
    Total   = pd.concat([Values.rename('Cantidad'), 
                         ValuesN.rename('Porcentaje'), 
                         Values.cumsum().rename('Cant_Acum'), 
                         ValuesN.cumsum().rename('Porcent_Acumu'), 
                         Ausent.rename('Ausentismo')], axis=1).rename_axis(name)
    return Total, Diferen

# %% [markdown]
# ## Definimos funciones de Integridad

# %%
def check_EstadoDelTurno(df, col='EstadoDelTurno'):
    """Verifica que EstadoDelTurno sea 'Atendido' o 'Ausente'."""
    return set(df[col].unique()) == {'Atendido', 'Ausente'}

def check_Edad(df, col='Edad', n_stds=3):
    """Verifica si existen registros con Edad outliers."""
    outliers = Outliers(df, col, n_stds=n_stds, mask_only=True, verbose=False)
    return outliers.sum() == 0

def check_Sexo(df, col='Sexo'):
    """Verifica que Sexo sea 'F' o 'M'."""
    return set(df[col].unique()) == {'F', 'M'}

def check_Provincia(df, col='Provincia'):
    """Verifica que Provincia sea 'Córdoba', 'No Definido', u 'Otra'."""
    return set(df[col].unique()) == {'Córdoba', 'No Definido', 'Otra'}

def check_Localidad(df, col='Localidad'):
    """Verifica que Localidad sea 'Córdoba', 'No Definido', u 'Otra'."""
    return set(df[col].unique()) == {'Córdoba', 'No Definido', 'Otra'}

def check_NombreDelCanal(df, col='NombreDelCanal'):
    """Verifica que NombreDelCanal no posea valores nulos o vacíos (' ')."""
    return not bool(df[col].isnull().sum() | (df[col] == ' ').sum())

def check_Prestador(df, col='PrestadorAgrupado', val=11):
    """Verifica que la columna PrestadorAgrupado tenga no más de 11 prestadores. 
    De no existir ésta, chequea lo mismo sobre la columna Prestador."""
    if col in df:
        return df[col].nunique() <= val
    return df.Prestador.nunique() <= val

def check_Servicio(df, col='ServicioAgrupado', val=11):
    """Verifica que la columna ServicioAgrupado tenga no más de 11 prestadores.
    También verifica que no existan servicios de GUARDIA.
    De no existir ésta, chequea lo mismo sobre la columna Servicio."""
    if col in df:
        return df[col].nunique() <= val
    return df.Servicio.nunique() <= val

def check_Prestacion(df, col='PrestacionAgrupado', val=11):
    """Verifica que la columna PrestacionAgrupado tenga no más de 11 prestadores. 
    De no existir ésta, chequea lo mismo sobre la columna PrestacionAsignada."""
    if col in df:
        return df[col].nunique() <= val
    return df.PrestacionAsignada.nunique() <= val

def check_FechaDelTurno(df, col='FechaDelTurno', per=[2018, 2019]):
    """Verifica que FechaDelTurno esté comprendida en el periodo (en años) de interés."""
    return ((df[col].dt.year < per[0]) | (per[1] < df[col].dt.year)).sum() == 0
    
def check_FechaDeOtorgado(df, col='FechaDeOtorgado', col_1='FechaDelTurno'):
    """Verifica que el día de la FechaDeOtorgado sea siempre menor o igual a FechaDelTurno."""
    return (df[col].dt.date > df[col_1].dt.date).sum() == 0

def check_TipoDeTurno(df, col='TipoDeTurnoAsignado'):
    """Verifica que TipoDeTurnoAsignado no posea valores nulos o vacíos (' ')."""
    return not bool(df[col].isnull().sum() | (df[col] == ' ').sum())

def test_integridad(df, n_stds=3, val=11, per=[2018, 2019]):
    """Ejecuta uno por uno los tests e informa el resultado."""
    print('Ejecutando tests de Integridad')
    print('Test Estado del Turno : %s' % ('EXITOSO' if check_EstadoDelTurno(df)         else 'ERROR'))
    print('Test Edad             : %s' % ('EXITOSO' if check_Edad(df, n_stds=n_stds)    else 'ERROR'))
    print('Test Sexo             : %s' % ('EXITOSO' if check_Sexo(df)                   else 'ERROR'))
    print('Test Provincia        : %s' % ('EXITOSO' if check_Provincia(df)              else 'ERROR'))
    print('Test Localidad        : %s' % ('EXITOSO' if check_Localidad(df)              else 'ERROR'))
    print('Test Nombre del Canal : %s' % ('EXITOSO' if check_NombreDelCanal(df)         else 'ERROR'))
    print('Test Prestador        : %s' % ('EXITOSO' if check_Prestador(df, val=val)     else 'ERROR'))        
    print('Test Servicio         : %s' % ('EXITOSO' if check_Servicio(df, val=val)      else 'ERROR'))
    print('Test Prestación       : %s' % ('EXITOSO' if check_Prestacion(df, val=val)    else 'ERROR'))
    print('Test Fecha de Turno   : %s' % ('EXITOSO' if check_FechaDelTurno(df, per=per) else 'ERROR'))
    print('Test Fecha de Otorgado: %s' % ('EXITOSO' if check_FechaDeOtorgado(df)        else 'ERROR'))
    print('Test Tipo de Turno    : %s' % ('EXITOSO' if check_TipoDeTurno(df)            else 'ERROR'))
    return

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Datasets

# %% [markdown]
# ## Carga

# %%
if in_colab:
  data_dir = "https://github.com/Gianuzzi/Ausentismo-DD2020-Final/raw/master/data/"
else:
  data_dir = os.path.join(os.getcwd(), '..', '..', 'data')

# %% [markdown]
# ### Datasets clínicos

# %%
dataset_con_paciente = os.path.join(data_dir, 'turnos_con_paciente_2018-2019_despersonalizado.zip')
dataset_sin_paciente = os.path.join(data_dir, 'turnos_sin_paciente_2018-2019_despersonalizado.zip')

dfcp = pd.read_csv(dataset_con_paciente, sep=';')
dfsp = pd.read_csv(dataset_sin_paciente, sep=';')

# %%
print('Tamaño:'
      '\n  df Con Pacientes: %.2f GB'
      '\n  df Sin Pacientes: %.2f GB'
      %(dfcp.memory_usage(deep=False).sum()*1e-9, dfsp.memory_usage(deep=False).sum()*1e-9))
# Out:
# Tamaño:
#   df Con Pacientes: 0.31 GB
#   df Sin Pacientes: 0.18 GB

# %%
Memory()
# Out:
# Memoria actual utilizada: 0.85 GB

# %% [markdown]
# **Pre-Visualizamos**

# %%
print('Tamañano de dataset "Con paciente":' ,dfcp.shape)
display(dfcp.sample(5))
# Out:
# Tamañano de dataset "Con paciente": (2762590, 14)
#          CentroAtencion_Nombre                 Prestador  Recurso  \
# 2516415                      2  OMINT S. A. DE SERVICIOS       48
# 1880274                      2          CONSUMIDOR FINAL      171
# 905507                       1                         -      517
# 899189                       1                         -      119
# 2755412                      2                     OSDE       173
#
#               Servicio_Nombre           FechaTurno TurnoEstado_Nombre Sexo  \
# 2516415          REUMATOLOGÍA  2019-11-06 18:00:00            Ausente    F
# 1880274             ECOGRAFIA  2019-06-19 15:45:00            Anulado    F
# 905507            GINECOLOGÍA  2018-09-25 15:45:00           Inactivo
# 899189   DEMANDA DE PEDIATRÍA  2018-09-24 13:45:00              Libre
# 2755412             ECOGRAFIA  2019-12-30 08:00:00           Atendido    M
#
#          Edad        HC           TipoTurno                   Prestacion  \
# ...

# %%
print('Tamañano de dataset "Sin paciente":' ,dfsp.shape)
display(dfsp.sample(5))
# Out:
# Tamañano de dataset "Sin paciente": (2196779, 10)
#          Centro de atención                 Servicio  Recurso  \
# 1996408                   3     GINECO Y OBSTETRICIA      485
# 1509715                   3     GINECO Y OBSTETRICIA       52
# 237157                    4  KINESIOL Y FISIOTERAPIA      508
# 1243278                   1          HOSPITAL DE DÍA      267
# 1807983                   3     GINECO Y OBSTETRICIA      231
#
#          Prestación asignada Estado del turno Nombre del canal  \
# 1996408      CONSULTA MEDICA         Atendido    Turnos Online
# 1509715                  NaN            Libre              NaN
# 237157   TERAPIA OCUPACIONAL         Atendido              NaN
# 1243278                  NaN            Libre              NaN
# 1807983                  NaN            Libre              NaN
#
#         Fecha del turno Hora del turno Es sobre turno Tipo de turno asignado
# 1996408      2019-11-01          18:30             NO     Ulterior / Control
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Datasets de información climática

# %%
dataset_clima_2018 = os.path.join(data_dir, 'clima_dataset_2018.csv')
dataset_clima_2019 = os.path.join(data_dir, 'clima_dataset_2019.csv')

df_clima2018 = pd.read_csv(dataset_clima_2018)
df_clima2019 = pd.read_csv(dataset_clima_2019)

print('Tamaño:'
      '\n  df Clima 2018: %.2f KB'
      '\n  df Clima 2019: %.2f KB'
      %(df_clima2018.memory_usage(deep=False).sum()*1e-3, df_clima2019.memory_usage(deep=False).sum()*1e-3))
# Out:
# Tamaño:
#   df Clima 2018: 41.01 KB
#   df Clima 2019: 41.01 KB

# %% [markdown]
# **Pre-Visualizamos**

# %%
print('Tamañano de dataset "Clima_2018":' ,df_clima2018.shape)
display(df_clima2018.sample(5))
# Out:
# Tamañano de dataset "Clima_2018": (365, 14)
#           Fecha  Hr.Med(%)  NubTotOct NubbajOct Prec.(mm)  Pres.n. mar(Hp)  \
# 144  25/05/2018       68.0        0.4       0.0       0.0           1020.1
# 40   10/02/2018       69.7        5.6       2.4      14.0           1012.9
# 297  25/10/2018       93.5        8.0       8.0       7.0           1018.2
# 120  01/05/2018       97.7        8.0       8.0       3.7           1018.8
# 342  09/12/2018       54.1        2.0       2.8       0.0           1008.2
#
#      TdMed(C)  Tmax  Tmed  Tmin Dir.  Rch.  Vel.  VisKm
# 144       6.2  23.6  12.8   2.4   NE  ----  16.7   11.5
# 40       12.2  26.3  18.5  12.5  SSW   NaN  10.0    9.7
# 297      13.1  16.4  14.3  12.4    S  ----   8.8    4.8
# 120      13.3  17.0  13.8  12.0  SSW  ----  13.4    3.1
# 342      13.0  30.9  23.6  13.8  NNE  ----  14.4   11.2

# %%
print('Tamañano de dataset "Clima_2019":' ,df_clima2019.shape)
display(df_clima2019.sample(5))
# Out:
# Tamañano de dataset "Clima_2019": (365, 14)
#           Fecha  Tmax  Tmin  Tmed  TdMed(C)  Hr.Med(%) Dir.  Vel.  Rch.  \
# 162  12/06/2019  19.8   6.6  14.0      11.7       87.8  ESE  10.0  ----
# 88   30/03/2019  27.8  16.5  21.3      17.5       80.4  NNE   9.5  ----
# 46   16/02/2019  28.5  13.3  21.1      16.6       78.1  NNE  12.3  ----
# 70   12/03/2019  24.9  13.2  17.7      15.0       85.1    E   7.3  ----
# 306  03/11/2019  25.8  10.9  18.8       5.4       43.7   NE  12.3  ----
#
#      Pres.n. mar(Hp) Prec.(mm)  NubTotOct NubbajOct  VisKm
# 162           1009.2        Ip        5.1       5.3    7.1
# 88            1013.6       0.0        6.4       4.2   10.5
# 46            1015.8       0.0        1.6       1.9   12.5
# 70            1014.7       0.1        6.4       5.7    8.6
# 306           1013.4       0.0        5.4       3.0   12.1

# %%
Memory()
# Out:
# Memoria actual utilizada: 0.90 GB

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Primera re-estructuración de datos

# %% [markdown]
# ### Con paciente

# %%
display(dfcp.columns)
# Out:
# Index(['CentroAtencion_Nombre', 'Prestador', 'Recurso', 'Servicio_Nombre',
#        'FechaTurno', 'TurnoEstado_Nombre', 'Sexo', 'Edad', 'HC', 'TipoTurno',
#        'Prestacion', 'FechaOtrogado', 'Dirección (localidad)',
#        'Dirección (provincia)'],
#       dtype='object')

# %%
##Renombramos columas
dfcp.columns = ['CentroDeAtencion', 'Prestador', 'Recurso', 'Servicio',
                'FechaDelTurno', 'EstadoDelTurno', 'Sexo', 'Edad', 'HC', 'TipoDeTurnoAsignado',
                'PrestacionAsignada', 'FechaDeOtorgado', 'Localidad',
                'Provincia']

##Vemos los tipos
display(pd.DataFrame(dfcp.dtypes).rename(columns={0: 'Tipo'}))
# Out:
#                         Tipo
# CentroDeAtencion       int64
# Prestador             object
# Recurso                int64
# Servicio              object
# FechaDelTurno         object
# EstadoDelTurno        object
# Sexo                  object
# Edad                   int64
# HC                   float64
# TipoDeTurnoAsignado   object
# PrestacionAsignada    object
# FechaDeOtorgado       object
# Localidad             object
# Provincia             object

# %%
##FechaDelTurno y FechaDeOtorgado
####Al analizar la columa *FechaDeOtorgado*, vemos que las fechas (cuando existen) tiene el siguiente formato: yyyy-mm-dd hh:mm:ss.sss, por eso
####redondearemos a 1 segundo
###Transformamos *FechaDelTurno* y *FechaDeOtorgado* en datetime
dfcp.FechaDelTurno   = pd.to_datetime(dfcp.FechaDelTurno, format='%Y-%m-%d %H:%M:%S.%f')
dfcp.FechaDeOtorgado = pd.to_datetime(dfcp.FechaDeOtorgado, format='%Y-%m-%d %H:%M:%S.%f').dt.round('1s')

# %% [markdown]
# ##Revemos los tipos
# display(pd.DataFrame(dfcp.dtypes).rename(columns={0: 'Tipo'}))

# %% [markdown]
# ---

# %% [markdown]
# ### Sin paciente

# %%
display(dfsp.columns)
# Out:
# Index(['Centro de atención', 'Servicio', 'Recurso', 'Prestación asignada',
#        'Estado del turno', 'Nombre del canal', 'Fecha del turno',
#        'Hora del turno', 'Es sobre turno', 'Tipo de turno asignado'],
#       dtype='object')

# %%
##Renombramos columas
dfsp.columns = ['CentroDeAtencion', 'Servicio', 'Recurso', 'PrestacionAsignada',
                'EstadoDelTurno', 'NombreDelCanal', 'DiaDelTurno',
                'HoraDelTurno', 'EsSobreTurno', 'TipoDeTurnoAsignado']

##Vemos los tipos
display(pd.DataFrame(dfsp.dtypes).rename(columns={0: 'Tipo'}))
# Out:
#                        Tipo
# CentroDeAtencion      int64
# Servicio             object
# Recurso               int64
# PrestacionAsignada   object
# EstadoDelTurno       object
# NombreDelCanal       object
# DiaDelTurno          object
# HoraDelTurno         object
# EsSobreTurno         object
# TipoDeTurnoAsignado  object

# %%
##DiaDelTurno y HoraDelTurno
###Creamos una nueva columna FechaDelTurno uniendo estas 2 columnas, y las eliminamos
dfsp['FechaDelTurno'] = dfsp.DiaDelTurno + ' ' + dfsp.HoraDelTurno
dfsp.drop(columns=['DiaDelTurno', 'HoraDelTurno'], inplace=True)

###Ahora transformamos FechaDelTurno en datetime
dfsp.FechaDelTurno   = pd.to_datetime(dfsp.FechaDelTurno, format='%Y-%m-%d %H:%M')

# %% [markdown]
# ##Revemos los tipos
# display(pd.DataFrame(dfsp.dtypes).rename(columns={0: 'Tipo'}))

# %% [markdown]
# ---

# %% [markdown]
# ### Clima2018 y Clima2019

# %%
print('Las columnas de los dataset de clima son: %s' %('Iguales' if set(df_clima2018.columns) == set(df_clima2019.columns) else ' Distintas'))
# Out:
# Las columnas de los dataset de clima son: Iguales

# %% [markdown]
# #### Concatenación de Datasets de Clima

# %%
#Poseen los mismos nombres de columnas, así que las uniremos primero
df_clima = pd.concat([df_clima2018, df_clima2019], ignore_index=True, sort=False)
print('Tamaño df Clima [2018, 2018]: %.2f KB' %(df_clima.memory_usage(deep=False).sum()*1e-3))
print('Tamaño del dataset:', df_clima.shape)
display(df_clima.sample(3))
# Out:
# Tamaño df Clima [2018, 2018]: 81.89 KB
# Tamaño del dataset: (730, 14)
#           Fecha  Hr.Med(%)  NubTotOct NubbajOct Prec.(mm)  Pres.n. mar(Hp)  \
# 295  23/10/2018       92.8        8.0       6.9       0.9           1020.4
# 440  17/03/2019       82.4        6.7       4.3      17.0           1013.7
# 665  28/10/2019       68.7        3.0       2.7       0.0           1002.8
#
#      TdMed(C)  Tmax  Tmed  Tmin Dir.  Rch.  Vel.  VisKm
# 295      12.7  17.2  14.1  12.7  SSE  ----  10.7    7.0
# 440      15.1  23.9  18.6  14.3  SSW  ----  11.4    9.3
# 665      15.3  29.2  22.3  17.3    S  ----  15.6    9.0

# %% [markdown]
# #### Reestrucitación de Dataset de Clima

# %%
#Renombramos las columnas
df_clima.columns = ['Fecha', 'HrMed_Por', 'NubTotOct', 'NubbajOct',
                    'Prec_mm', 'PresNivMar_Hp', 'TDMed_C',
                    'Tmax', 'Tmed', 'Tmin',  'Dir', 'Rch', 'Vel', 'Vis_Km']
##Vemos los tipos
display(pd.DataFrame(df_clima.dtypes).rename(columns={0: 'Tipo'}))
# Out:
#                   Tipo
# Fecha           object
# HrMed_Por      float64
# NubTotOct      float64
# NubbajOct       object
# Prec_mm         object
# PresNivMar_Hp  float64
# TDMed_C        float64
# Tmax           float64
# Tmed           float64
# Tmin           float64
# Dir             object
# Rch             object
# Vel            float64
# Vis_Km         float64

# %%
##Fecha
###Transformamos Fecha en datetime
df_clima.Fecha = pd.to_datetime(df_clima.Fecha, format='%d/%m/%Y')

# %% [markdown]
# ##Revemos los tipos
# display(pd.DataFrame(df_clima.dtypes).rename(columns={0: 'Tipo'}))

# %%
#Borramos los datasets que no se utiliza más (Reutilizar la memoria)
del df_clima2018
del df_clima2019

# %%
Memory()
# Out:
# Memoria actual utilizada: 0.79 GB

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Merge de Datasets

# %% [markdown]
# ### Con Paciente + Sin Paciente

# %%
merge_cols = ['CentroDeAtencion', 'Servicio', 'Recurso', 'PrestacionAsignada', 'EstadoDelTurno', 'TipoDeTurnoAsignado', 'FechaDelTurno']
df_turnos  = dfcp.merge(dfsp, how='left', on=merge_cols)
print('Tamaño df Turnos: %.2f GB' %(df_turnos.memory_usage(deep=False).sum()*1e-9))
print('Tamaño del dataset:', df_turnos.shape)
display(df_turnos.sample(5))
# Out:
# Tamaño df Turnos: 0.42 GB
# Tamaño del dataset: (3075037, 16)
#          CentroDeAtencion                     Prestador  Recurso  \
# 332898                  1  PERSONAL DE FARMACIA-GAPRESA       54
# 691418                  1            SWISS MEDICAL S.A.      270
# 1317232                 1              CONSUMIDOR FINAL      483
# 974304                  1            SWISS MEDICAL S.A.      267
# 1860744                 1                         DASPU      450
#
#                      Servicio       FechaDelTurno EstadoDelTurno Sexo  Edad  \
# 332898   ORTOPEDIA Y TRAUMATO 2018-03-15 17:00:00       Atendido    F    20
# 691418        HOSPITAL DE DÍA 2018-06-27 17:30:00        Anulado    F    60
# 1317232        NEUROLOGÍA INF 2018-12-06 08:16:00       Atendido    F    15
# 974304        HOSPITAL DE DÍA 2018-09-11 13:45:00        Anulado    F    64
# 1860744  ORTOPEDIA Y TRAUMATO 2019-04-24 11:35:00       Atendido    F    55
#
# ...

# %%
#Borramos los datasets que no se utiliza más (Reutilizar la memoria)
del dfcp
del dfsp

# %%
Memory()
# Out:
# Memoria actual utilizada: 1.26 GB

# %% [markdown]
# ---

# %% [markdown]
# ### Turnos + Clima

# %%
####Debido a que la fecha en el dataset Clima es del orden del día, mientras que las de los Turnos es del orden de los minutos,
####creamos una columa con la fecha (sin hms) para Turnos
df_turnos['Fecha'] = df_turnos.FechaDelTurno.dt.date
df_turnos.Fecha    = pd.to_datetime(df_turnos.Fecha)

#Hacemos el merge
df = df_turnos.merge(df_clima, on='Fecha', how='left')
df.drop('Fecha', axis=1, inplace=True)
print('Tamaño df [Turnos + Clima]: %.2f GB' %(df.memory_usage(deep=False).sum()*1e-9))
print('Tamaño del dataset:', df.shape)
display(df.sample(5))
# Out:
# Tamaño df [Turnos + Clima]: 0.74 GB
# Tamaño del dataset: (3075037, 29)
#          CentroDeAtencion         Prestador  Recurso  \
# 2944502                 2             OSDE       112
# 1486651                 1                 -      106
# 1156833                 1  CONSUMIDOR FINAL      492
# 379492                  1                 -       87
# 1516458                 2             OSDE       513
#
#                                           Servicio       FechaDelTurno  \
# 2944502                   GINECOLOGIA PRACTICAS CP 2019-12-03 16:15:00
# 1486651                       DEMANDA DE PEDIATRÍA 2019-01-21 14:48:00
# 1156833  CUENTAS PROPIAS ALERGIA E INMUNOLOGIA INF 2018-10-25 16:19:00
# 379492                                   PEDIATRÍA 2018-03-30 16:00:00
# 1516458                               OFTALMOLOGÍA 2019-01-28 10:30:00
#
#         EstadoDelTurno Sexo  Edad        HC TipoDeTurnoAsignado  \
# 2944502       Atendido    F    45   82889.0            Práctica
# ...

# %%
#Borramos los datasets que no se utiliza más (Reutilizar la memoria)
del df_turnos
del df_clima

# %%
print('DataFrames Unidos')
pd.options.display.max_rows    = 30
display(pd.DataFrame(df.dtypes).rename(columns={0: 'Tipo'}))
# Out:
# DataFrames Unidos
#                                Tipo
# CentroDeAtencion              int64
# Prestador                    object
# Recurso                       int64
# Servicio                     object
# FechaDelTurno        datetime64[ns]
# EstadoDelTurno               object
# Sexo                         object
# Edad                          int64
# HC                          float64
# TipoDeTurnoAsignado          object
# PrestacionAsignada           object
# FechaDeOtorgado      datetime64[ns]
# Localidad                    object
# Provincia                    object
# NombreDelCanal               object
# EsSobreTurno                 object
# HrMed_Por                   float64
# NubTotOct                   float64
# NubbajOct                    object
# Prec_mm                      object
# PresNivMar_Hp               float64
# TDMed_C                     float64
# Tmax                        float64
# Tmed                        float64
# ...

# %%
Memory()
# Out:
# Memoria actual utilizada: 1.08 GB

# %% [markdown]
# ## Segunda re-estructuración de Datos

# %%
df_Num = ['CentroDeAtencion', 'Recurso', 'Edad', 'HC']

df_Str = ['Prestador', 'Servicio', 'EstadoDelTurno', 'Sexo', 'TipoDeTurnoAsignado', 'PrestacionAsignada', 'Localidad',
          'Provincia', 'NombreDelCanal', 'EsSobreTurno', 'Dir']

df_Cli = ['HrMed_Por', 'NubTotOct', 'NubbajOct', 'Prec_mm', 'PresNivMar_Hp', 'TDMed_C', 'Tmax', 'Tmed', 'Tmin', 'Rch',
          'Vel', 'Vis_Km']

df_Dat = ['FechaDelTurno', 'FechaDeOtorgado']

# %%
#Str
###Reemplazamos "-", " " y np.nan por "No Definido"
To_Replace = {' ': 'No Definido', '-': 'No Definido', '--': 'No Definido', '---': 'No Definido', '----': 'No Definido'}
for str_col in df_Str:
    df[str_col].replace(To_Replace, inplace=True)
    df[str_col].fillna('No Definido', inplace=True)

# %%
#Num y Dat
### Hacemos numpericas las columas que lo son. Todo lo que no es num, es convertido en np.nan
#### En "Precipitaciones", se encuentra el valor "Ip" (Imperceptible), el cual no es 0 (ni significa no medido (np.nan)); por lo tanto
#### le introduciremos prmero el valor 0.05, y luego efectuaremos el pasado a numérico de columnas

df.Prec_mm.replace('Ip', 0.05, inplace=True) #Lluvia imperceptible

for num_col in df_Num+df_Cli:
    df[num_col] = pd.to_numeric(df[num_col], errors='coerce')
    
#Cambiamos el tipo de float64 a Int64 (notar la I mayúscula, ya que este tipo contiene NaNs "enteros")
df.HC = df.HC.astype('Int64')

# %%
print('DataFrames Unidos')
display(pd.DataFrame(df.dtypes).rename(columns={0: 'Tipo'}))
# Out:
# DataFrames Unidos
#                                Tipo
# CentroDeAtencion              int64
# Prestador                    object
# Recurso                       int64
# Servicio                     object
# FechaDelTurno        datetime64[ns]
# EstadoDelTurno               object
# Sexo                         object
# Edad                          int64
# HC                            Int64
# TipoDeTurnoAsignado          object
# PrestacionAsignada           object
# FechaDeOtorgado      datetime64[ns]
# Localidad                    object
# Provincia                    object
# NombreDelCanal               object
# EsSobreTurno                 object
# HrMed_Por                   float64
# NubTotOct                   float64
# NubbajOct                   float64
# Prec_mm                     float64
# PresNivMar_Hp               float64
# TDMed_C                     float64
# Tmax                        float64
# Tmed                        float64
# ...

# %%
#Borramos innecesarios
del To_Replace, df_Cli, df_Dat, df_Num, df_Str, merge_cols, num_col, str_col

# %%
Memory()
# Out:
# Memoria actual utilizada: 1.25 GB

# %%
test_integridad(df)
# Out:
# Ejecutando tests de Integridad
# Test Estado del Turno : ERROR
# Test Edad             : ERROR
# Test Sexo             : ERROR
# Test Provincia        : ERROR
# Test Localidad        : ERROR
# Test Nombre del Canal : EXITOSO
# Test Prestador        : ERROR
# Test Servicio         : ERROR
# Test Prestación       : ERROR
# Test Fecha de Turno   : EXITOSO
# Test Fecha de Otorgado: ERROR
# Test Tipo de Turno    : EXITOSO

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Limpieza de Datos

# %% [markdown]
# ## Reemplazos

# %% [markdown]
# ### Estado Del Turno

# %%
#Reemplazamos "Atendiendo", "Receptado", "Asignado" por "Atendido"
print('Antes  :', df.EstadoDelTurno.unique())
#df.EstadoDelTurno.replace(['Atendiendo', 'Receptado', 'Asignado'], 'Atendido', inplace=True)
df.EstadoDelTurno.replace(['Atendiendo', 'Receptado', 'Asignado', 'Turno consecutivo'],      'Atendido', inplace=True)
df.EstadoDelTurno.replace(['Cancelado por Cambio de Agenda', 'Anulado','Inactivo', 'Libre'], 'Otro'    , inplace=True)
print('Después:', df.EstadoDelTurno.unique())
# Out:
# Antes  : ['Inactivo' 'Cancelado por Cambio de Agenda' 'Atendido' 'Anulado' 'Libre'
#  'Turno consecutivo' 'Receptado' 'Ausente' 'Atendiendo' 'Asignado']
# Después: ['Otro' 'Atendido' 'Ausente']

# %% [markdown]
# ---

# %% [markdown]
# ### Nombre Del Canal

# %%
#Reemplazamos "Atendiendo", "Receptado", "Asignado" por "Atendido"
print('Antes  :', df.NombreDelCanal.unique())
df.NombreDelCanal.replace('Call Center', 'Teléfono', inplace=True)
print('Después:', df.NombreDelCanal.unique())
# Out:
# Antes  : ['No Definido' 'Recepción' 'Call Center' 'Turnos Online' 'Teléfono'
#  'Chat/Redes Sociales']
# Después: ['No Definido' 'Recepción' 'Teléfono' 'Turnos Online'
#  'Chat/Redes Sociales']

# %% [markdown]
# ---

# %% [markdown]
# ### Sexo

# %%
#Reemplazamos "I" por "No definido"
print('Antes  :', df.Sexo.unique())
df.Sexo.replace('I', 'No Definido', inplace=True)
print('Después:', df.Sexo.unique())
# Out:
# Antes  : ['No Definido' 'F' 'M' 'I']
# Después: ['No Definido' 'F' 'M']

# %% [markdown]
# ---

# %% [markdown]
# ### Localidad y Provincia

# %%
#Ambos
##Aesthetic (Primera letra en mayúscula)
df.Localidad = df.Localidad.str.capitalize()
df.Provincia = df.Provincia.str.capitalize()

##Aplicamos unidecode
df.Localidad = df.Localidad.apply(unidecode.unidecode)
df.Provincia = df.Provincia.apply(unidecode.unidecode)

##Borramos espacios y puntos (Y cualquier otro símbolo que querramos agregar)
A_Remover    = [".", " ", "-", "(", ")"]
df.Localidad = ([s.replace('.', '').replace(' ', '').replace('-', '').replace(')', '').replace('(', '') for s in df.Localidad])
df.Provincia = ([s.replace('.', '').replace(' ', '').replace('-', '').replace(')', '').replace('(', '') for s in df.Provincia])

##Reemplazamos todos los _Córdoba_ mal escritos (ya revisados) por "Cordoba" en ambos
##Reemplazamos por "cordoba", cuando hay alguna localidad de Córdoba (mal introducida) en Provincia (Ej: villaallende).
Mal_Escrito = ['Cba', 'Cordiba', 'Cordo', 'Cordobacapital', 'Cordobacapitral', 'Cordonba', 'Corodba', 'Crdoba', 'Ordoba']
Mal_Provinc = ['Golfaltagracia', 'Sanfrancisco', 'Vallecercanoac', 'Laboulaye', 'Adeliamaria', 'Villaallende', 'Cruzdeleje',
               'Riotercero', 'Riocuarto', 'Freyre']
df.Localidad.replace(Mal_Escrito            , 'Cordoba', inplace=True)
df.Provincia.replace(Mal_Escrito+Mal_Provinc, 'Cordoba', inplace=True)

#Localidad
##Evaluamos y reemplazamos los que tenemos dudas (ya revisados), por "Cordoba" 
Duda = ['Capital', 'Centro']
df.loc[(df.Provincia == 'Cordoba') & (df.Localidad.isin(Duda)), 'Localidad'] = 'Cordoba'

#Provincia
##Reemplazamos los posibles "nodefinido" por "Cordoba" en Provincia, cuando Localidad='Cordoba'
df.loc[df.Localidad == 'Cordoba', 'Provincia'] = 'Cordoba'

#Ambos
##Reemplazamos todo lo que no es "cordoba" por "otro"
df.loc[(df.Provincia != 'Cordoba') & (df.Provincia != 'Nodefinido'), 'Provincia'] = 'Otra'
df.loc[(df.Localidad != 'Cordoba') & (df.Localidad != 'Nodefinido'), 'Localidad'] = 'Otra'

##Aesthetic (Separamos No definido) e introducimos tilde en Córodoba
df.Localidad.replace({'Nodefinido': 'No Definido', 'Cordoba': 'Córdoba'}, inplace=True)
df.Provincia.replace({'Nodefinido': 'No Definido', 'Cordoba': 'Córdoba'}, inplace=True)

print("Finales: \n Localidad: {} \n Provincia: {}".format(df.Localidad.unique(), df.Localidad.unique()))
# Out:
# Finales:
#  Localidad: ['No Definido' 'Córdoba' 'Otra']
#  Provincia: ['No Definido' 'Córdoba' 'Otra']

# %%
Memory()
# Out:
# Memoria actual utilizada: 1.32 GB

# %% [markdown]
# ___

# %% [markdown]
# ---

# %% [markdown]
# ## Duplicados

# %%
Old = len(df)
print('Tamaño df: %.2f GB' %(df.memory_usage(deep=False).sum()*1e-9))
df.drop_duplicates(inplace=True)
print('Cantidad de filas duplicadas y removidas: %i == %.2f%%' %(Old-len(df), (Old-len(df))*100/Old))
print('Tamaño df: %.2f GB' %(df.memory_usage(deep=False).sum()*1e-9))
# Out:
# Tamaño df: 0.74 GB
# Cantidad de filas duplicadas y removidas: 517576 == 16.83%
# Tamaño df: 0.62 GB

# %%
Memory()
# Out:
# Memoria actual utilizada: 0.90 GB

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Orden

# %%
#Verificamos el rango temporal de turnos
print('Turnos fuera del rango a estudiar [2018-2019]:', ((df.FechaDelTurno.dt.year < 2018) | (2019 < df.FechaDelTurno.dt.year)).sum())
print('Fecha del Turno')
print('')
print('Diferencia mínima temporal:', df.FechaDelTurno.diff().min())
print('Están ordenados por Turnos:', df.FechaDelTurno.diff().min() >= pd.Timedelta(0))
print('Primer turno:', df.FechaDelTurno.min())
print('Último turno:', df.FechaDelTurno.max())
print('')
print('Fecha de Otorgado')
#print('Diferencia mínima temporal:', df[~df.FechaDeOtorgado.isnull()].FechaDeOtorgado.diff().min())
print('Primer turno:', df.FechaDeOtorgado.min())
print('Último turno:', df.FechaDeOtorgado.max())
# Out:
# Turnos fuera del rango a estudiar [2018-2019]: 0
# Fecha del Turno
#
# Diferencia mínima temporal: -30 days +13:10:00
# Están ordenados por Turnos: False
# Primer turno: 2018-01-01 02:31:00
# Último turno: 2019-12-31 23:30:00
#
# Fecha de Otorgado
# Primer turno: 2017-11-29 14:36:56
# Último turno: 2020-05-18 13:06:41

# %%
Bad_Dates = df.FechaDelTurno         < df.FechaDeOtorgado
Ter_Dates = df.FechaDelTurno.dt.date < df.FechaDeOtorgado.dt.date
print('Cantidad de fechas otorgadas antes del turno en si: %i == %.2f%%' %(Bad_Dates.sum(), Bad_Dates.sum()*100/len(df)))
print('Cantidad de fechas otorgadas antes del turno en si, con más de 1 día de diferencia: %i == %.2f%%' %(Ter_Dates.sum(), Ter_Dates.sum()*100/len(df)))
df.drop(df.index[Ter_Dates], inplace=True)
print('Se han removido las %i filas de fechas erróneas' %Ter_Dates.sum())
df.reset_index(drop=True, inplace=True)
# Out:
# Cantidad de fechas otorgadas antes del turno en si: 176432 == 6.90%
# Cantidad de fechas otorgadas antes del turno en si, con más de 1 día de diferencia: 32 == 0.00%
# Se han removido las 32 filas de fechas erróneas

# %%
print('Tamaño df: %.2f GB' %(df.memory_usage(deep=False).sum()*1e-9))
print('Tamaño del dataset:', np.shape(df))
display(df.sample(5))
# Out:
# Tamaño df: 0.60 GB
# Tamaño del dataset: (2557429, 29)
#          CentroDeAtencion                         Prestador  Recurso  \
# 1929971                 2           MEDIFE ASOCIACIÓN CIVIL       17
# 2205624                 1                             OSDE       121
# 812775                  1                           SANCOR       112
# 759973                  2  O.S.DEL PERSONAL DE LUZ Y FUERZA      512
# 943231                  3                             DASPU        3
#
#                          Servicio       FechaDelTurno EstadoDelTurno Sexo  \
# 1929971                 ANESTESIA 2019-07-31 16:00:00           Otro    F
# 2205624   GUARDIA DE TRAUMATO DIA 2019-10-07 08:10:00       Atendido    F
# 812775   GINECOLOGIA PRACTICAS CP 2018-09-20 11:30:00       Atendido    F
# 759973    DEMANDA DE OFTALMOLOGIA 2018-09-05 18:28:00       Atendido    M
# 943231       GINECO Y OBSTETRICIA 2018-10-29 14:20:00       Atendido    F
#
# ...

# %%
Memory()
# Out:
# Memoria actual utilizada: 1.28 GB

# %%
#Borramos innecesarios
del A_Remover, Mal_Escrito, Mal_Provinc, Bad_Dates, Ter_Dates, Duda

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Análisis rápido

# %% [markdown]
# ---

# %% [markdown]
# ## Centro de Atención

# %%
df.stb.freq(['CentroDeAtencion'], style=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_3f2fb96c_1a28_11eb_8d42_b160fb2373de" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CentroDeAtencion</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3f2fb96c_1a28_11eb_8d42_b160fb2373delevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3f2fb96c_1a28_11eb_8d42_b160fb2373derow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_3f2fb96c_1a28_11eb_8d42_b160fb2373derow0_col1" class="data row0 col1" >1,554,909</td>
#                         <td id="T_3f2fb96c_1a28_11eb_8d42_b160fb2373derow0_col2" class="data row0 col2" >60.80%</td>
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Prestador

# %%
df.stb.freq(['Prestador'], style=True, thresh=80, other_label='Resto')
# Out:
# <style  type="text/css" >
# </style><table id="T_3f686dde_1a28_11eb_8d42_b160fb2373de" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Prestador</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3f686dde_1a28_11eb_8d42_b160fb2373delevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3f686dde_1a28_11eb_8d42_b160fb2373derow0_col0" class="data row0 col0" >No Definido</td>
#                         <td id="T_3f686dde_1a28_11eb_8d42_b160fb2373derow0_col1" class="data row0 col1" >786,466</td>
#                         <td id="T_3f686dde_1a28_11eb_8d42_b160fb2373derow0_col2" class="data row0 col2" >30.75%</td>
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Recurso

# %%
df.stb.freq(['Recurso'], style=True, thresh=20, other_label='Resto')
# Out:
# <style  type="text/css" >
# </style><table id="T_3f7d8c82_1a28_11eb_8d42_b160fb2373de" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Recurso</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3f7d8c82_1a28_11eb_8d42_b160fb2373delevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3f7d8c82_1a28_11eb_8d42_b160fb2373derow0_col0" class="data row0 col0" >506.000000</td>
#                         <td id="T_3f7d8c82_1a28_11eb_8d42_b160fb2373derow0_col1" class="data row0 col1" >134,825</td>
#                         <td id="T_3f7d8c82_1a28_11eb_8d42_b160fb2373derow0_col2" class="data row0 col2" >5.27%</td>
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Servicio

# %%
df.stb.freq(['Servicio'], style=True, thresh=50, other_label='Resto')
# Out:
# <style  type="text/css" >
# </style><table id="T_3fb7875c_1a28_11eb_8d42_b160fb2373de" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Servicio</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3fb7875c_1a28_11eb_8d42_b160fb2373delevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3fb7875c_1a28_11eb_8d42_b160fb2373derow0_col0" class="data row0 col0" >KINESIOL Y FISIOTERAPIA</td>
#                         <td id="T_3fb7875c_1a28_11eb_8d42_b160fb2373derow0_col1" class="data row0 col1" >262,789</td>
#                         <td id="T_3fb7875c_1a28_11eb_8d42_b160fb2373derow0_col2" class="data row0 col2" >10.28%</td>
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Estado Del Turno

# %%
df.stb.freq(['EstadoDelTurno'], style=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_3fe63c96_1a28_11eb_8d42_b160fb2373de" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >EstadoDelTurno</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3fe63c96_1a28_11eb_8d42_b160fb2373delevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3fe63c96_1a28_11eb_8d42_b160fb2373derow0_col0" class="data row0 col0" >Otro</td>
#                         <td id="T_3fe63c96_1a28_11eb_8d42_b160fb2373derow0_col1" class="data row0 col1" >1,188,940</td>
#                         <td id="T_3fe63c96_1a28_11eb_8d42_b160fb2373derow0_col2" class="data row0 col2" >46.49%</td>
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Sexo

# %%
df.stb.freq(['Sexo'], style=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_4013e5c4_1a28_11eb_8d42_b160fb2373de" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Sexo</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4013e5c4_1a28_11eb_8d42_b160fb2373delevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4013e5c4_1a28_11eb_8d42_b160fb2373derow0_col0" class="data row0 col0" >F</td>
#                         <td id="T_4013e5c4_1a28_11eb_8d42_b160fb2373derow0_col1" class="data row0 col1" >1,095,892</td>
#                         <td id="T_4013e5c4_1a28_11eb_8d42_b160fb2373derow0_col2" class="data row0 col2" >42.85%</td>
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Tipo De Turno Asignado

# %%
df.stb.freq(['TipoDeTurnoAsignado'], style=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_404836da_1a28_11eb_8d42_b160fb2373de" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >TipoDeTurnoAsignado</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_404836da_1a28_11eb_8d42_b160fb2373delevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_404836da_1a28_11eb_8d42_b160fb2373derow0_col0" class="data row0 col0" >No Definido</td>
#                         <td id="T_404836da_1a28_11eb_8d42_b160fb2373derow0_col1" class="data row0 col1" >786,466</td>
#                         <td id="T_404836da_1a28_11eb_8d42_b160fb2373derow0_col2" class="data row0 col2" >30.75%</td>
# ...

# %% [markdown]
# ## Prestación Asignada

# %%
df.stb.freq(['PrestacionAsignada'], style=True, thresh=85, other_label='Resto')
# Out:
# <style  type="text/css" >
# </style><table id="T_4082f1bc_1a28_11eb_8d42_b160fb2373de" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PrestacionAsignada</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4082f1bc_1a28_11eb_8d42_b160fb2373delevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4082f1bc_1a28_11eb_8d42_b160fb2373derow0_col0" class="data row0 col0" >CONSULTA MEDICA</td>
#                         <td id="T_4082f1bc_1a28_11eb_8d42_b160fb2373derow0_col1" class="data row0 col1" >1,022,592</td>
#                         <td id="T_4082f1bc_1a28_11eb_8d42_b160fb2373derow0_col2" class="data row0 col2" >39.99%</td>
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Localidad

# %%
df.stb.freq(['Localidad'], style=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_40b4659e_1a28_11eb_8d42_b160fb2373de" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Localidad</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_40b4659e_1a28_11eb_8d42_b160fb2373delevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_40b4659e_1a28_11eb_8d42_b160fb2373derow0_col0" class="data row0 col0" >No Definido</td>
#                         <td id="T_40b4659e_1a28_11eb_8d42_b160fb2373derow0_col1" class="data row0 col1" >1,947,388</td>
#                         <td id="T_40b4659e_1a28_11eb_8d42_b160fb2373derow0_col2" class="data row0 col2" >76.15%</td>
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Provincia

# %%
df.stb.freq(['Provincia'], style=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_40e53386_1a28_11eb_8d42_b160fb2373de" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Provincia</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_40e53386_1a28_11eb_8d42_b160fb2373delevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_40e53386_1a28_11eb_8d42_b160fb2373derow0_col0" class="data row0 col0" >No Definido</td>
#                         <td id="T_40e53386_1a28_11eb_8d42_b160fb2373derow0_col1" class="data row0 col1" >1,853,183</td>
#                         <td id="T_40e53386_1a28_11eb_8d42_b160fb2373derow0_col2" class="data row0 col2" >72.46%</td>
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Nombre Del Canal

# %%
df.stb.freq(['NombreDelCanal'], style=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_41166032_1a28_11eb_8d42_b160fb2373de" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >NombreDelCanal</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_41166032_1a28_11eb_8d42_b160fb2373delevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_41166032_1a28_11eb_8d42_b160fb2373derow0_col0" class="data row0 col0" >No Definido</td>
#                         <td id="T_41166032_1a28_11eb_8d42_b160fb2373derow0_col1" class="data row0 col1" >1,498,745</td>
#                         <td id="T_41166032_1a28_11eb_8d42_b160fb2373derow0_col2" class="data row0 col2" >58.60%</td>
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Es Sobre Turno

# %%
df.stb.freq(['EsSobreTurno'], style=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_4142ae44_1a28_11eb_8d42_b160fb2373de" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >EsSobreTurno</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4142ae44_1a28_11eb_8d42_b160fb2373delevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4142ae44_1a28_11eb_8d42_b160fb2373derow0_col0" class="data row0 col0" >NO</td>
#                         <td id="T_4142ae44_1a28_11eb_8d42_b160fb2373derow0_col1" class="data row0 col1" >1,722,844</td>
#                         <td id="T_4142ae44_1a28_11eb_8d42_b160fb2373derow0_col2" class="data row0 col2" >67.37%</td>
# ...

# %%
Memory()
# Out:
# Memoria actual utilizada: 1.24 GB

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # _**PACIENTES EXISTENTES**_

# %% [markdown]
# ## Creación de _Nuevo dataset (**dfnn**)_
#
# **HC $\ne$ np.nan**
#
# **turno $\ne$ 'Otro'**
#
# En caso de que un paciente existente tenga **turno == 'Otro'**, se eliminará la fila (no se estudiará)

# %%
Pacientes = ~df.HC.isnull()
print('Cantidad de turnos con paciente: %i == %.2f%% del total de turnos' %(np.sum(Pacientes), np.sum(Pacientes)*100/float(len(df))))

Extra = df[Pacientes].EstadoDelTurno == 'Otro'
print('Cantidad de turnos (con paciente) catalogados como "Otro": '
      '%i == %.4f%% del total de turnos con paciente' 
      %(np.sum(Extra), np.sum(Extra)*100/float(len(df[Pacientes]))))
# Out:
# Cantidad de turnos con paciente: 1770963 == 69.25% del total de turnos
# Cantidad de turnos (con paciente) catalogados como "Otro": 402474 == 22.7263% del total de turnos con paciente

# %%
dfnn = df[Pacientes][~Extra]
dfnn.reset_index(inplace=True)
dfnn.rename(columns={"index": "Index_df"}, inplace=True)
print('Tamaño df: %.2f GB' %(dfnn.memory_usage(deep=False).sum()*1e-9))
print('Tamaño del dataset:', dfnn.shape)
display(dfnn.sample(5))
# Out:
# Tamaño df: 0.33 GB
# Tamaño del dataset: (1368489, 30)
#          Index_df  CentroDeAtencion                 Prestador  Recurso  \
# 1117693   2112308                 3          PREVENCION SALUD       27
# 1203030   2261359                 2  OMINT S. A. DE SERVICIOS      317
# 815414    1559095                 1        SWISS MEDICAL S.A.      446
# 959817    1823404                 1   MEDIFE ASOCIACIÓN CIVIL      248
# 683463    1305998                 1                   SANCOR       103
#
#                          Servicio       FechaDelTurno EstadoDelTurno Sexo  \
# 1117693               GINECOLOGÍA 2019-09-13 14:15:00       Atendido    F
# 1203030                MAMOGRAFIA 2019-10-21 11:15:00       Atendido    F
# 815414                  PEDIATRÍA 2019-04-30 17:20:00       Atendido    F
# 959817            GOTEO DE HIERRO 2019-07-05 17:45:00       Atendido    F
# 683463   OTORRINOLARINGOLOGIA INF 2019-02-18 11:30:00       Atendido    M
#
# ...

# %%
Memory()
# Out:
# Memoria actual utilizada: 1.49 GB

# %%
test_integridad(dfnn)
# Out:
# Ejecutando tests de Integridad
# Test Estado del Turno : EXITOSO
# Test Edad             : ERROR
# Test Sexo             : ERROR
# Test Provincia        : EXITOSO
# Test Localidad        : EXITOSO
# Test Nombre del Canal : EXITOSO
# Test Prestador        : ERROR
# Test Servicio         : ERROR
# Test Prestación       : ERROR
# Test Fecha de Turno   : EXITOSO
# Test Fecha de Otorgado: EXITOSO
# Test Tipo de Turno    : EXITOSO

# %% [markdown]
# ## Análisis, limpieza y categorización rápidas

# %% [markdown]
# ---

# %% [markdown]
# ### Estado del Turno

# %%
display(dfnn.stb.freq(['EstadoDelTurno'], style=True))

plt.figure(dpi=100)
dfnn.EstadoDelTurno.value_counts(normalize=True, ascending=False).plot.bar(color=[RED, ORANGE])
plt.xlabel('Estado del Turno')
plt.ylabel('Frecuencia')
plt.xticks(rotation=0)
plt.show()
# Out:
# <style  type="text/css" >
# </style><table id="T_45416cc4_1a28_11eb_8d42_b160fb2373de" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >EstadoDelTurno</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_45416cc4_1a28_11eb_8d42_b160fb2373delevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_45416cc4_1a28_11eb_8d42_b160fb2373derow0_col0" class="data row0 col0" >Atendido</td>
#                         <td id="T_45416cc4_1a28_11eb_8d42_b160fb2373derow0_col1" class="data row0 col1" >1,172,439</td>
#                         <td id="T_45416cc4_1a28_11eb_8d42_b160fb2373derow0_col2" class="data row0 col2" >85.67%</td>
# ...

# %% [markdown]
# #### **Ausentes y Atendidos**
#
# Creamos una máscara para los turnos ausentados y una para los turnos atendidos. (Se irá actualizando a medida que se opere sobre _dfnn_)

# %%
Ausentes  = dfnn.EstadoDelTurno == 'Ausente'
Atendidos = dfnn.EstadoDelTurno == 'Atendido'

# %% [markdown]
# ### Centro de Atención

# %%
#Centro de atención 6
print('Cantidad de turnos eliminados, pertenecientes al centro de atención 6:', (dfnn.CentroDeAtencion == 6).sum())

#Eliminamos el cetro de atención 6
dfnn.drop(dfnn[dfnn.CentroDeAtencion == 6].index, inplace=True)

#Rehacemos las máscaras
Ausentes  = dfnn.EstadoDelTurno == 'Ausente'
Atendidos = dfnn.EstadoDelTurno == 'Atendido'
# Out:
# Cantidad de turnos eliminados, pertenecientes al centro de atención 6: 1

# %%
#Generamos las tablas
Tot, Dif                = Tablas(dfnn, 'CentroDeAtencion')
Diferenciado            = Dif.copy()
Total                   = Tot.copy()
Diferenciado.Porcentaje = Dif.Porcentaje.apply(Porcent)
Total.Porcentaje        = Total.Porcentaje.apply(Porcent)
Total.Porcent_Acumu     = Total.Porcent_Acumu.apply(Porcent)
display_side_by_side("Diferenciado", "Total")
# Out:
# Diferenciado
#                                  Cantidad Porcentaje
# CentroDeAtencion EstadoDelTurno
# 1                Atendido          740111     86.87%
#                  Ausente           111834     13.13%
# 2                Atendido          211488     84.51%
#                  Ausente            38753     15.49%
# 4                Atendido          110021     83.65%
#                  Ausente            21500     16.35%
# 3                Atendido          107757     82.09%
#                  Ausente            23502     17.91%
# 5                Atendido            3062     86.94%
#                  Ausente              460     13.06%
#
# Total
#                   Cantidad Porcentaje  Cant_Acum Porcent_Acumu  Ausentismo
# CentroDeAtencion
# 1                   851945     62.25%     851945        62.25%    0.151104
# 2                   250241     18.29%    1102186        80.54%    0.183240
# 4                   131521      9.61%    1233707        90.15%    0.195417
# ...

# %%
#Ploteamos
Ploteo(Tot, Dif, name='Centro de Atención')

# %% [markdown]
# ---

# %% [markdown]
# ### Prestador

# %%
print('Total de prestadores:', len(dfnn.Prestador.unique()))
display(dfnn.stb.freq(['Prestador'], style=True, thresh=80, other_label='Resto'))

plt.figure(dpi=100)
dfnn.Prestador.value_counts(normalize=True, ascending=True)[-10:].plot.barh(color=BLUE)
plt.ylabel('Prestador')
plt.xlabel('Frecuencia')
plt.show()
# Out:
# Total de prestadores: 75
# <style  type="text/css" >
# </style><table id="T_4751ff7e_1a28_11eb_8d42_b160fb2373de" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Prestador</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4751ff7e_1a28_11eb_8d42_b160fb2373delevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4751ff7e_1a28_11eb_8d42_b160fb2373derow0_col0" class="data row0 col0" >OSDE </td>
#                         <td id="T_4751ff7e_1a28_11eb_8d42_b160fb2373derow0_col1" class="data row0 col1" >183,434</td>
# ...

# %% [markdown]
# #### Agrupación

# %%
#Agrupamos los prestadores de igual central, e introduciomos una columna nueva con el resultado
dfnn['PrestadorAgrupado'] = dfnn.Prestador.apply(unidecode.unidecode).str.upper().str.strip()

Agrupaciones = ['GALENO', 'LA SEGUNDA', 'OSPE', 'PREVENCION', 'SANCOR', 'OMINT']

for Nuevo in Agrupaciones:
    dfnn.loc[[Nuevo in s for s in dfnn.PrestadorAgrupado] ,'PrestadorAgrupado'] = Nuevo

#Estos quedan colgando...
dfnn['PrestadorAgrupado'] = dfnn.Prestador.replace({
    'CONSUMIDOR FINAL': 'PARTICULAR',
    'EMPLEADO CURF': 'EMPLEADO',
    'UNIVERSIDAD CATOLICA DE CORDOBA': 'EMPLEADO',
    'CAMPAÑAS': 'EXCEPCIONES',
    'PRE OCUPACIONALES': 'EXCEPCIONES',
    'PROTOCOLOS': 'EXCEPCIONES'})

# %%
#Nos quedamos con los 10 más representativos
print('Debido a la gran cantidad de prestadores, nos quedaremos con los 10 más repetidos, y al resto los catalogaremos como "OTRO"')
dfnn.loc[~dfnn.PrestadorAgrupado.isin(dfnn.PrestadorAgrupado.value_counts()[:10].index), 'PrestadorAgrupado'] = 'OTRO'

print('Total de prestadores:', len(dfnn.PrestadorAgrupado.unique()))
# Out:
# Debido a la gran cantidad de prestadores, nos quedaremos con los 10 más repetidos, y al resto los catalogaremos como "OTRO"
# Total de prestadores: 11

# %%
#Generamos las tablas
Tot, Dif                = Tablas(dfnn, 'PrestadorAgrupado')
Diferenciado            = Dif.copy()
Total                   = Tot.copy()
Diferenciado.Porcentaje = Dif.Porcentaje.apply(Porcent)
Total.Porcentaje        = Total.Porcentaje.apply(Porcent)
Total.Porcent_Acumu     = Total.Porcent_Acumu.apply(Porcent)
display_side_by_side("Diferenciado", "Total")
# Out:
# Diferenciado
#                                          Cantidad Porcentaje
# PrestadorAgrupado        EstadoDelTurno
# OTRO                     Atendido          274510     85.27%
#                          Ausente            47429     14.73%
# OSDE                     Atendido          161341     87.96%
#                          Ausente            22093     12.04%
# SWISS MEDICAL S.A.       Atendido          120793     85.67%
#                          Ausente            20199     14.33%
# OMINT S. A. DE SERVICIOS Atendido          118071     85.97%
#                          Ausente            19264     14.03%
# PARTICULAR               Atendido          109247     86.51%
#                          Ausente            17034     13.49%
# MEDIFE ASOCIACIÓN CIVIL  Atendido           96602     83.77%
#                          Ausente            18718     16.23%
# SANCOR                   Atendido           92502     85.53%
# ...

# %%
#Ploteamos
Ploteo(Tot, Dif, 'Prestador', h=True)

# %% [markdown]
# ---

# %% [markdown]
# ### Servicio

# %%
print('Total de servicios:', len(dfnn.Servicio.unique()))
display(dfnn.stb.freq(['Servicio'], style=True, thresh=55, other_label='Resto'))

plt.figure(dpi=100)
dfnn.Servicio.value_counts(normalize=True, ascending=True)[-10:].plot.barh(color=BLUE)
plt.ylabel('Servicio')
plt.xlabel('Frecuencia')
plt.show()
# Out:
# Total de servicios: 109
# <style  type="text/css" >
# </style><table id="T_4e9ad166_1a28_11eb_8d42_b160fb2373de" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Servicio</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4e9ad166_1a28_11eb_8d42_b160fb2373delevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4e9ad166_1a28_11eb_8d42_b160fb2373derow0_col0" class="data row0 col0" >GINECO Y OBSTETRICIA</td>
#                         <td id="T_4e9ad166_1a28_11eb_8d42_b160fb2373derow0_col1" class="data row0 col1" >132,154</td>
# ...

# %% [markdown]
# #### Guardia

# %%
#Hallamos las guardias
Guardia = ['GUARDIA' in s for s in dfnn.Servicio]
print('Cantidad de turnos de GUARDIA removidos: %i (%.2f%% del total de turnos)' %(np.sum(Guardia), np.sum(Guardia)*100/len(dfnn)))

#Eliminamos GUARDIAs
dfnn.drop(dfnn[Guardia].index, inplace=True)
# Out:
# Cantidad de turnos de GUARDIA removidos: 30988 (2.26% del total de turnos)

# %% [markdown]
# #### Agrupación

# %%
#Agrupamos los Servicios, e introduciomos una columna nueva con el resultado
dfnn['ServicioAgrupado'] = dfnn.Servicio.apply(unidecode.unidecode).str.strip()
Agrupaciones = ['ALERGIA E INMUNOLOGIA', 'ANATOMIA PATOLOGICA', 'CARDIOLOGIA', 'CHEQUEO', 'CIRUGIA',
                'CUENTAS PROPIAS ALERGIA E INMUNOLOGIA', 'DEMANDA', 'DERMATOLOGIA', 'ENDOCRINOLOGIA',
                'FONOAUDIOLOGIA', 'GASTROENTEROLOGIA', 'GINECOLOGIA', 'HEMATOLOGIA', 'HEMOSTASIA',
                'INFECTOLOGIA', 'NEFROLOGIA', 'NEUMONOLOGIA', 'NEUROCIRUGIA', 'NEUROLOGIA', 'NUTRICION',
                'ORTOPEDIA', 'OTORRINOLARINGOLOGIA', 'PSICOLOGIA', 'REUMATOLOGIA', 'TERAPIA OCUPACIONAL',
                'UROLOGIA', 'NUTRIC']

for Nuevo in Agrupaciones:
    dfnn.loc[[Nuevo in s for s in dfnn.ServicioAgrupado] ,'ServicioAgrupado'] = Nuevo

# %%
#Nos quedamos con los 10 más representativos
print('Debido a la gran cantidad de servicios, nos quedaremos con los 10 más repetidos, y al resto los catalogaremos como "OTRO"')
dfnn.loc[~dfnn.ServicioAgrupado.isin(dfnn.ServicioAgrupado.value_counts()[:10].index), 'ServicioAgrupado'] = 'OTRO'

print('Total de Servicios:', len(dfnn.ServicioAgrupado.unique()))
# Out:
# Debido a la gran cantidad de servicios, nos quedaremos con los 10 más repetidos, y al resto los catalogaremos como "OTRO"
# Total de Servicios: 11

# %%
#Generamos las tablas
Tot, Dif                = Tablas(dfnn, 'ServicioAgrupado')
Diferenciado            = Dif.copy()
Total                   = Tot.copy()
Diferenciado.Porcentaje = Dif.Porcentaje.apply(Porcent)
Total.Porcentaje        = Total.Porcentaje.apply(Porcent)
Total.Porcent_Acumu     = Total.Porcent_Acumu.apply(Porcent)
display_side_by_side("Diferenciado", "Total")
# Out:
# Diferenciado
#                                         Cantidad Porcentaje
# ServicioAgrupado        EstadoDelTurno
# OTRO                    Atendido          480462     86.61%
#                         Ausente            74264     13.39%
# GINECO Y OBSTETRICIA    Atendido          112161     84.87%
#                         Ausente            19993     15.13%
# KINESIOL Y FISIOTERAPIA Atendido          106943     83.49%
#                         Ausente            21144     16.51%
# PEDIATRIA               Atendido           90496     88.24%
#                         Ausente            12061     11.76%
# ORTOPEDIA               Atendido           66699     83.99%
#                         Ausente            12716     16.01%
# CLINICA MEDICA          Atendido           59014     82.99%
#                         Ausente            12097     17.01%
# CARDIOLOGIA             Atendido           56186     85.56%
#                         Ausente             9481     14.44%
# ...

# %%
#Ploteamos
Ploteo(Tot, Dif, 'Servicio', True)

# %% [markdown]
# ---

# %% [markdown]
# ### Sexo

# %%
#Sexo No definido
print('Cantidad de turnos eliminados, con Sexo "No Definido":', (dfnn.Sexo == 'No Definido').sum())

#Eliminamos el Sexo No definido
dfnn.drop(dfnn[dfnn.Sexo == 'No Definido'].index, inplace=True)

#Rehacemos las máscaras
Ausentes  = dfnn.EstadoDelTurno == 'Ausente'
Atendidos = dfnn.EstadoDelTurno == 'Atendido'
# Out:
# Cantidad de turnos eliminados, con Sexo "No Definido": 1223

# %%
#Generamos las tablas
Tot, Dif                = Tablas(dfnn, 'Sexo')
Diferenciado            = Dif.copy()
Total                   = Tot.copy()
Diferenciado.Porcentaje = Dif.Porcentaje.apply(Porcent)
Total.Porcentaje        = Total.Porcentaje.apply(Porcent)
Total.Porcent_Acumu     = Total.Porcent_Acumu.apply(Porcent)
display_side_by_side("Diferenciado", "Total")
# Out:
# Diferenciado
#                      Cantidad Porcentaje
# Sexo EstadoDelTurno
# F    Atendido          698981     84.83%
#      Ausente           124992     15.17%
# M    Atendido          441651     86.21%
#      Ausente            70653     13.79%
#
# Total
#       Cantidad Porcentaje  Cant_Acum Porcent_Acumu  Ausentismo
# Sexo
# F       823973     61.66%     823973        61.66%    0.178820
# M       512304     38.34%    1336277       100.00%    0.159975

# %%
#Ploteamos
Ploteo(Tot, Dif)

# %% [markdown]
# ---

# %% [markdown]
# ### Tipo de Turno Asignado

# %%
#Rehacemos las máscaras
Ausentes  = dfnn.EstadoDelTurno == 'Ausente'
Atendidos = dfnn.EstadoDelTurno == 'Atendido'

# %%
#Generamos las tablas
Tot, Dif                = Tablas(dfnn, 'TipoDeTurnoAsignado')
Diferenciado            = Dif.copy()
Total                   = Tot.copy()
Diferenciado.Porcentaje = Dif.Porcentaje.apply(Porcent)
Total.Porcentaje        = Total.Porcentaje.apply(Porcent)
Total.Porcent_Acumu     = Total.Porcent_Acumu.apply(Porcent)
display_side_by_side("Diferenciado", "Total")
# Out:
# Diferenciado
#                                     Cantidad Porcentaje
# TipoDeTurnoAsignado EstadoDelTurno
# Ulterior / Control  Atendido          492932     86.96%
#                     Ausente            73899     13.04%
# Práctica            Atendido          338118     86.92%
#                     Ausente            50898     13.08%
# Primera Vez         Atendido          287360     80.38%
#                     Ausente            70122     19.62%
# Recetas             Atendido           18256     98.03%
#                     Ausente              367      1.97%
# DNP                 Atendido            3966     91.70%
#                     Ausente              359      8.30%
#
# Total
#                      Cantidad Porcentaje  Cant_Acum Porcent_Acumu  Ausentismo
# TipoDeTurnoAsignado
# Ulterior / Control     566831     42.42%     566831        42.42%    0.149917
# Práctica               389016     29.11%     955847        71.53%    0.150533
# ...

# %%
#Ploteamos
Ploteo(Tot, Dif, 'Tipo de Turno', True)

# %% [markdown]
# ---

# %% [markdown]
# ### Prestación Asignada

# %%
print('Total de prestaciones:', len(dfnn.PrestacionAsignada.unique()))
display(dfnn.stb.freq(['PrestacionAsignada'], style=True, thresh=75, other_label='Resto'))

plt.figure(dpi=100)
dfnn.PrestacionAsignada.value_counts(normalize=True, ascending=True)[-10:].plot.barh(color=BLUE)
plt.ylabel('Prestación Asignada')
plt.xlabel('Frecuencia')
plt.show()
# Out:
# Total de prestaciones: 834
# <style  type="text/css" >
# </style><table id="T_61af303a_1a28_11eb_8d42_b160fb2373de" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PrestacionAsignada</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_61af303a_1a28_11eb_8d42_b160fb2373delevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_61af303a_1a28_11eb_8d42_b160fb2373derow0_col0" class="data row0 col0" >CONSULTA MEDICA</td>
#                         <td id="T_61af303a_1a28_11eb_8d42_b160fb2373derow0_col1" class="data row0 col1" >782,042</td>
# ...

# %% [markdown]
# #### Agrupación

# %%
#Agrupamos las Prestaciones, e introduciomos una columna nueva con el resultado
dfnn['PrestacionAgrupado'] = dfnn.PrestacionAsignada.apply(unidecode.unidecode).str.upper().str.strip()
Agrupaciones = ['ATENCION DEL', 'ANALISIS CROMOSOMICO', 'ANGIORESONANCIA', 'ANGIOTAC', 'ANTICUERPOS MONOCLONALES',
                'APLICACION DE SUSTANCIA QUIMICA', 'BIOFEEDBACK', 'BIOPSIA', 'BLOQUEO FACETARIO', 'CALIBRACION',
                'CIRUGIA', 'CITOLOGIA', 'VACUNAS', 'COLOC', 'CONIZACION', 'CONSULTA', 'CONTROL', 'COOMBS',
                'PERDIDA DE REGION CROMOSOMICA', 'CRIOCIRUGIA', 'CURVA', 'DRENAJE', 'EMMAC', 'ERGOMETRIA', 'ESCISION',
                'ESPIROMETRIA', 'ESTUDIO', 'EVALUACION', 'EXAMEN', 'EXTIRPACION', 'EXTRACCION', 'FERULA',
                'FOTOCOAGULACION', 'HIGIENE', 'HOLTER', 'HPV', 'IMPEDANCIONMETRIA', 'INCISION', 'INFILTRACION',
                'MAMOGRAFIA', 'MARCA', 'MIRINGO', 'NEURO', 'OFTA', 'OSTEOSINTESIS', 'PEELING', 'PLAN NUTRICIONAL',
                'POST QUIRURGICO', 'POTENCIAL', 'PRUEBA', 'PUNCION', 'QF PCR', 'RADIOGRAFIA', 'RECAMBIO DE',
                'REHABILITACION', 'RESECCION', 'RIESGO', 'RMN ', 'RX HUMERO', 'SELECCION', 'SESION TERAPIA',
                'SINUSOTOMIA', 'TAC ', 'TENOPLASTIA', 'TENORRAFIA', 'TRANSFUSION', 'URETROCISTOFIBROSCOPIA',
                'VALORACION', 'VIDEOENDOSCOPIA', 'YESO', 'ECO']
for Nuevo in Agrupaciones:
    dfnn.loc[[Nuevo in s for s in dfnn.PrestacionAgrupado] ,'PrestacionAgrupado'] = Nuevo

#Estos quedan colgando...
dfnn.PrestacionAgrupado.replace('ATENCION DEL', 'QUEMADURAS', inplace=True)
dfnn.loc[[('E.C.G' in s) or ('ELECTRO' in s) or ('EMG' in s) for s in dfnn.PrestacionAgrupado],
         'PrestacionAgrupado'] = 'ELECTRO'
dfnn.loc[[('OTOEMISIONES' in s) or ('OTOPLASTIA' in s) for s in dfnn.PrestacionAgrupado],
         'PrestacionAgrupado'] = 'OSTO'
dfnn.loc[[('TRAT.' in s) or ('TRATAMIENTO' in s) for s in dfnn.PrestacionAgrupado],
         'PrestacionAgrupado'] = 'TRATAMIENTO'
dfnn.loc[[('FISIO' in s) or ('KINE' in s) for s in dfnn.PrestacionAgrupado],
         'PrestacionAgrupado'] = 'FISIO|KINE'
dfnn.loc[[('MOD.' in s) or ('MODULO' in s) for s in dfnn.PrestacionAgrupado],
         'PrestacionAgrupado'] = 'MODULO'
dfnn.loc[[('TESTIFICACION' in s) or ('TEST' in s) for s in dfnn.PrestacionAgrupado],
         'PrestacionAgrupado'] = 'TEST'

# %%
#Nos quedamos con las 10 más representativos
print('Debido a la gran cantidad de Prestaciones, nos quedaremos con las 10 más repetidas, y al resto las catalogaremos como "OTRA"')
dfnn.loc[~dfnn.PrestacionAgrupado.isin(dfnn.PrestacionAgrupado.value_counts()[:10].index), 'PrestacionAgrupado'] = 'OTRA'

print('Total de Servicios:', len(dfnn.PrestacionAgrupado.unique()))
# Out:
# Debido a la gran cantidad de Prestaciones, nos quedaremos con las 10 más repetidas, y al resto las catalogaremos como "OTRA"
# Total de Servicios: 11

# %%
#Generamos las tablas
Tot, Dif                = Tablas(dfnn, 'PrestacionAgrupado')
Diferenciado            = Dif.copy()
Total                   = Tot.copy()
Diferenciado.Porcentaje = Dif.Porcentaje.apply(Porcent)
Total.Porcentaje        = Total.Porcentaje.apply(Porcent)
Total.Porcent_Acumu     = Total.Porcent_Acumu.apply(Porcent)
display_side_by_side("Diferenciado", "Total")
# Out:
# Diferenciado
#                                             Cantidad Porcentaje
# PrestacionAgrupado          EstadoDelTurno
# CONSULTA                    Atendido          731183     84.03%
#                             Ausente           138988     15.97%
# OTRA                        Atendido          107972     82.71%
#                             Ausente            22563     17.29%
# PRESTACIONES MULTIPLES      Atendido          101271     97.93%
#                             Ausente             2137      2.07%
# FISIO|KINE                  Atendido           58589     83.17%
#                             Ausente            11853     16.83%
# QUIMIOTERAPIA AMBULATORIA   Atendido           33912     97.34%
#                             Ausente              927      2.66%
# REHABILITACION              Atendido           26234     75.69%
#                             Ausente             8426     24.31%
# ECO                         Atendido           23864     85.83%
# ...

# %%
#Ploteamos
Ploteo(Tot, Dif, 'Prestación', True)

# %% [markdown]
# ---

# %% [markdown]
# ### Localidad

# %%
#Generamos las tablas
Tot, Dif                = Tablas(dfnn, 'Localidad')
Diferenciado            = Dif.copy()
Total                   = Tot.copy()
Diferenciado.Porcentaje = Dif.Porcentaje.apply(Porcent)
Total.Porcentaje        = Total.Porcentaje.apply(Porcent)
Total.Porcent_Acumu     = Total.Porcent_Acumu.apply(Porcent)
display_side_by_side("Diferenciado", "Total")
# Out:
# Diferenciado
#                             Cantidad Porcentaje
# Localidad   EstadoDelTurno
# No Definido Atendido          749610     85.20%
#             Ausente           130239     14.80%
# Córdoba     Atendido          305591     84.81%
#             Ausente            54739     15.19%
# Otra        Atendido           85431     88.90%
#             Ausente            10667     11.10%
#
# Total
#              Cantidad Porcentaje  Cant_Acum Porcent_Acumu  Ausentismo
# Localidad
# No Definido    879849     65.84%     879849        65.84%    0.173742
# Córdoba        360330     26.97%    1240179        92.81%    0.179125
# Otra            96098      7.19%    1336277       100.00%    0.124861

# %%
#Ploteamos
Ploteo(Tot, Dif)

# %% [markdown]
# ---

# %% [markdown]
# ### Provincia

# %%
#Generamos las tablas
Tot, Dif                = Tablas(dfnn, 'Provincia')
Diferenciado            = Dif.copy()
Total                   = Tot.copy()
Diferenciado.Porcentaje = Dif.Porcentaje.apply(Porcent)
Total.Porcentaje        = Total.Porcentaje.apply(Porcent)
Total.Porcent_Acumu     = Total.Porcent_Acumu.apply(Porcent)
display_side_by_side("Diferenciado", "Total")
# Out:
# Diferenciado
#                             Cantidad Porcentaje
# Provincia   EstadoDelTurno
# No Definido Atendido          694562     85.60%
#             Ausente           116824     14.40%
# Córdoba     Atendido          440822     84.93%
#             Ausente            78222     15.07%
# Otra        Atendido            5248     89.76%
#             Ausente              599     10.24%
#
# Total
#              Cantidad Porcentaje  Cant_Acum Porcent_Acumu  Ausentismo
# Provincia
# No Definido    811386     60.72%     811386        60.72%    0.168198
# Córdoba        519044     38.84%    1330430        99.56%    0.177446
# Otra             5847      0.44%    1336277       100.00%    0.114139

# %%
#Ploteamos
Ploteo(Tot, Dif)

# %% [markdown]
# ---

# %% [markdown]
# ### Nombre de Canal

# %%
#Generamos las tablas
Tot, Dif                = Tablas(dfnn, 'NombreDelCanal')
Diferenciado            = Dif.copy()
Total                   = Tot.copy()
Diferenciado.Porcentaje = Dif.Porcentaje.apply(Porcent)
Total.Porcentaje        = Total.Porcentaje.apply(Porcent)
Total.Porcent_Acumu     = Total.Porcent_Acumu.apply(Porcent)
display_side_by_side("Diferenciado", "Total")
# Out:
# Diferenciado
#                                     Cantidad Porcentaje
# NombreDelCanal      EstadoDelTurno
# No Definido         Atendido          470549     90.18%
#                     Ausente            51246      9.82%
# Teléfono            Atendido          357650     80.36%
#                     Ausente            87395     19.64%
# Recepción           Atendido          248513     84.08%
#                     Ausente            47049     15.92%
# Turnos Online       Atendido           63394     86.61%
#                     Ausente             9805     13.39%
# Chat/Redes Sociales Atendido             526     77.81%
#                     Ausente              150     22.19%
#
# Total
#                      Cantidad Porcentaje  Cant_Acum Porcent_Acumu  Ausentismo
# NombreDelCanal
# No Definido            521795     39.05%     521795        39.05%    0.108907
# Teléfono               445045     33.30%     966840        72.35%    0.244359
# ...

# %%
#Ploteamos
Ploteo(Tot, Dif, 'Canal', True)

# %% [markdown]
# ---

# %% [markdown]
# ### Sobre Turno

# %%
#Generamos las tablas
Tot, Dif                = Tablas(dfnn, 'EsSobreTurno')
Diferenciado            = Dif.copy()
Total                   = Tot.copy()
Diferenciado.Porcentaje = Dif.Porcentaje.apply(Porcent)
Total.Porcentaje        = Total.Porcentaje.apply(Porcent)
Total.Porcent_Acumu     = Total.Porcent_Acumu.apply(Porcent)
display_side_by_side("Diferenciado", "Total")
# Out:
# Diferenciado
#                              Cantidad Porcentaje
# EsSobreTurno EstadoDelTurno
# NO           Atendido          846231     82.16%
#              Ausente           183691     17.84%
# SI           Atendido          248217     95.41%
#              Ausente            11942      4.59%
# No Definido  Atendido           46184     99.97%
#              Ausente               12      0.03%
#
# Total
#               Cantidad Porcentaje  Cant_Acum Porcent_Acumu  Ausentismo
# EsSobreTurno
# NO             1029922     77.07%    1029922        77.07%    0.217070
# SI              260159     19.47%    1290081        96.54%    0.048111
# No Definido      46196      3.46%    1336277       100.00%    0.000260

# %%
#Ploteamos
Ploteo(Tot, Dif, 'Sobre Turno')

# %% [markdown]
# ---

# %% [markdown]
# ### Fecha

# %% [markdown]
# #### Día Semanal

# %%
#Añadimos la columa del día semanal 
dfnn['DiaSemanal'] = dfnn.FechaDelTurno.dt.weekday.replace(
    {0: 'Lunes', 1: 'Martes', 2: 'Miércoles', 3: 'Jueves', 4: 'Viernes', 5: 'Sábado', 6: 'Domingo'})
OrderDS = ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado', 'Domingo']

# %%
#Generamos las tablas
Tot, Dif                = Tablas(dfnn, 'DiaSemanal', order=OrderDS)
Diferenciado            = Dif.copy()
Total                   = Tot.copy()
Diferenciado.Porcentaje = Dif.Porcentaje.apply(Porcent)
Total.Porcentaje        = Total.Porcentaje.apply(Porcent)
Total.Porcent_Acumu     = Total.Porcent_Acumu.apply(Porcent)
display_side_by_side("Diferenciado", "Total")
# Out:
# Diferenciado
#                            Cantidad Porcentaje
# DiaSemanal EstadoDelTurno
# Lunes      Atendido          219428     85.04%
#            Ausente            38607     14.96%
# Martes     Atendido          237018     84.98%
#            Ausente            41902     15.02%
# Miércoles  Atendido          242210     85.79%
#            Ausente            40116     14.21%
# Jueves     Atendido          224951     85.78%
#            Ausente            37288     14.22%
# Viernes    Atendido          205436     85.43%
#            Ausente            35045     14.57%
# Sábado     Atendido           11182     81.80%
#            Ausente             2488     18.20%
# Domingo    Atendido             407     67.16%
#            Ausente              199     32.84%
#
# Total
#             Cantidad Porcentaje  Cant_Acum Porcent_Acumu  Ausentismo
# DiaSemanal
# Lunes         258035     19.31%     258035        19.31%    0.175944
# ...

# %%
#Ploteamos
Ploteo(Tot, Dif, 'Día Semanal', True, order=OrderDS, yticks=True)

# %% [markdown]
# #### Momento del día

# %%
#Añadimos la columa del día semanal 
dfnn['Hora'] = dfnn.FechaDelTurno.dt.hour
dfnn['MomDelDia'] = ''
dfnn.loc[dfnn.Hora <= 7,                       'MomDelDia'] = '00 - 07'
dfnn.loc[(7  < dfnn.Hora) & (dfnn.Hora <= 10), 'MomDelDia'] = '08 - 10'
dfnn.loc[(10 < dfnn.Hora) & (dfnn.Hora <= 13), 'MomDelDia'] = '11 - 13'
dfnn.loc[(13 < dfnn.Hora) & (dfnn.Hora <= 17), 'MomDelDia'] = '14 - 17'
dfnn.loc[(17 < dfnn.Hora) & (dfnn.Hora <= 20), 'MomDelDia'] = '18 - 20'
dfnn.loc[20 < dfnn.Hora,                       'MomDelDia'] = '21 - 24'
dfnn.drop(columns='Hora', inplace=True)
OrderMD = ['00 - 07', '08 - 10', '11 - 13', '14 - 17', '18 - 20', '21 - 24']

# %%
#Generamos las tablas
Tot, Dif                = Tablas(dfnn, 'MomDelDia', order=OrderMD)
Diferenciado            = Dif.copy()
Total                   = Tot.copy()
Diferenciado.Porcentaje = Dif.Porcentaje.apply(Porcent)
Total.Porcentaje        = Total.Porcentaje.apply(Porcent)
Total.Porcent_Acumu     = Total.Porcent_Acumu.apply(Porcent)
display_side_by_side("Diferenciado", "Total")
# Out:
# Diferenciado
#                           Cantidad Porcentaje
# MomDelDia EstadoDelTurno
# 00 - 07   Atendido            7571     87.83%
#           Ausente             1049     12.17%
# 08 - 10   Atendido          315219     85.17%
#           Ausente            54865     14.83%
# 11 - 13   Atendido          257056     86.55%
#           Ausente            39964     13.45%
# 14 - 17   Atendido          428156     85.08%
#           Ausente            75089     14.92%
# 18 - 20   Atendido          131073     84.92%
#           Ausente            23278     15.08%
# 21 - 24   Atendido            1557     52.65%
#           Ausente             1400     47.35%
#
# Total
#            Cantidad Porcentaje  Cant_Acum Porcent_Acumu  Ausentismo
# MomDelDia
# 00 - 07        8620      0.65%       8620         0.65%    0.138555
# 08 - 10      370084     27.70%     378704        28.34%    0.174054
# 11 - 13      297020     22.23%     675724        50.57%    0.155468
# ...

# %%
#Ploteamos
Ploteo(Tot, Dif, 'Día Semanal', order=OrderMD)

# %% [markdown]
# #### Diferencia temporal entre _Otorgado_ y _Oficial_

# %%
#Añadimos la columa de diferencia temporal (en días)
dfnn['DifEnDias'] = ((dfnn.FechaDelTurno - dfnn.FechaDeOtorgado)/np.timedelta64(1, 'D')).astype(int)

# %%
#Realizamos un resumen
Resumen = pd.DataFrame(dfnn.DifEnDias.rename('Todos').describe().map("{:,.1f}".format))
Resumen['Atendidos'] = pd.DataFrame(dfnn[Atendidos].DifEnDias.describe().map("{:,.1f}".format))
Resumen['Ausentes '] = pd.DataFrame(dfnn[Ausentes ].DifEnDias.describe().map("{:,.1f}".format))
Resumen.rename_axis("DifEnDías", axis="columns", inplace=True)

# %% [markdown]
# ##### Binneamos (cada 5 días)

# %%
#Creamos los bines, e introducimos una columna nueva con el bin correspondiente a cada tiempo.
Bin_Dias              = pd.cut(dfnn.DifEnDias, bins=np.arange(dfnn.DifEnDias.min(), dfnn.DifEnDias.max()+5, 5), right=False)
dfnn['Bin_Diff_Dias'] = Bin_Dias

# %%
#Vemos resultados
Dias_Binneado  = pd.DataFrame(Bin_Dias).stb.freq(['DifEnDias'], style=True, sort_cols=True)
display_side_by_side('Resumen','Dias_Binneado')
# Out:
# Resumen
# DifEnDías        Todos    Atendidos  Ausentes
# count      1,336,277.0  1,140,632.0  195,645.0
# mean              10.3          9.8       13.0
# std               11.0         10.9       10.8
# min                0.0          0.0        0.0
# 25%                1.0          0.0        5.0
# 50%                7.0          6.0       10.0
# 75%               16.0         15.0       20.0
# max               64.0         64.0       64.0
#
# Dias_Binneado
# ...

# %%
plt.figure(figsize=(20,15))
grid = plt.GridSpec(3, 2, wspace=0.4, hspace=0.3)
plt.suptitle('Diferencia en Días entre Turno y Otorgado', y=0.93, fontsize=20)
mini = dfnn.DifEnDias.min()
maxi = dfnn.DifEnDias.max()

ax1 = plt.subplot(grid[0,0])
sns.boxplot(data=dfnn, x='DifEnDias', color=BLUE)
plt.ylabel('Todos')

ax2 = plt.subplot(grid[0,1])
plt.title('Ancho de bin = 5 días', fontsize=13)
sns.distplot(dfnn.DifEnDias, kde=False, norm_hist=True, bins=np.arange(mini, maxi+5, 5),
             color=BLUE, label='Todos', hist_kws={"alpha": 0.8})
plt.legend()

ax3 = plt.subplot(grid[1,0])
sns.boxplot(data=dfnn[Ausentes | Atendidos], y='EstadoDelTurno', x='DifEnDias', palette=[RED, ORANGE])
plt.ylabel('')

ax4 = plt.subplot(grid[1,1])
plt.title('Ancho de bin = 1 día', fontsize=13)
sns.distplot(dfnn.DifEnDias[Atendidos], kde=True, norm_hist=True, bins=dfnn.DifEnDias[Atendidos].max(), color=RED, label='Atendidos', 
             kde_kws={"lw": 3.5} ,hist_kws={"alpha": 0.25, "linewidth": 2})
sns.distplot(dfnn.DifEnDias[Ausentes] , kde=True, norm_hist=True, bins=dfnn.DifEnDias[Ausentes].max(), color=ORANGE, label='Ausentes', 
             kde_kws={"lw": 3.5} ,hist_kws={"alpha": 0.25, "linewidth": 2})
plt.legend()

ax5 = plt.subplot(grid[2,0:])
Ausentismo = dfnn.DifEnDias[Ausentes].value_counts().div(dfnn.DifEnDias[Atendidos].value_counts())
Ausentismo.plot.bar(color=GREEN, label='Ausentismo')
plt.xlabel('Diferencia en Días')
plt.xticks(np.arange(mini, maxi+5, 5), np.arange(mini, maxi+5, 5), rotation=0)
plt.legend()

plt.setp([ax2, ax4, ax5], ylabel='Frecuencia')
plt.setp([ax1, ax2, ax3, ax4], xlabel='', xlim=[mini - 0.5, + maxi + 0.5])
plt.setp([ax1, ax3], xticks=np.arange(mini, maxi + 5, 5))


plt.show()
# Out:
# /home/egianuzzi/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/egianuzzi/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# #### Estación _meteorológica_ del año

# %%
#Basado en https://www.tiempo.com/ram/361562/las-estaciones-meteorologicas-difieren-las-estaciones-astronomicas/
#Añadimos la columa de diferencia temporal (en días)
dfnn['EstaciMeteor'] = ((dfnn.FechaDelTurno.dt.month%12 + 3)//3).replace({1: 'Verano', 2: 'Otoño', 3: 'Invierno', 4: 'Primavera'})
OrderEM = ['Verano', 'Otoño', 'Invierno', 'Primavera']

# %%
#Generamos las tablas
Tot, Dif                = Tablas(dfnn, 'EstaciMeteor', order=OrderEM)
Diferenciado            = Dif.copy()
Total                   = Tot.copy()
Diferenciado.Porcentaje = Dif.Porcentaje.apply(Porcent)
Total.Porcentaje        = Total.Porcentaje.apply(Porcent)
Total.Porcent_Acumu     = Total.Porcent_Acumu.apply(Porcent)
display_side_by_side("Diferenciado", "Total")
# Out:
# Diferenciado
#                              Cantidad Porcentaje
# EstaciMeteor EstadoDelTurno
# Verano       Atendido          254012     85.94%
#              Ausente            41561     14.06%
# Otoño        Atendido          265931     84.78%
#              Ausente            47737     15.22%
# Invierno     Atendido          299841     85.35%
#              Ausente            51448     14.65%
# Primavera    Atendido          320848     85.39%
#              Ausente            54899     14.61%
#
# Total
#               Cantidad Porcentaje  Cant_Acum Porcent_Acumu  Ausentismo
# EstaciMeteor
# Verano          295573     22.12%     295573        22.12%    0.163618
# Otoño           313668     23.47%     609241        45.59%    0.179509
# Invierno        351289     26.29%     960530        71.88%    0.171584
# Primavera       375747     28.12%    1336277       100.00%    0.171106

# %%
#Ploteamos
Ploteo(Tot, Dif, 'Estación Climática', order=OrderEM)

# %% [markdown]
# ---

# %% [markdown]
# ### Clima
#
# Nos quedaremos con las columnas que utilizaremos: **Temperatura Media** _(Tmed)_, **Precipitaciones** _(Prec_mm)_

# %%
#Nos deshacemos de las columnas climáticas que no utilizamos
print('Tamaño df: %.2f GB' %(dfnn.memory_usage(deep=False).sum()*1e-9))
To_Erase = ['HrMed_Por', 'NubTotOct', 'NubbajOct', 'PresNivMar_Hp', 'TDMed_C', 'Tmax', 'Tmin', 'Dir', 'Rch', 'Vel', 'Vis_Km']
dfnn.drop(columns=To_Erase, inplace=True)
print('Columnas borradas:', To_Erase)
print('Tamaño df: %.2f GB' %(dfnn.memory_usage(deep=False).sum()*1e-9))
# Out:
# Tamaño df: 0.41 GB
# Columnas borradas: ['HrMed_Por', 'NubTotOct', 'NubbajOct', 'PresNivMar_Hp', 'TDMed_C', 'Tmax', 'Tmin', 'Dir', 'Rch', 'Vel', 'Vis_Km']
# Tamaño df: 0.29 GB

# %% [markdown]
# #### Lluvia

# %%
#Añadimos la columna de cantidad de precipitación (LLuvia)
## Criterio https://es.wikipedia.org/wiki/Lluvia
dfnn['Lluvia'] = ''
dfnn.loc[dfnn.Prec_mm <= 0.04,                        'Lluvia'] = 'Nula'
dfnn.loc[(0.04 < dfnn.Prec_mm) & (dfnn.Prec_mm <= 2), 'Lluvia'] = 'Débil' #0.05 == Imperceptible
dfnn.loc[(2  < dfnn.Prec_mm) & (dfnn.Prec_mm <= 15) , 'Lluvia'] = 'Moderada'
dfnn.loc[(15 < dfnn.Prec_mm) & (dfnn.Prec_mm <= 30) , 'Lluvia'] = 'Fuerte'
dfnn.loc[(30 < dfnn.Prec_mm) & (dfnn.Prec_mm <= 60) , 'Lluvia'] = 'Muy fuerte'
dfnn.loc[60 < dfnn.Prec_mm,                           'Lluvia'] = 'Torrencial'
dfnn.loc[dfnn.Prec_mm.isnull(),                       'Lluvia'] = 'Indefinida'
OrderL = ['Nula','Débil', 'Moderada', 'Fuerte', 'Muy fuerte', 'Torrencial', 'Indefinida']

# %%
#Generamos las tablas
Tot, Dif                = Tablas(dfnn, 'Lluvia', order=OrderL)
Diferenciado            = Dif.copy()
Total                   = Tot.copy()
Diferenciado.Porcentaje = Dif.Porcentaje.apply(Porcent)
Total.Porcentaje        = Total.Porcentaje.apply(Porcent)
Total.Porcent_Acumu     = Total.Porcent_Acumu.apply(Porcent)
display_side_by_side("Diferenciado", "Total")
# Out:
# Diferenciado
#                            Cantidad Porcentaje
# Lluvia     EstadoDelTurno
# Nula       Atendido          770472     85.50%
#            Ausente           130648     14.50%
# Débil      Atendido          215100     85.18%
#            Ausente            37429     14.82%
# Moderada   Atendido           83236     85.10%
#            Ausente            14579     14.90%
# Fuerte     Atendido           46745     84.42%
#            Ausente             8628     15.58%
# Muy fuerte Atendido            9586     85.64%
#            Ausente             1607     14.36%
# Torrencial Atendido            5599     84.55%
#            Ausente             1023     15.45%
# Indefinida Atendido            9894     85.11%
#            Ausente             1731     14.89%
#
# Total
#             Cantidad Porcentaje  Cant_Acum Porcent_Acumu  Ausentismo
# Lluvia
# Nula          901120     67.44%     901120        67.44%    0.169569
# ...

# %%
#Ploteamos
Ploteo(Tot, Dif, h=True, order=OrderL)

# %% [markdown]
# #### Temperatura

# %%
#Añadimos la columna de cantidad de precipitación (Temperatura)
dfnn['Temperatura'] = ''
dfnn.loc[dfnn.Tmed <= 8,                       'Temperatura'] = 'Muy frío'
dfnn.loc[(8  < dfnn.Tmed) & (dfnn.Tmed <= 13), 'Temperatura'] = 'Frío'
dfnn.loc[(13 < dfnn.Tmed) & (dfnn.Tmed <= 21), 'Temperatura'] = 'Templado'
dfnn.loc[(21 < dfnn.Tmed) & (dfnn.Tmed <= 26), 'Temperatura'] = 'Caluroso'
dfnn.loc[26 < dfnn.Tmed,                       'Temperatura'] = 'Muy caluroso'
OrderT =['Muy frío', 'Frío', 'Templado', 'Caluroso', 'Muy caluroso']

# %%
#Generamos las tablas
Tot, Dif                = Tablas(dfnn, 'Temperatura', order=OrderT)
Diferenciado            = Dif.copy()
Total                   = Tot.copy()
Diferenciado.Porcentaje = Dif.Porcentaje.apply(Porcent)
Total.Porcentaje        = Total.Porcentaje.apply(Porcent)
Total.Porcent_Acumu     = Total.Porcent_Acumu.apply(Porcent)
display_side_by_side("Diferenciado", "Total")
# Out:
# Diferenciado
#                              Cantidad Porcentaje
# Temperatura  EstadoDelTurno
# Muy frío     Atendido          102682     85.25%
#              Ausente            17773     14.75%
# Frío         Atendido          194284     84.99%
#              Ausente            34323     15.01%
# Templado     Atendido          524634     85.37%
#              Ausente            89921     14.63%
# Caluroso     Atendido          273481     85.66%
#              Ausente            45779     14.34%
# Muy caluroso Atendido           45551     85.30%
#              Ausente             7849     14.70%
#
# Total
#               Cantidad Porcentaje  Cant_Acum Porcent_Acumu  Ausentismo
# Temperatura
# Muy frío        120455      9.01%     120455         9.01%    0.173088
# Frío            228607     17.11%     349062        26.12%    0.176664
# Templado        614555     45.99%     963617        72.11%    0.171398
# Caluroso        319260     23.89%    1282877        96.00%    0.167394
# ...

# %%
#Ploteamos
Ploteo(Tot, Dif, order=OrderT)

# %%
del Agrupaciones, Ausentismo, Dif, Diferenciado, Guardia, Nuevo, Old
del OrderDS, OrderEM, OrderL, OrderMD, OrderT, Pacientes, To_Erase, Total

# %% [markdown]
# ---

# %% [markdown]
# ### Edad

# %%
print('La edad introducida a los turnos sin paciente es de: %i años' %df[df.HC.isnull()].Edad.unique())
# Out:
# La edad introducida a los turnos sin paciente es de: 0 años

# %%
print('Resumen')
Edad_des              = pd.DataFrame(dfnn.Edad.rename('Todos').describe().map("{:,.1f}".format))
Edad_des['Atendidos'] = pd.DataFrame(dfnn[Atendidos].Edad.describe().map("{:,.1f}".format))
Edad_des['Ausentes '] = pd.DataFrame(dfnn[Ausentes ].Edad.describe().map("{:,.1f}".format))
display(Edad_des.rename_axis("Edad", axis="columns"))
# Out:
# Resumen
# Edad         Todos    Atendidos  Ausentes
# count  1,336,277.0  1,140,632.0  195,645.0
# mean          35.4         35.6       33.8
# std           21.4         21.7       19.5
# min            0.0          0.0        0.0
# 25%           19.0         19.0       21.0
# 50%           35.0         36.0       34.0
# 75%           49.0         50.0       45.0
# max          120.0        120.0      120.0

# %%
#Eliminamos las entradas de pacientes de 120 años
dfnn.drop(dfnn[dfnn.Edad == 120].index, inplace=True)

#Rehacemos las máscaras de Atendios y Ausentes
Ausentes  = dfnn.EstadoDelTurno == 'Ausente'
Atendidos = dfnn.EstadoDelTurno == 'Atendido'

# %% [markdown]
# #### Binneamos (cada 10 años)

# %%
#Actualizamos el resumen
Resumen_Actualizado = pd.DataFrame(dfnn.Edad.rename('Todos').describe().map("{:,.1f}".format))
Resumen_Actualizado['Atendidos'] = pd.DataFrame(dfnn[Atendidos].Edad.describe().map("{:,.1f}".format))
Resumen_Actualizado['Ausentes '] = pd.DataFrame(dfnn[Ausentes ].Edad.describe().map("{:,.1f}".format))
Resumen_Actualizado.rename_axis("Edad", axis="columns", inplace=True)

#Creamos los bines, e introducimos una columna nueva con el bin correspondiente a cada edad.
Bin_Edad = pd.cut(dfnn.Edad, bins=np.arange(dfnn.Edad.min(), dfnn.Edad.max()+10, 10), right=False)
dfnn['Bin_Edad'] = Bin_Edad

#Vemos resultados
Edad_Binneado  = pd.DataFrame(Bin_Edad).stb.freq(['Edad'], style=True, sort_cols=True)
display_side_by_side('Resumen_Actualizado','Edad_Binneado')
# Out:
# Resumen_Actualizado
# Edad         Todos    Atendidos  Ausentes
# count  1,335,652.0  1,140,244.0  195,408.0
# mean          35.3         35.6       33.7
# std           21.4         21.7       19.3
# min            0.0          0.0        0.0
# 25%           19.0         19.0       21.0
# 50%           35.0         36.0       34.0
# 75%           49.0         50.0       45.0
# max          102.0        102.0       99.0
#
# Edad_Binneado
# ...

# %%
plt.figure(figsize=(20,15))
grid = plt.GridSpec(3, 2, wspace=0.4, hspace=0.3)
plt.suptitle('Edad', y=0.93, fontsize=20)
mini = dfnn.Edad.min()
maxi = dfnn.Edad.max()

ax1 = plt.subplot(grid[0,0])
sns.boxplot(data=dfnn, x='Edad', color=BLUE)
plt.ylabel('Todos')

ax2 = plt.subplot(grid[0,1])
plt.title('Ancho de bin = 10 años', fontsize=13)
x = np.linspace(norm.ppf(0.001, loc=dfnn.Edad.mean(), scale=dfnn.Edad.std()),
                norm.ppf(0.999, loc=dfnn.Edad.mean(), scale=dfnn.Edad.std()), 100)
sns.distplot(dfnn.Edad, kde=False, norm_hist=True, bins=np.arange(mini, maxi+10, 10),
             color=BLUE, label='Todos', hist_kws={"alpha": 0.8})
plt.plot(x, norm.pdf(x, loc=dfnn.Edad.mean(), scale=dfnn.Edad.std()), 'k-', lw=5, alpha=0.8, label='Distribución Normal')
plt.legend()

ax3 = plt.subplot(grid[1,0])
sns.boxplot(data=dfnn[Ausentes | Atendidos], y='EstadoDelTurno', x='Edad', palette=[RED, ORANGE])
plt.ylabel('')

ax4 = plt.subplot(grid[1,1])
plt.title('Ancho de bin = 1 año', fontsize=13)
sns.distplot(dfnn.Edad[Atendidos], kde=True, norm_hist=True, bins=dfnn.Edad[Atendidos].max(), color=RED, label='Atendidos', 
             kde_kws={"lw": 3.5} ,hist_kws={"alpha": 0.25, "linewidth": 2})
sns.distplot(dfnn.Edad[Ausentes] , kde=True, norm_hist=True, bins=dfnn.Edad[Ausentes].max(), color=ORANGE, label='Ausentes', 
             kde_kws={"lw": 3.5} ,hist_kws={"alpha": 0.25, "linewidth": 2})
plt.legend()

ax5 = plt.subplot(grid[2,0:])
Ausentismo = dfnn.Edad[Ausentes].value_counts().div(dfnn.Edad[Atendidos].value_counts())
Ausentismo.plot.bar(color=GREEN, label='Ausentismo')
plt.xticks(np.arange(mini, maxi, 5), np.arange(mini, maxi, 5), rotation=0)
plt.xlabel('Edad')
plt.legend()

plt.setp([ax2, ax4, ax5], ylabel='Frecuencia')
plt.setp([ax1, ax2, ax3, ax4], xlabel='', xlim=[mini - 0.5, + maxi + 0.5])
plt.setp([ax1, ax3], xticks=np.arange(mini, maxi + 10, 10))


plt.show()
# Out:
# /home/egianuzzi/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/egianuzzi/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
#Borramos innecesarios
del Ausentismo, ax1, ax2, ax3, ax4, ax5, Bin_Edad, Bin_Dias, Edad_Binneado, Dias_Binneado, Edad_des, grid, Resumen_Actualizado, x, mini, maxi

# %%
Memory()
# Out:
# Memoria actual utilizada: 1.54 GB

# %% [markdown]
# ---

# %% [markdown]
# ### HC

# %%
#Localizamos las historias clínicas con edades variables.
ValMal  = dfnn[['HC', 'Edad']].groupby('HC').nunique()['Edad'] != 1
Errores = ValMal[ValMal].index
print('Índice de Historias Cínicas con errores de edades:', Errores.to_list())
print('En total, son %i entradas (%.3f%%)' %(dfnn.HC.isin(ValMal[ValMal].index).sum(), dfnn.HC.isin(ValMal[ValMal].index).sum()*100/len(dfnn)))

#Les pegamos un vistazo
Valores = dfnn[dfnn.HC.isin(Errores)][['HC','Edad']].sort_values(['HC', 'Edad'])
Resumen = dfnn[['HC','Edad', 'Index_df']][dfnn.HC.isin(Errores)].groupby(['HC','Edad']).count().rename(columns={'Index_df': 'Cantidad'})
display_side_by_side('Valores', 'Resumen')
# Out:
# Índice de Historias Cínicas con errores de edades: [92377, 99204, 122097]
# En total, son 33 entradas (0.002%)
# Valores
#              HC  Edad
# 492036    92377    26
# 425694    92377    43
# 484666    99204     1
# 492813    99204     1
# 492954    99204     1
# ...         ...   ...
# 1057323  122097     1
# 1290113  122097     1
# 1351370  122097     1
# 723940   122097    17
# 859266   122097    17
#
# [33 rows x 2 columns]
#
# Resumen
#              Cantidad
# HC     Edad
# 92377  26           1
#        43           1
# 99204  1            7
#        73           7
# 122097 1           15
#        17           2

# %%
#Al ser pocas, serán eliminadas
dfnn.drop(dfnn[dfnn.HC.isin(Errores)].index, inplace=True)

# %%
#Borramos innecesarios
del ValMal, Errores, Valores, Resumen

# %%
Memory()
# Out:
# Memoria actual utilizada: 1.54 GB

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Despersonalización de campos sensibles

# %% [markdown]
# ## HC y Recurso

# %%
#Despersonalizamos HC y Recurso
dfnn['HC2']      = dfnn.HC.astype(str).apply(hashit)
dfnn['Recurso2'] = dfnn.Recurso.astype(str).apply(hashit)

# %%
display(dfnn[['HC', 'HC2', 'Recurso', 'Recurso2']].sample(5))
# Out:
#             HC                               HC2  Recurso  \
# 607611   37461  e2a06284900590e8df25361db42caede      466
# 193904   60533  ae44f78fa4792bb0549224afdd4d6152      301
# 851272    9900  8af95fe2ab1a54b488ef8efb3f3b0797      255
# 1178456   5933  a5d42e4024cc540befb48f466820e25f      353
# 1337099  75823  400abdeb764023f3dcb8b0a23b279f08      213
#
#                                  Recurso2
# 607611   e836d813fd184325132fca8edcdfb40e
# 193904   34ed066df378efacc9b924ec161e7639
# 851272   fe131d7f5a6b38b23cc967316c13dae2
# 1178456  138bb0696595b338afbab333c555292a
# 1337099  979d472a84804b9f647bc185a877a8b5

# %%
Memory()
# Out:
# Memoria actual utilizada: 1.82 GB

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Aesthetic

# %% [markdown]
# ## Índice

# %%
#Resetemos el índice
dfnn.reset_index(inplace=True)
dfnn.drop(columns='index', inplace=True)

# %% [markdown]
# ## Columnas

# %%
# Reacomodamos posiciones de las columnas
dfnn = dfnn[['Index_df', 'CentroDeAtencion', 'Prestador', 'PrestadorAgrupado', 'Servicio', 'ServicioAgrupado', 'EstadoDelTurno',
             'Sexo', 'Edad',  'Bin_Edad', 'HC', 'HC2', 'TipoDeTurnoAsignado', 'PrestacionAsignada', 'PrestacionAgrupado',
             'Localidad', 'Provincia', 'NombreDelCanal', 'EsSobreTurno', 'FechaDelTurno', 'FechaDeOtorgado', 'DifEnDias',
             'Bin_Diff_Dias', 'DiaSemanal', 'MomDelDia',  'EstaciMeteor', 'Prec_mm', 'Lluvia', 'Tmed', 'Temperatura','Recurso', 'Recurso2']]
#Vemos el orden
print('Columnas finales:', dfnn.columns)
# Out:
# Columnas finales: Index(['Index_df', 'CentroDeAtencion', 'Prestador', 'PrestadorAgrupado',
#        'Servicio', 'ServicioAgrupado', 'EstadoDelTurno', 'Sexo', 'Edad',
#        'Bin_Edad', 'HC', 'HC2', 'TipoDeTurnoAsignado', 'PrestacionAsignada',
#        'PrestacionAgrupado', 'Localidad', 'Provincia', 'NombreDelCanal',
#        'EsSobreTurno', 'FechaDelTurno', 'FechaDeOtorgado', 'DifEnDias',
#        'Bin_Diff_Dias', 'DiaSemanal', 'MomDelDia', 'EstaciMeteor', 'Prec_mm',
#        'Lluvia', 'Tmed', 'Temperatura', 'Recurso', 'Recurso2'],
#       dtype='object')

# %%
#Una muestra
display(dfnn.sample(5))
# Out:
#          Index_df  CentroDeAtencion                 Prestador  \
# 42235       93476                 1        SWISS MEDICAL S.A.
# 1015394   1977431                 2        SWISS MEDICAL S.A.
# 1151139   2219131                 1                     DASPU
# 1092345   2117185                 1  OMINT S. A. DE SERVICIOS
# 545853    1071282                 1                     IOSFA
#
#                 PrestadorAgrupado              Servicio      ServicioAgrupado  \
# 42235          SWISS MEDICAL S.A.          NEONATOLOGÍA                  OTRO
# 1015394        SWISS MEDICAL S.A.        ENDOCRINOLOGÍA                  OTRO
# 1151139                     DASPU        CLÍNICA MÉDICA        CLINICA MEDICA
# 1092345  OMINT S. A. DE SERVICIOS        CLÍNICA MÉDICA        CLINICA MEDICA
# 545853                      IOSFA  GINECO Y OBSTETRICIA  GINECO Y OBSTETRICIA
#
#         EstadoDelTurno Sexo  Edad  Bin_Edad      HC  \
# 42235         Atendido    M     2   [0, 10)   23290
# ...

# %% [markdown]
# ## Tipos

# %%
#Descomente el bloque de aquí abajo para cambiar los tipos de las columnas (posibles) a 'category'.
#----------------------
print('Tamaño df antes del cambio: %.2f GB' %(dfnn.memory_usage(deep=False).sum()*1e-9))
To_category = ['CentroDeAtencion', 'PrestadorAgrupado', 'ServicioAgrupado', 'EstadoDelTurno', 'Sexo', 'Bin_Edad', 'TipoDeTurnoAsignado', 'PrestacionAgrupado',
             'Localidad', 'Provincia', 'NombreDelCanal', 'EsSobreTurno', 'Bin_Diff_Dias', 'DiaSemanal', 'MomDelDia',  'EstaciMeteor', 'Lluvia', 'Temperatura']
for cambio in To_category:
    dfnn[cambio] = dfnn[cambio].astype('category')
print('Tamaño df luego del cambio: %.2f GB' %(dfnn.memory_usage(deep=False).sum()*1e-9))
#----------------------

#Descomente el bloque de aquí abajo para cambiar los tipos de las columnas (posibles) a 'int32'.
#----------------------
print('Tamaño df antes del cambio: %.2f GB' %(dfnn.memory_usage(deep=False).sum()*1e-9))
To_int32 = ['Index_df', 'Edad', 'HC', 'DifEnDias', 'Tmed', 'Recurso']
for cambio in To_int32:
    dfnn[cambio] = dfnn[cambio].astype('int32')
print('Tamaño df luego del cambio: %.2f GB' %(dfnn.memory_usage(deep=False).sum()*1e-9))
#----------------------
# Out:
# Tamaño df antes del cambio: 0.32 GB
# Tamaño df luego del cambio: 0.17 GB
# Tamaño df antes del cambio: 0.17 GB
# Tamaño df luego del cambio: 0.14 GB

# %%
#Detalles por tipo
print('Numéricas')
display(dfnn.describe(include='number'))
print('Objetos')
display(dfnn.describe(include='object'))
print('Categorías')
display(dfnn.describe(include='category'))
print('Fechas')
display(dfnn.describe(include='datetime'))
# Out:
# Numéricas
#            Index_df          Edad            HC     DifEnDias       Prec_mm  \
# count  1.335619e+06  1.335619e+06  1.335619e+06  1.335619e+06  1.324004e+06
# mean   1.303472e+06  3.533331e+01  6.076298e+04  1.030860e+01  2.313934e+00
# std    7.372835e+05  2.135533e+01  4.607821e+04  1.098087e+01  9.048073e+00
# min    5.790000e+02  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    6.646375e+05  1.900000e+01  2.032800e+04  1.000000e+00  0.000000e+00
# 50%    1.311590e+06  3.500000e+01  5.138900e+04  7.000000e+00  0.000000e+00
# 75%    1.952762e+06  4.900000e+01  9.508400e+04  1.600000e+01  5.000000e-02
# max    2.556142e+06  1.020000e+02  1.694880e+05  6.400000e+01  1.300000e+02
#
#                Tmed       Recurso
# count  1.335619e+06  1.335619e+06
# mean   1.651549e+01  2.778862e+02
# std    5.899190e+00  1.549370e+02
# min    0.000000e+00  0.000000e+00
# 25%    1.200000e+01  1.440000e+02
# 50%    1.700000e+01  2.680000e+02
# ...

# %%
Memory()
# Out:
# Memoria actual utilizada: 1.59 GB

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Test de Integridad FINAL

# %%
test_integridad(dfnn)
# Out:
# Ejecutando tests de Integridad
# Test Estado del Turno : EXITOSO
# Test Edad             : ERROR
# Test Sexo             : EXITOSO
# Test Provincia        : EXITOSO
# Test Localidad        : EXITOSO
# Test Nombre del Canal : EXITOSO
# Test Prestador        : EXITOSO
# Test Servicio         : EXITOSO
# Test Prestación       : EXITOSO
# Test Fecha de Turno   : EXITOSO
# Test Fecha de Otorgado: EXITOSO
# Test Tipo de Turno    : EXITOSO

# %%
Memory()
# Out:
# Memoria actual utilizada: 1.59 GB

# %% [markdown]
# ## Edad (Excepción)

# %%
display(pd.DataFrame(Outliers(dfnn, 'Edad', outl_only=True, verbose=True).Edad.value_counts()
            ).rename(columns={'Edad': 'Cantidad'}).rename_axis('Edad'))
# Out:
# Cantidad de Outliers en Edad : 27 (0.0020%)
#       Cantidad
# Edad
# 102         23
# 100          4

# %% [markdown]
# Al tratarse de edades posiblemente reales, y de poca cantidad, **no** se eliminan estos Outliers del dataset.

# %% [markdown]
# # Guardado

# %%
if not in_colab:
    name  = 'dataset_curado.csv'
    dfnn.to_csv(name, index=False)
    from zipfile import ZipFile, ZIP_DEFLATED
    zname = name[:-3]+'zip'
    with ZipFile(zname, 'w', ZIP_DEFLATED) as zf:
        zf.write(name)
    os.rename(os.path.join(os.getcwd(), zname), os.path.join(data_dir, zname))
    os.remove(name) 
    print('Dataset guardado en {}'.format(os.path.join(data_dir, zname)))
# Out:
# Dataset guardado en /home/egianuzzi/Documentos/Git/DiploDatos2020/Ausentismo-DD2020-Final/Notebooks/Analisis_y_Curacion/../../data/dataset_curado.zip
