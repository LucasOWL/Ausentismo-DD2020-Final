# %% [markdown]
# <a href="https://colab.research.google.com/github/Gianuzzi/Ausentismo-DD2020-Final/blob/master/Notebooks/Aprendizaje_Automatico/Practico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Práctico-de-Introducción-a-Machine-Learning" data-toc-modified-id="Práctico-de-Introducción-a-Machine-Learning-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Práctico de Introducción a Machine Learning</a></span><ul class="toc-item"><li><span><a href="#Preprocesamiento" data-toc-modified-id="Preprocesamiento-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Preprocesamiento</a></span></li><li><span><a href="#Elección-de-los-modelos" data-toc-modified-id="Elección-de-los-modelos-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Elección de los modelos</a></span></li><li><span><a href="#Elección-de-métricas" data-toc-modified-id="Elección-de-métricas-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Elección de métricas</a></span></li></ul></li><li><span><a href="#Importaciones" data-toc-modified-id="Importaciones-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Importaciones</a></span><ul class="toc-item"><li><span><a href="#Librerías" data-toc-modified-id="Librerías-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Librerías</a></span></li><li><span><a href="#Funciones" data-toc-modified-id="Funciones-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Funciones</a></span></li><li><span><a href="#Dataset" data-toc-modified-id="Dataset-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Dataset</a></span></li></ul></li><li><span><a href="#Pre--Estudio" data-toc-modified-id="Pre--Estudio-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Pre- Estudio</a></span><ul class="toc-item"><li><span><a href="#Análisis" data-toc-modified-id="Análisis-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Análisis</a></span><ul class="toc-item"><li><span><a href="#Nulos" data-toc-modified-id="Nulos-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Nulos</a></span></li><li><span><a href="#Menores-de-Edad-(18)" data-toc-modified-id="Menores-de-Edad-(18)-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Menores de Edad (18)</a></span></li><li><span><a href="#Domingos" data-toc-modified-id="Domingos-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Domingos</a></span></li><li><span><a href="#Sexo" data-toc-modified-id="Sexo-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Sexo</a></span></li><li><span><a href="#GUARDIA" data-toc-modified-id="GUARDIA-3.1.5"><span class="toc-item-num">3.1.5&nbsp;&nbsp;</span>GUARDIA</a></span></li><li><span><a href="#Pedriatría-y-Servicios-Infantiles" data-toc-modified-id="Pedriatría-y-Servicios-Infantiles-3.1.6"><span class="toc-item-num">3.1.6&nbsp;&nbsp;</span>Pedriatría y Servicios Infantiles</a></span></li><li><span><a href="#Centros-de-Atención-5-y-6" data-toc-modified-id="Centros-de-Atención-5-y-6-3.1.7"><span class="toc-item-num">3.1.7&nbsp;&nbsp;</span>Centros de Atención 5 y 6</a></span></li></ul></li><li><span><a href="#Curación-de-filas" data-toc-modified-id="Curación-de-filas-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Curación de filas</a></span><ul class="toc-item"><li><span><a href="#Edad-(Revisión)" data-toc-modified-id="Edad-(Revisión)-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Edad (Revisión)</a></span></li><li><span><a href="#Domingo-(Revisión)" data-toc-modified-id="Domingo-(Revisión)-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Domingo (Revisión)</a></span></li><li><span><a href="#Sexo-(Revisón)" data-toc-modified-id="Sexo-(Revisón)-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Sexo (Revisón)</a></span></li><li><span><a href="#Sobre-Turno-(Revisón)" data-toc-modified-id="Sobre-Turno-(Revisón)-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Sobre Turno (Revisón)</a></span></li><li><span><a href="#Guardia-e-INF-(Revisión-Servicio)" data-toc-modified-id="Guardia-e-INF-(Revisión-Servicio)-3.2.5"><span class="toc-item-num">3.2.5&nbsp;&nbsp;</span>Guardia e INF (Revisión Servicio)</a></span></li><li><span><a href="#Pediatría-(Revisión-Prestación)" data-toc-modified-id="Pediatría-(Revisión-Prestación)-3.2.6"><span class="toc-item-num">3.2.6&nbsp;&nbsp;</span>Pediatría (Revisión Prestación)</a></span></li><li><span><a href="#Centros-de-Atención-(Revisión)" data-toc-modified-id="Centros-de-Atención-(Revisión)-3.2.7"><span class="toc-item-num">3.2.7&nbsp;&nbsp;</span>Centros de Atención (Revisión)</a></span></li></ul></li><li><span><a href="#Features-Nuevos" data-toc-modified-id="Features-Nuevos-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Features Nuevos</a></span><ul class="toc-item"><li><span><a href="#Mes" data-toc-modified-id="Mes-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Mes</a></span></li><li><span><a href="#Consulta-y-Particular" data-toc-modified-id="Consulta-y-Particular-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Consulta y Particular</a></span></li></ul></li><li><span><a href="#Curación-de-Columnas" data-toc-modified-id="Curación-de-Columnas-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Curación de Columnas</a></span><ul class="toc-item"><li><span><a href="#Nulos" data-toc-modified-id="Nulos-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Nulos</a></span><ul class="toc-item"><li><span><a href="#Localidad-y-Provincia" data-toc-modified-id="Localidad-y-Provincia-3.4.1.1"><span class="toc-item-num">3.4.1.1&nbsp;&nbsp;</span>Localidad y Provincia</a></span></li><li><span><a href="#Nombre-del-Canal" data-toc-modified-id="Nombre-del-Canal-3.4.1.2"><span class="toc-item-num">3.4.1.2&nbsp;&nbsp;</span>Nombre del Canal</a></span></li></ul></li><li><span><a href="#Extras" data-toc-modified-id="Extras-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Extras</a></span></li></ul></li><li><span><a href="#Clasificación-y-Edición-de-columnas" data-toc-modified-id="Clasificación-y-Edición-de-columnas-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Clasificación y Edición de columnas</a></span><ul class="toc-item"><li><span><a href="#Binarizado-(Binarias)" data-toc-modified-id="Binarizado-(Binarias)-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Binarizado (Binarias)</a></span></li><li><span><a href="#Hot-Encoding--(Categorical)" data-toc-modified-id="Hot-Encoding--(Categorical)-3.5.2"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>Hot Encoding  (Categorical)</a></span></li><li><span><a href="#Scaling-(Numerical)" data-toc-modified-id="Scaling-(Numerical)-3.5.3"><span class="toc-item-num">3.5.3&nbsp;&nbsp;</span>Scaling (Numerical)</a></span><ul class="toc-item"><li><span><a href="#Standard-Scaler" data-toc-modified-id="Standard-Scaler-3.5.3.1"><span class="toc-item-num">3.5.3.1&nbsp;&nbsp;</span>Standard Scaler</a></span></li><li><span><a href="#MinMax-Scaler" data-toc-modified-id="MinMax-Scaler-3.5.3.2"><span class="toc-item-num">3.5.3.2&nbsp;&nbsp;</span>MinMax Scaler</a></span></li></ul></li></ul></li><li><span><a href="#Formato-y-Memoria" data-toc-modified-id="Formato-y-Memoria-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Formato y Memoria</a></span></li><li><span><a href="#Guardado" data-toc-modified-id="Guardado-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Guardado</a></span></li></ul></li><li><span><a href="#Estudio" data-toc-modified-id="Estudio-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Estudio</a></span><ul class="toc-item"><li><span><a href="#División-entre-conjunto-de-entrenamiento-y-de-evaluación" data-toc-modified-id="División-entre-conjunto-de-entrenamiento-y-de-evaluación-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>División entre conjunto de entrenamiento y de evaluación</a></span><ul class="toc-item"><li><span><a href="#Balance-Entrenamiento" data-toc-modified-id="Balance-Entrenamiento-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Balance Entrenamiento</a></span></li><li><span><a href="#Balance-Prueba" data-toc-modified-id="Balance-Prueba-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Balance Prueba</a></span></li><li><span><a href="#Balance-Total" data-toc-modified-id="Balance-Total-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Balance Total</a></span></li></ul></li><li><span><a href="#Entrenamiento-de-modelos-sin-hiperparámetros" data-toc-modified-id="Entrenamiento-de-modelos-sin-hiperparámetros-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Entrenamiento de modelos sin hiperparámetros</a></span><ul class="toc-item"><li><span><a href="#Sin-escalado" data-toc-modified-id="Sin-escalado-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Sin escalado</a></span><ul class="toc-item"><li><span><a href="#Decision-Tree" data-toc-modified-id="Decision-Tree-4.2.1.1"><span class="toc-item-num">4.2.1.1&nbsp;&nbsp;</span>Decision Tree</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-4.2.1.2"><span class="toc-item-num">4.2.1.2&nbsp;&nbsp;</span>Random Forest</a></span></li><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-4.2.1.3"><span class="toc-item-num">4.2.1.3&nbsp;&nbsp;</span>Logistic Regression</a></span></li><li><span><a href="#Gaussian-Naive-Bayes" data-toc-modified-id="Gaussian-Naive-Bayes-4.2.1.4"><span class="toc-item-num">4.2.1.4&nbsp;&nbsp;</span>Gaussian Naive Bayes</a></span></li><li><span><a href="#SGD-Classifier" data-toc-modified-id="SGD-Classifier-4.2.1.5"><span class="toc-item-num">4.2.1.5&nbsp;&nbsp;</span>SGD Classifier</a></span></li><li><span><a href="#Perceptron" data-toc-modified-id="Perceptron-4.2.1.6"><span class="toc-item-num">4.2.1.6&nbsp;&nbsp;</span>Perceptron</a></span></li><li><span><a href="#XGBoost" data-toc-modified-id="XGBoost-4.2.1.7"><span class="toc-item-num">4.2.1.7&nbsp;&nbsp;</span>XGBoost</a></span></li><li><span><a href="#Resumen-de-modelos-sin-hiperparámetros-(Sin-escalado)" data-toc-modified-id="Resumen-de-modelos-sin-hiperparámetros-(Sin-escalado)-4.2.1.8"><span class="toc-item-num">4.2.1.8&nbsp;&nbsp;</span>Resumen de modelos sin hiperparámetros (Sin escalado)</a></span></li></ul></li><li><span><a href="#Standard-Scaler" data-toc-modified-id="Standard-Scaler-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Standard Scaler</a></span><ul class="toc-item"><li><span><a href="#Decision-Tree" data-toc-modified-id="Decision-Tree-4.2.2.1"><span class="toc-item-num">4.2.2.1&nbsp;&nbsp;</span>Decision Tree</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-4.2.2.2"><span class="toc-item-num">4.2.2.2&nbsp;&nbsp;</span>Random Forest</a></span></li><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-4.2.2.3"><span class="toc-item-num">4.2.2.3&nbsp;&nbsp;</span>Logistic Regression</a></span></li><li><span><a href="#Gaussian-Naive-Bayes" data-toc-modified-id="Gaussian-Naive-Bayes-4.2.2.4"><span class="toc-item-num">4.2.2.4&nbsp;&nbsp;</span>Gaussian Naive Bayes</a></span></li><li><span><a href="#SGD-Classifier" data-toc-modified-id="SGD-Classifier-4.2.2.5"><span class="toc-item-num">4.2.2.5&nbsp;&nbsp;</span>SGD Classifier</a></span></li><li><span><a href="#Perceptron" data-toc-modified-id="Perceptron-4.2.2.6"><span class="toc-item-num">4.2.2.6&nbsp;&nbsp;</span>Perceptron</a></span></li><li><span><a href="#XGBoost" data-toc-modified-id="XGBoost-4.2.2.7"><span class="toc-item-num">4.2.2.7&nbsp;&nbsp;</span>XGBoost</a></span></li><li><span><a href="#Resumen-de-modelos-sin-hiperparámetros-(Standard-Scaler)" data-toc-modified-id="Resumen-de-modelos-sin-hiperparámetros-(Standard-Scaler)-4.2.2.8"><span class="toc-item-num">4.2.2.8&nbsp;&nbsp;</span>Resumen de modelos sin hiperparámetros (Standard Scaler)</a></span></li></ul></li><li><span><a href="#MinMax-Scaler" data-toc-modified-id="MinMax-Scaler-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>MinMax Scaler</a></span><ul class="toc-item"><li><span><a href="#Decision-Tree" data-toc-modified-id="Decision-Tree-4.2.3.1"><span class="toc-item-num">4.2.3.1&nbsp;&nbsp;</span>Decision Tree</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-4.2.3.2"><span class="toc-item-num">4.2.3.2&nbsp;&nbsp;</span>Random Forest</a></span></li><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-4.2.3.3"><span class="toc-item-num">4.2.3.3&nbsp;&nbsp;</span>Logistic Regression</a></span></li><li><span><a href="#Gaussian-Naive-Bayes" data-toc-modified-id="Gaussian-Naive-Bayes-4.2.3.4"><span class="toc-item-num">4.2.3.4&nbsp;&nbsp;</span>Gaussian Naive Bayes</a></span></li><li><span><a href="#SGD-Classifier" data-toc-modified-id="SGD-Classifier-4.2.3.5"><span class="toc-item-num">4.2.3.5&nbsp;&nbsp;</span>SGD Classifier</a></span></li><li><span><a href="#Perceptron" data-toc-modified-id="Perceptron-4.2.3.6"><span class="toc-item-num">4.2.3.6&nbsp;&nbsp;</span>Perceptron</a></span></li><li><span><a href="#XGBoost" data-toc-modified-id="XGBoost-4.2.3.7"><span class="toc-item-num">4.2.3.7&nbsp;&nbsp;</span>XGBoost</a></span></li><li><span><a href="#Resumen-de-modelos-sin-hiperparámetros-(MinMax-Scaler)" data-toc-modified-id="Resumen-de-modelos-sin-hiperparámetros-(MinMax-Scaler)-4.2.3.8"><span class="toc-item-num">4.2.3.8&nbsp;&nbsp;</span>Resumen de modelos sin hiperparámetros (MinMax Scaler)</a></span></li></ul></li></ul></li><li><span><a href="#Entrenamiento-de-modelos-con-hiperparámetros-variados" data-toc-modified-id="Entrenamiento-de-modelos-con-hiperparámetros-variados-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Entrenamiento de modelos con hiperparámetros variados</a></span><ul class="toc-item"><li><span><a href="#Sin-escalado" data-toc-modified-id="Sin-escalado-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Sin escalado</a></span><ul class="toc-item"><li><span><a href="#Decision-Tree-(Hyperparameter-tuning)" data-toc-modified-id="Decision-Tree-(Hyperparameter-tuning)-4.3.1.1"><span class="toc-item-num">4.3.1.1&nbsp;&nbsp;</span>Decision Tree (Hyperparameter tuning)</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-4.3.1.2"><span class="toc-item-num">4.3.1.2&nbsp;&nbsp;</span>Random Forest</a></span></li><li><span><a href="#XGBoost" data-toc-modified-id="XGBoost-4.3.1.3"><span class="toc-item-num">4.3.1.3&nbsp;&nbsp;</span>XGBoost</a></span></li><li><span><a href="#Resumen-de-modelos-con-hiperparámetros-(Sin-escalado)" data-toc-modified-id="Resumen-de-modelos-con-hiperparámetros-(Sin-escalado)-4.3.1.4"><span class="toc-item-num">4.3.1.4&nbsp;&nbsp;</span>Resumen de modelos con hiperparámetros (Sin escalado)</a></span></li></ul></li><li><span><a href="#Standard-Scaler" data-toc-modified-id="Standard-Scaler-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Standard Scaler</a></span><ul class="toc-item"><li><span><a href="#Decision-Tree-(Hyperparameter-tuning)" data-toc-modified-id="Decision-Tree-(Hyperparameter-tuning)-4.3.2.1"><span class="toc-item-num">4.3.2.1&nbsp;&nbsp;</span>Decision Tree (Hyperparameter tuning)</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-4.3.2.2"><span class="toc-item-num">4.3.2.2&nbsp;&nbsp;</span>Random Forest</a></span></li><li><span><a href="#XGBoost" data-toc-modified-id="XGBoost-4.3.2.3"><span class="toc-item-num">4.3.2.3&nbsp;&nbsp;</span>XGBoost</a></span></li><li><span><a href="#Resumen-de-modelos-con-hiperparámetros-(Standard-Scaler)" data-toc-modified-id="Resumen-de-modelos-con-hiperparámetros-(Standard-Scaler)-4.3.2.4"><span class="toc-item-num">4.3.2.4&nbsp;&nbsp;</span>Resumen de modelos con hiperparámetros (Standard Scaler)</a></span></li></ul></li><li><span><a href="#MinMax-Scaler" data-toc-modified-id="MinMax-Scaler-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>MinMax Scaler</a></span><ul class="toc-item"><li><span><a href="#Decision-Tree-(Hyperparameter-tuning)" data-toc-modified-id="Decision-Tree-(Hyperparameter-tuning)-4.3.3.1"><span class="toc-item-num">4.3.3.1&nbsp;&nbsp;</span>Decision Tree (Hyperparameter tuning)</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-4.3.3.2"><span class="toc-item-num">4.3.3.2&nbsp;&nbsp;</span>Random Forest</a></span></li><li><span><a href="#XGBoost" data-toc-modified-id="XGBoost-4.3.3.3"><span class="toc-item-num">4.3.3.3&nbsp;&nbsp;</span>XGBoost</a></span></li><li><span><a href="#Resumen-de-modelos-con-hiperparámetros-(MinMax-Scaler)" data-toc-modified-id="Resumen-de-modelos-con-hiperparámetros-(MinMax-Scaler)-4.3.3.4"><span class="toc-item-num">4.3.3.4&nbsp;&nbsp;</span>Resumen de modelos con hiperparámetros (MinMax Scaler)</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Conclusión" data-toc-modified-id="Conclusión-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Conclusión</a></span></li></ul></div>

# %% [markdown]
# # Práctico de Introducción a Machine Learning
#
# En este práctico implementaremos modelos sencillos de clasificiación para intentar predecir el ausentismo en los turnos. Vamos a experimentar con modelos lineales y con árboles de decisión. Nuestro objetivo no será construir el mejor modelo, sino ganar un poco más de intuición sobre nuestro conjunto de datos, y tomar algunas decisiones sobre las que profundizaremos en el próximo práctico.
#
# ## Preprocesamiento
#
# Antes de aplicar los modelos, haremos un filtrado de los datos. Se sugiere seguir los siguientes pasos, pero pueden experimentar ustedes también otras alternativas
#
# - Seleccionar sólo los registros cuyo estado de turno sea "Ausente" o "Atendido". Esta variable será nuestra variable objetivo, sobre la cual buscaremos hacer predicciones.
#
# - Remover los siguientes registros:
#
#     - Turnos con pacientes menores de edad.
#
#     - Turnos en días domingo.
#
#     - Pacientes sin datos en columna "Sexo"
#
#     - Consultas de guardia
#
#     - Consultas de pediatría
#
#     - Registros cuyo centro de atención sea "1" o "2"
#
# - Crear los siguientes features:
#
#     - **Anticipación de reserva**. Diferencia entre la fecha del turno y la fecha de otorgado. En caso de que la fecha de otorgado sea mayor a la del turno, colocar el valor 0.
#
#     - **Día de la semana**.
#
#     - **Consulta médica**. Variable binaria construida a partir del campo "Prestación asignada", que vale 1 si la prestación es una consulta médica, o 0 si es de otro tipo.
#
#     - **Consumidor final**. Variable binaria construida a partir del campo "Prestador", que vale 1 si se trata de un consumidor final, o 0 si cuenta con obra social o prepaga.
#
# Una vez realizados los pasos previos (o los que ustedes consideren pertinentes) debemos decidir qué hacer con los valores nulos que hayan quedado. Dado que los modelos no pueden recibir valores nulos, es necesario tomar una decisión (descartarlos, reemplazarlos por algún valor representativo, descartar alguna columna, etc.). Utilicen el criterio que consideren adecuado en este caso.
#
# Una vez que el dataset resultante no tenga valores nulos, es necesario transformar las variables categóricas en variables numéricas (es decir, realizar un encoding de los datos). Las recomendaciones en este caso son:
#
# - Realizar one-hot encoding para los campos
#
#     - Día de la semana
#     - Tipo de turno
#     - Centro de atención
#
#
# - Transformar en variables binarias los campos
#
#     - Estado del turno ("Ausente" == 1, "Atendido" = 0)
#     - Sexo
#     - Es sobre turno
#     - Consulta médica
#     - Consumidor final
#
# Pueden ver más sobre encoding [acá](https://towardsdatascience.com/categorical-encoding-using-label-encoding-and-one-hot-encoder-911ef77fb5bd).
#
# ## Elección de los modelos
#
# Con los pasos anteriores, nuestro dataset debería ser una tabla con valores numéricos y sin valores nulos. Ahora, deberán separar el conjunto de datos en conjunto de entrenamiento (train) y conjunto de prueba (test). Por ahora, no utilizaremos conjunto de validación. Se recomienda utilizar el método `train_test_split` de `scikitlearn`, con un 80% para train y 20% para test.
#
# Una vez divididos los datos, construimos los modelos predictivos. Deberán elegir (al menos) dos modelos [lineales](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.linear_model) y dos modelos basados en [árboles de decisión](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.ensemble). Entrenen cada modelo utilizando el conjunto de entrenamiento y los parámetros por defecto y evaluen la predicción utilizando las cuatro métricas descriptas más adelante. ¿Qué diferencias hay entre los distintos modelos? ¿Qué tan buenas son las predicciones?
#
# Jueguen un poco variando algunos parámetros (no es necesario hacer una búsqueda sistemática). ¿Qué parámetros influyen más en el desempeño de los clasificadores? ¿Por qué les parece que algunos parámetros influyen más que otros?
#
# Repitan el proceso pero normalizando los datos de entrada (pueden usar, por ejemplo `MinMaxScaler` o `StandardScaler`). ¿Hay alguna diferencia en el resultado de los modelos? ¿A qué se debe?
#
# Finalmente, intenten mejorar las predicciones agregando o quitando features, o variando el tipo de encoding. En base a los resultados que vayan obteniendo, determinen los features que ustedes consideren que son más informativos (aquellos que ayudan a mejorar la predicción) y aquellos que sean redundantes, o que empeoren el resultado.
#
# ## Elección de métricas
#
# Un aspecto fundamental del aprendizaje automático es la elección de métricas para evaluar los modelos predictivos. En este práctico vamos a explorar las siguientes cuatro métricas:
#
# - Accuracy
# - F1
# - AUC ROC
# - AUC Precision-Recall
#
# Para cada uno de los modelos que utilicen, calculen las cuatro métricas. ¿Qué información brinda cada una? ¿Hay algún inconveniente en utilizar alguna de ellas? ¿Cuáles les parece que pueden ser de utilidad para nuestra problemática? Pueden encontrar información sobre las últimas dos [acá](https://machinelearningmastery.com/roc-curves-and-precision-recall-curves-for-classification-in-python/).

# %% [markdown]
# **Integrantes:**
#
#   + Gianuzzi Emmanuel
#   + Lascano Lucas
#   + Salgado Cristian

# %% [markdown]
# # Importaciones

# %% [markdown]
# ## Librerías

# %%
#Libs posiblemente faltantes
import os
import gc
import sys
import pkg_resources
if 'sidetable' not in {pkg.key for pkg in pkg_resources.working_set}:
    # !pip install sidetable
if 'psutil' not in {pkg.key for pkg in pkg_resources.working_set}:
    # !pip install psutil
if 'xgboost' not in {pkg.key for pkg in pkg_resources.working_set}:
    # !pip install xgboost
if 'scikit-learn' not in {pkg.key for pkg in pkg_resources.working_set}:
    # !pip install scikit-learn
in_colab = 'google.colab' in sys.modules

# %%
#Vemos versiones
from platform import python_version
print('python                       ', python_version())
# !pip list | grep -E "numpy |pandas |seaborn |psutil |xgboost |scikit-learn |sidetable |scipy |matplotlib "
# Out:
# python                        3.8.5
# matplotlib                        3.3.1
# numpy                             1.19.1
# pandas                            1.1.3
# psutil                            5.7.2
# scikit-learn                      0.23.2
# scipy                             1.5.2
# seaborn                           0.11.0
# sidetable                         0.6.0
# xgboost                           1.2.0

# %%
#Resto de libs
import psutil
import sidetable
import numpy as np
import scipy as sp
import pandas as pd
import seaborn as sns
from seaborn import heatmap
from scipy.stats import norm
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
from IPython.display import display_html
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import (MinMaxScaler,
                                   StandardScaler)
from sklearn.tree import (DecisionTreeClassifier)
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import (Perceptron,
                                  SGDClassifier,
                                  LogisticRegression)
from sklearn.model_selection import (GridSearchCV,
                                     train_test_split)
from sklearn.metrics import (f1_score,
                             recall_score,
                             roc_auc_score,
                             accuracy_score,
                             precision_score,
                             confusion_matrix,
                             balanced_accuracy_score)

# %%
#Reproducibilidad
np.random.seed(0)

#Aesthetic
sns.set()
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["legend.shadow"]    = True

BLUE   = '#5DADE2'
RED    = '#ff7043'
ORANGE = '#F5B041'
GREEN  = '#58D68D'
YELLOW = '#F4D03F'

pd.options.display.max_columns = 30
pd.options.display.max_rows    = 20

# %% [markdown]
# ## Funciones

# %%
def CantidadNulos(df, col=None):
    '''Imprime la cantidad de nulos en cada columna de df.
    Parámetros
    ----------
    df : DataFrame
    \t Dataframe a analizar nulos.
    col: string
    \t Columna específica a analizar.'''
    if col in df.columns:
        Cur_DropNa(df, col, exc=False)
        return
    print('\tCantidad de nulos por columna:')
    for cols in df.columns:
        Cur_DropNa(df, cols, exc=False)
    return

def get_null_fraction(df, col):
    """Fracción nula."""
    return df[col].isnull().sum() / float(df.shape[0])

def get_null_percent(df, col):
    """Porcentaje nulo."""
    return 'NULL = {:.2f}%'.format(100*get_null_fraction(df, col))

class display_side_by_side(object):
    """Display HTML representation of multiple objects."""
    template = """<div style="float: left; padding: 10px;">
    <p style='font-family:"Courier New", Courier, monospace'>{0}</p>{1}
    </div>"""
    def __init__(self, *args):
        self.args = args
        
    def _repr_html_(self):
        return '\n'.join(self.template.format(a, eval(a)._repr_html_())
                         for a in self.args)
    
    def __repr__(self):
        return '\n\n'.join(a + '\n' + repr(eval(a))
                           for a in self.args)
    
def Memory():
    """Imprime la cantidad de memoria RAM utilizada por el proceso 
    hasta el momento, en GB"""
    gc.collect()
    process = psutil.Process(os.getpid())
    print('Memoria actual utilizada: %.2f GB' %(process.memory_full_info().rss*1e-9))
    return


def Ploteo(Tot, Dif, name=None, h: bool=False, size=(20,5), row: bool=True, order=None, yticks: bool=False):
    """Función para plotear las tablas 'Tot' y 'Dif' (Provenientes de 'Tablas')
    Parámetros
    ----------
    Tot : DataFrame
    \t Dataframe con los porcentajes totales.
    Dif : DataFrame
    \t Dataframe con los porcentajes diferenciados.
    name : string, optional (Default = str(col))
    \t Nombre a colocar en el eje principal.
    h : bool, optional (Default = False)
    \t Si el barplot es horizontal o no.
    size : tuple, optional (Default = (20,5))
    \t Tamaño de la figura.
    row : bool, optional(Default = True)
    \t Si la figura posee 3 columnas (True) o 3 filas (False).
    order : list, optional (Default=np.sort(values))
    \t El orden de ploteo de los valores.
    yticks : bool, optional (Default=False)
    \t Si plotear o no los ticks en caso de que h==True.
    """
    col = Tot.index.name
    if not name:
        name = str(col)
    if not order:
        order = Tot.index
    elif order==True:
        order = np.sort(Tot.index)
    kind  = 'bar'
    if h:
        kind  = 'barh'
        order = order[::-1]
    if row:
        fig, ax = plt.subplots(1,3, figsize=size)
    else:
        fig, ax = plt.subplots(3,1, figsize=size)
    Tot.Porcentaje[order].plot(kind=kind, color=BLUE, ax=ax[0], label='Todos')
    Dif.Porcentaje.unstack(level=1).loc[order].plot(kind=kind, subplots=False, color=[RED, ORANGE], ax=ax[1])
    Tot.Ausentismo[order].plot(kind=kind, color=GREEN, ax=ax[2])
    if not h:
        plt.setp(ax[0], ylabel='Frecuencia')
        plt.setp([ax[0],ax[1],ax[2]], xlabel=name)
        ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=0)
        ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=0)
        ax[2].set_xticklabels(ax[2].get_xticklabels(), rotation=0)
    else:
        plt.setp([ax[0], ax[1], ax[2]], xlabel='Frecuencia')
        plt.setp(ax[0], ylabel=name)
        plt.setp([ax[1], ax[2]], ylabel='')
        if not yticks:
            ax[1].set_yticklabels('')
            ax[2].set_yticklabels('')
    ax[0].legend(loc=(1,1), bbox_to_anchor=(0.4, 1.05))
    ax[1].legend(loc=(1,1), bbox_to_anchor=(0.2, 1.05),  ncol=2)
    ax[2].legend(loc=(1,1), bbox_to_anchor=(0.35, 1.05))
    plt.show()
    
def Porcent(x):
    """Devuelve un string pasando de ratio a porcentaje."""
    return "%.2f%%"%(x*100)
                        
def Tablas(df, col, order=None, name=None):
    """Función para generar tablas 'Total' y 'Diferenciado'.
    Parámetros
    ----------
    df  : DataFrame
    \t Dataframe con los datos.
    col : string
    \t Nombre de la columna a operar.
    order : list, optional (Default="Mayor a menor frecuencia")
    \t Lista con el order de los índices de las tablas.
    name : string, optional (Default=str(col))
    \t Nombre a introducir en como título de las tablas.
    """
    if not name:
        name = str(col)
    Values = df[col].value_counts()
    if not order:
        order = Values.index
    elif order==True:
        order = np.sort(df[col].unique())
    Diferen = pd.DataFrame(df[[col, 'EstadoDelTurno']].groupby([col, 'EstadoDelTurno']).size()).rename(
        columns={0: 'Cantidad'}).reindex(order, level=0)
    Diferen['Porcentaje'] = Diferen.Cantidad.div(Diferen.Cantidad.sum(level=0), level=0)
    Ausent  = Diferen.unstack().Cantidad.Ausente.div(Diferen.unstack().Cantidad.Atendido)
    Values  = Values.loc[order]
    ValuesN = df[col].value_counts(normalize=True).loc[order]
    Total   = pd.concat([Values.rename('Cantidad'), 
                         ValuesN.rename('Porcentaje'), 
                         Values.cumsum().rename('Cant_Acum'), 
                         ValuesN.cumsum().rename('Porcent_Acumu'), 
                         Ausent.rename('Ausentismo')], axis=1).rename_axis(name)
    return Total, Diferen

def get_metrics_train_test(y_true_train, y_pred_train, y_true_test, y_pred_test):
    print('Conjunto de entrenamiento:')
    display(get_metrics(y_true_train, y_pred_train).T.applymap("{0:.2%}".format))
    print('\nConjunto de evaluación:')
    display(get_metrics(y_true_test, y_pred_test).T.applymap("{0:.2%}".format))
    return
    
def get_metrics(y_true, y_pred, index='Valor'):
    """Devuelve un DataFrame con accuracy, precision, recall y f1-score."""
    accuracy     = accuracy_score(y_true, y_pred)
    bal_accuracy = balanced_accuracy_score(y_true, y_pred)
    precision    = precision_score(y_true, y_pred)
    precision    = precision_score(y_true, y_pred)
    recall       = recall_score(y_true, y_pred)
    f1           = f1_score(y_true, y_pred)
    roc_auc      = roc_auc_score(y_true, y_pred)
    df           = pd.DataFrame(data=[[accuracy, bal_accuracy,
                                       precision, recall, f1, roc_auc]],
                    columns=['Accuracy', 'Balanced Accuracy', 'Precision',
                             'Recall', 'F1-Score', 'AUC_ROC'],
                    index=[index])
    return df

def get_metrics_comparison(y_true, y_predictions, models):
    metrics_list = []
    for y_pred, model in zip(y_predictions, models):
        df_y       = get_metrics(y_true, y_pred)
        df_y.index = [model]
        metrics_list.append(df_y)
    df_metrics = pd.concat(metrics_list)
    display(df_metrics.style.background_gradient(low=0, high=1, cmap='Greens', axis=0))
    return

# def get_confusion_matrix(y_true, y_pred):
#     """Devuelve un DataFrame con la matriz de confusión."""    
#     cm = confusion_matrix(y_true, y_pred, labels=[0, 1]).transpose()
#     df = pd.DataFrame(
#         cm, 
#         columns=['Actual - Atendido', 'Actual - Ausente'],
#         index=['Predicted - Atendido', 'Predicted - Ausente'])
#     df.loc['Total'] = df.sum()  # Agrego fila de totales
#     df['Total']     = df.sum(axis=1)  # Agrego columna de totales
#     df              = df.applymap("{:,}".format)
#     return df

def Cur_Lim(df, col=None, Min=None, Max=None, inplace: bool=False,
           exc: bool=True, ret: bool=None):
    '''Función para remover valores numéricos por encima de "Min",
    y por encima de "Max".
    Parámetros:
    -----------
    Min    : Valor límite inferior. (float/int - Default:18)
    Max    : Valor límite superior. (float/int - Default:150)
    col    : Columna a trabajar. (string - Default:None)
    inplace: Sobreescribir DataFrame. (bool - Default:False)
    exc    : Elevar exception. [Opcional] (bool - Default:True)
    ret    : Devolver DataFrame sin eliminados (0) o 
             solamente ellos (1). [Opcional] (bool - Default:None).
    '''
    if not col:
        verb = 'Especifique columna.'
        if exc:
            raise Exception(verb)
        return print(verb)
    if col not in df.columns:
        verb = 'La columna {} no es válida.'.format(col)
        if exc:
            raise Exception(verb)
        return print(verb)
    if (not Min) and (not Max):
        print('No se introdujeron límites para {}.'.
              format(col))
        print('Límites:'
              '\n Mín: {}'
              '\n Máx: {}'.format(
              df[col].min(), df[col].max()))
        verb = 'Especifique al menos un límite.'
        if exc:
            raise Exception(verb)
        return print(verb)
    if ret not in [None, 1, 0]:
        verb = 'Especifique un parámetro de devolución' \
               ' permitido. [None, 1, 0]'
        if exc:
            raise Exception(verb)
        return print(verb)
    a   = len(df)
    Min = df[col].min() if not Min else Min
    Max = df[col].max() if not Max else Max
    Rem = df[(df[col]<Min) | (df[col]>Max)]
    if len(Rem)==0:
        verb = 'No hay valores a eliminar en la columnas'\
               ' {} fuera de límites: [{}, {}]'.format(
                   col, Min, Max)
        if exc:
            raise Exception(verb)
        return print(verb)
    b   = df.drop(Rem.index, inplace=inplace)
    print('Curación de columna {} aplicada con límites:' \
          '[{:d}, {:d}]'.format(col, Min, Max))
    if not inplace:
        print('\tA remover: {:d} filas. (=={:.2f}%)'.format(
            a-len(b), (1-len(b)/a)*100))
        if ret==None:
            return 
        return Rem if ret else b
    print('\tRemovidas: {:d} filas. (=={:.2f}%)'.format(
        a-len(df), (1-len(df)/a)*100))
    if ret==None:
        return 
    return Rem if ret else b

def Cur_Drop(df, col=None, val=None, re: bool=True, inplace: bool=False,
           exc: bool=True, ret: bool=None):
    '''Función para remover entradas con valor "val" en la columna "col".
    Parámetros:
    -----------
    val    : Valor a intercambiar. (string - Default:None)
    col    : Columna a trabajar. (string - Default:None)
    re     : Búsqueda por regex. (bool  - Default:True)
    inplace: Sobreescribir DataFrame. (bool - Default:False)
    exc    : Elevar exception. [Opcional] (bool - Default:True)
    ret    : Devolver DataFrame sin eliminados (0) o 
             solamente ellos (1). [Opcional] (bool - Default:None).
    '''
    if not col:
        verb = 'Especifique columna.'
        if exc:
            raise Exception(verb)
        return print(verb)
    if col not in df.columns:
        verb = 'La columna {} no es válida.'.format(col)
        if exc:
            raise Exception(verb)
        return print(verb)
    if not val:
        verb = 'Especifique valor.'
        if exc:
            raise Exception(verb)
        return print(verb)
    if ret not in [None, 1, 0]:
        verb = 'Especifique un parámetro de devolución' \
               ' permitido. [1, 0]'
        if exc:
            raise Exception(verb)
        return print(verb)
    a = len(df)
    if not re:
        VAL = [val in s for s in df[col]]
        Rem = df[VAL]
        if len(Rem)==0:
            verb = 'No hay aciertos de {} en {}.'.format(val, col)
            if exc:
                raise Exception(verb)
            return print(verb)
        b   = df.drop(Rem.index, inplace=inplace)
    else:
        if val not in df[col].unique():
            verb = '{} no se encuentra en' \
                   ' la columna {}.'.format(val, col)
            if exc:
                raise Exception(verb)
            return print(verb)
        Rem = df[df[col]==val]
        b   = df.drop(Rem.index, inplace=inplace)
    print('Curación {} valor {} en columna {:s} aplicada.'
          .format(('de' if re else 'incluyendo'), val, col))
    if not inplace:
        print('\tA remover: {:d} filas. (=={:.2f}%)'.format(
            a-len(b), (1-len(b)/a)*100))
        if ret==None:
            return 
        return Rem if ret else b
    print('\tRemovidas: {:d} filas. (=={:.2f}%)'.format(
        a-len(df), (1-len(df)/a)*100))
    if ret==None:
        return 
    return Rem if ret else b

def Cur_DropNa(df, col=None, inplace: bool=False, exc: bool=True, 
              ND='No Definido', ret: bool=None):
    '''Función para remover entradas con valor nulo en la columna "col".
    Parámetros:
    -----------
    col    : Columna a trabajar. (string - Default:None)
    inplace: Sobreescribir DataFrame. (bool - Default:False)
    exc    : Elevar exception. [Opcional] (bool - Default:True)
    ND     : Valor referido a Nulo en cuanto a columna tipo "Objeto".
             [Opcional] (string/int/float - Default:'No Definido')
    ret    : Devolver DataFrame sin eliminados (0) o 
             solamente ellos (1). [Opcional] (bool - Default:None).
    '''
    if not col:
        verb = 'Especifique columna.'
        if exc:
            raise Exception(verb)
        return print(verb)
    if col not in df.columns:
        verb = 'La columna {} no es válida.'.format(col)
        if exc:
            raise Exception(verb)
        return print(verb)
    n = df[col] == ND if df[col].dtype == 'O' else df[col].isnull()
    if n.sum()==0:
        verb = 'La columna {} no posee valores nulos.'.format(col)
        if exc:
            raise Exception(verb)
        return print(verb)
    a   = len(df)
    Rem = df[n]
    b   = df.drop(Rem.index, inplace=inplace)
    print('Curación de Nulos en columna {:s} aplicada.'.format(col))
    if not inplace:
        print('\tA remover: {:d} filas. (=={:.2f}%)'.format(
            a-len(b), (1-len(b)/a)*100))
        if ret==None:
            return 
        return Rem if ret else b
    print('\tRemovidas: {:d} filas. (=={:.2f}%)'.format(
        a-len(df), (1-len(df)/a)*100))
    if ret==None:
        return 
    return Rem if ret else b

def Binarizer(df, col=None, unique=None, re: bool=True, exc: bool=True,
              merge: bool=True, text: bool=True, name=None, drop: bool=False):
    '''Función para binarizar en [0, 1] las entradas 
    de la columna "col". Si se especifica un valor (unique),
    se reemplazará por 0, y al resto 1; de lo contrario, se 
    binarizará en [0, 1] a los 2 valores pre-existentes de "col".
    Parámetros:
    -----------
    col    : Columna a binarizar. (str - Default:None)
    unique : Valor a setear en 1. (str/float/int - Default:None)
    re     : Búsqueda por regex. (bool  - Default:True)
    exc    : Elevar exception. [Opcional] (bool - Default:True)
    merge  : Devolver DataFrame/Series binario creado (0) o el merge
             con el DataFrame original (1). 
             [Opcional] (bool - Default:True).
    text   : Imprimir el proceso realizado.
    name   : Nombre a asignar a la columna creada.
    drop   : Eliminar la columna fuente utilizada para binarizar.
    '''
    if not col:
        verb = 'Especifique columna.'
        if exc:
            raise Exception(verb)
        return print(verb)
    if col not in df.columns:
        verb = 'La columna {} no es válida.'.format(col)
        if exc:
            raise Exception(verb)
        return print(verb)
    vals = df[col].unique()
    if not unique:
        if len(vals)!=2:
            verb = 'La columna introducida posee {} clases (!=2)'.format(
                len(vals))
            if exc:
                raise Exception(verb)
            return print(verb)
        if name is None: name = col+'_'+str(vals[0])
        if name in df.columns:
            verb = 'La columna {} ya existe'.format(name)
            if exc:
                raise Exception(verb)
            return print(verb)
        new  = df[col].replace(
            {vals[0]: 1, vals[1]: 0}).rename(name)
        if text:
            print('Reemplazo:'
                  '\n 1 = {} ({:.2f}%)'
                  '\n 0 = {}'.
                  format(vals[0], new.sum()*100/len(df),
                         vals[1]))
    else:
        if name is None: name = col+'_'+str(unique)
        if name in df.columns:
            verb = 'La columna {} ya existe'.format(name)
            if exc:
                raise Exception(verb)
            return print(verb)
        if re:
            if unique not in vals:
                verb = '{} no se encuentra en la columna {}.'.format(
                    unique, col)
                if exc:
                    raise Exception(verb)
                return print(verb)
            val = df[col] == unique
            can = sum(val)
        else:
            val = [unique in s for s in df[col]]
            can = sum(val)
            if can==0:
                verb = 'La expresión {} no se encuentra en ningúna' \
                        ' entrada de la columna {}.'.format(unique, col)
                if exc:
                    raise Exception(verb)
                return print(verb)
        new = df[col].copy().rename(name)
        new.loc[np.asarray(val)]  = 1
        new.loc[~np.asarray(val)] = 0
        if text:
            print('Reemplazo:'
                  '\n 1 = {} ({:.2f}%)'
                  '\n 0 = Resto'.format(
                      unique, can*100/len(df)))
    print('Columna {} creada'.format(name))
    if not merge: return new.astype('uint8')
    if drop: 
        print('Se elimina columna {}'.format(col))
        return df.merge(new.astype('uint8'), left_index=True,
                        right_index=True).drop(col, axis=1)
    return df.merge(new.astype('uint8'),
           left_index=True,right_index=True)

def BinarAll(df, cols=None, exc: bool=True, merge: bool=False,
             text: bool=True, fast: bool=True):
    '''Función para binarizar en [0, 1] TODAS las entradas 
    de la columna "col".
    Parámetros:
    -----------
    cols   : Columna(s) a binarizar. (str/list - Default:None)
    exc    : Elevar exception. [Opcional] (bool - Default:True)
    merge  : Devolver DataFrame/Series binario creado (1) o el merge
             con el DataFrame original (0). 
             [Opcional] (bool - Default:None).
    text   : Imprimir el proceso realizado.
    fast   : Método rápido. [Opcional] (bool - Default:True)
    '''
    if not cols:
        verb = 'Especifique columna(s).'
        if exc:
            raise Exception(verb)
        return print(verb)
    cols = list(cols)
    for col in cols:
        if col not in df.columns:
            verb = 'La columna {} no es válida.'.format(col)
            if exc:
                raise Exception(verb)
            return print(verb)
    if merge:
        return pd.get_dummies(df, columns=cols)
    if fast:
        extra = [cl for cl in df.columns if cl not in cols]
        return pd.get_dummies(
            df, columns=cols).drop(columns=extra, axis=1)
    for col in cols:
        vals = df[col].unique()
        if 'sr' not in locals():
            print('First')
            sr = Binarizer(df, col=col, unique=vals[0], exc=exc,
                           text=text).astype('uint8')
        for val in vals[1:]:
            sr = pd.concat([sr, Binarizer(
                    df, col=col, unique=val, exc=exc,
                    text=text).astype('uint8')], axis=1)
    return sr

def HM(y_real, y_pred, ax=None, cmap='Greys', normalize=None):
    '''Plot simple de heatmap.'''
    kwargs = dict(annot=True, linewidths=1.2, square=True,
                   linecolor='black', cbar=False, cmap=cmap,
                   annot_kws={"weight":'bold', "size":'15'}, ax=ax)
    if normalize: return heatmap(confusion_matrix(y_real, y_pred,
                            normalize=normalize), fmt='.3f', **kwargs)
    return heatmap(confusion_matrix(y_real, y_pred,
                            normalize=normalize), fmt='d', **kwargs)

def PlotHM(y_train, y_train_pred, y_test, y_test_pred, size=(10,6), cmap='Greys', 
           Title='Título', normalize=None):
    '''Plotea las 2 matrices de confusión (Entrenamiento y Prueba),
    dados los Target y sus predicciones (Train y Test).'''
    plt.figure(figsize=size)
    plt.suptitle(Title, y=.93)
    plt.subplot(1,2,1)
    plt.title('Entrenamiento')
    ax1 = HM(y_train, y_train_pred, cmap=cmap, normalize=normalize)
    plt.ylabel('Real', fontsize=15)
    plt.subplot(1,2,2)
    plt.title('Prueba')
    ax2  = HM(y_test, y_test_pred, cmap=cmap, normalize=normalize)
    plt.setp([ax1.get_xticklabels(), ax2.get_xticklabels()], rotation=0, weight='bold')
    plt.setp([ax1.get_yticklabels(), ax2.get_yticklabels()], rotation=0, weight='bold')
    plt.setp([ax1.set_xlabel('Predecido'), ax2.set_xlabel('Predecido')], fontsize=15)
    if normalize: 
        [t.set_text(t.get_text() + " %") for t in ax1.texts]
        [t.set_text(t.get_text() + " %") for t in ax2.texts]
    plt.show()

# %%
Memory()
# Out:
# Memoria actual utilizada: 0.17 GB

# %% [markdown]
# ## Dataset

# %%
if in_colab:
  data_dir = "https://github.com/Gianuzzi/Ausentismo-DD2020-Final/raw/master/data/"
else:
  data_dir = os.path.join(os.getcwd(), '..', '..', 'data')
df       = pd.read_csv(os.path.join(data_dir, 'dataset_curado.zip'))
size     = len(df)
scol     = len(df.columns)

# %%
#Vistazo
display(df.sample(3))
# Out:
#         Index_df  CentroDeAtencion                Prestador  \
# 136069    279785                 1                 I.O.S.E.
# 864770   1693883                 1       SWISS MEDICAL S.A.
# 873837   1709412                 2  MEDIFE ASOCIACIÓN CIVIL
#
#               PrestadorAgrupado         Servicio ServicioAgrupado  \
# 136069                     OTRO  GOTEO DE HIERRO             OTRO
# 864770       SWISS MEDICAL S.A.        PEDIATRÍA        PEDIATRIA
# 873837  MEDIFE ASOCIACIÓN CIVIL     OFTALMOLOGÍA             OTRO
#
#        EstadoDelTurno Sexo  Edad  Bin_Edad     HC  \
# 136069        Ausente    F    31  [30, 40)  12664
# 864770       Atendido    M     1   [0, 10)  79691
# 873837        Ausente    F    31  [30, 40)  14409
#
#                                      HC2 TipoDeTurnoAsignado  \
# 136069  2adfd952d109f78f310901931aa1675b            Práctica
# 864770  415049ced0a40124411a0823432e308a  Ulterior / Control
# 873837  746206d63610c80c08bdf440226b462a         Primera Vez
#
# ...

# %%
Memory()
# Out:
# Memoria actual utilizada: 0.93 GB

# %% [markdown]
# # Pre- Estudio

# %% [markdown]
# ## Análisis

# %% [markdown]
# ### Nulos

# %%
CantidadNulos(df)
# Out:
# 	Cantidad de nulos por columna:
# La columna Index_df no posee valores nulos.
# La columna CentroDeAtencion no posee valores nulos.
# La columna Prestador no posee valores nulos.
# La columna PrestadorAgrupado no posee valores nulos.
# La columna Servicio no posee valores nulos.
# La columna ServicioAgrupado no posee valores nulos.
# La columna EstadoDelTurno no posee valores nulos.
# La columna Sexo no posee valores nulos.
# La columna Edad no posee valores nulos.
# La columna Bin_Edad no posee valores nulos.
# La columna HC no posee valores nulos.
# La columna HC2 no posee valores nulos.
# La columna TipoDeTurnoAsignado no posee valores nulos.
# La columna PrestacionAsignada no posee valores nulos.
# La columna PrestacionAgrupado no posee valores nulos.
# Curación de Nulos en columna Localidad aplicada.
# 	A remover: 879297 filas. (==65.83%)
# Curación de Nulos en columna Provincia aplicada.
# 	A remover: 810933 filas. (==60.72%)
# ...

# %% [markdown]
# ### Menores de Edad (18)

# %%
Cur_Lim(df, 'Edad', Min=18, exc=False)
# Out:
# Curación de columna Edad aplicada con límites:[18, 102]
# 	A remover: 313695 filas. (==23.49%)

# %% [markdown]
# ### Domingos

# %%
Cur_Drop(df, 'DiaSemanal', 'Domingo', exc=False)
# Out:
# Curación de valor Domingo en columna DiaSemanal aplicada.
# 	A remover: 605 filas. (==0.05%)

# %% [markdown]
# ### Sexo

# %%
print('Valores únicos en columna SEXO:', df.Sexo.unique())
# Out:
# Valores únicos en columna SEXO: ['M' 'F']

# %% [markdown]
# ### GUARDIA

# %%
Cur_Drop(df, 'Servicio', 'GUARDIA', re=False, exc=False)
Cur_Drop(df, 'ServicioAgrupado', 'GUARDIA', re=False, exc=False)
# Out:
# No hay aciertos de GUARDIA en Servicio.
# No hay aciertos de GUARDIA en ServicioAgrupado.

# %% [markdown]
# ### Pedriatría y Servicios Infantiles

# %%
Cur_Drop(df, 'Servicio', 'PEDIAT', re=False, exc=False)
Cur_Drop(df, 'ServicioAgrupado', 'PEDIAT', re=False, exc=False)
Cur_Drop(df, 'PrestacionAsignada', '- INF', re=False, exc=False) #INF solo incluye otras cosas
Cur_Drop(df, 'PrestacionAgrupado', 'INF', re=False, exc=False)
# Out:
# Curación incluyendo valor PEDIAT en columna Servicio aplicada.
# 	A remover: 124377 filas. (==9.31%)
# Curación incluyendo valor PEDIAT en columna ServicioAgrupado aplicada.
# 	A remover: 102502 filas. (==7.67%)
# Curación incluyendo valor - INF en columna PrestacionAsignada aplicada.
# 	A remover: 3430 filas. (==0.26%)
# No hay aciertos de INF en PrestacionAgrupado.

# %% [markdown]
# ### Centros de Atención 5 y 6

# %%
Cur_Drop(df, 'CentroDeAtencion', 5, exc=False)
Cur_Drop(df, 'CentroDeAtencion', 6, exc=False)
# Out:
# Curación de valor 5 en columna CentroDeAtencion aplicada.
# 	A remover: 3522 filas. (==0.26%)
# 6 no se encuentra en la columna CentroDeAtencion.

# %%
Memory()
# Out:
# Memoria actual utilizada: 0.93 GB

# %% [markdown]
# ## Curación de filas

# %%
print('Tamaño inicial de dataset:', size)
print('--------------------------')
#Edad: No Menores de 18.
Cur_Lim(df, 'Edad', Min=18, inplace=True, exc=False)
#Día Semanal: NO Domingos.
Cur_Drop(df, 'DiaSemanal', 'Domingo', inplace=True, exc=False)
#Sexo: NO Valores Nulos.
Cur_DropNa(df, 'Sexo', inplace=True, exc=False)
#Centro de Atención: NO 5 NI 6.
Cur_Drop(df, 'CentroDeAtencion', 5, inplace=True, exc=False)
Cur_Drop(df, 'CentroDeAtencion', 6, inplace=True, exc=False)
#Servicio: NO GUARDIA.
Cur_Drop(df, 'Servicio', 'GUARDIA', re=False, inplace=True, exc=False)
#Servicio: NO PEDIATRÍA
Cur_Drop(df, 'Servicio', 'PEDIAT', re=False, inplace=True, exc=False)
#Prestación: NO INFANTIL.
Cur_Drop(df, 'PrestacionAsignada', '- INF', re=False, inplace=True, exc=False)
#Sobre Turno: NO No Definidos.
Cur_Drop(df, 'EsSobreTurno', 'No Definido', inplace=True, exc=False)
#Precipitaciones: NO NaNs.
Cur_DropNa(df, 'Prec_mm', inplace=True, exc=False)
#Renovamos el Indíce
df.reset_index(inplace=True, drop=True)
print('---------------------------------------------------------')
print('Tamaño de dataset curado: {} ({:.2f}% del original)'.format(
    len(df), len(df)*100/size))
size      = len(df)
Ausentes  = df.EstadoDelTurno == 'Ausente'
Atendidos = df.EstadoDelTurno == 'Atendido'
# Out:
# Tamaño inicial de dataset: 1335619
# --------------------------
# Curación de columna Edad aplicada con límites:[18, 102]
# 	Removidas: 313695 filas. (==23.49%)
# Curación de valor Domingo en columna DiaSemanal aplicada.
# 	Removidas: 297 filas. (==0.03%)
# La columna Sexo no posee valores nulos.
# Curación de valor 5 en columna CentroDeAtencion aplicada.
# 	Removidas: 2370 filas. (==0.23%)
# 6 no se encuentra en la columna CentroDeAtencion.
# No hay aciertos de GUARDIA en Servicio.
# Curación incluyendo valor PEDIAT en columna Servicio aplicada.
# 	Removidas: 3894 filas. (==0.38%)
# Curación incluyendo valor - INF en columna PrestacionAsignada aplicada.
# 	Removidas: 3420 filas. (==0.34%)
# Curación de valor No Definido en columna EsSobreTurno aplicada.
# 	Removidas: 41009 filas. (==4.05%)
# Curación de Nulos en columna Prec_mm aplicada.
# 	Removidas: 8640 filas. (==0.89%)
# ---------------------------------------------------------
# ...

# %% [markdown]
# ### Edad (Revisión)

# %%
print('Resumen')
Edad_des              = pd.DataFrame(df.Edad.rename('Todos').describe().map("{:,.1f}".format))
Edad_des['Atendidos'] = pd.DataFrame(df[Atendidos].Edad.describe().map("{:,.1f}".format))
Edad_des['Ausentes '] = pd.DataFrame(df[Ausentes ].Edad.describe().map("{:,.1f}".format))
display(Edad_des.rename_axis("Edad", axis="columns"))
# Out:
# Resumen
# Edad       Todos  Atendidos  Ausentes
# count  962,294.0  811,682.0  150,612.0
# mean        43.9       44.5       41.0
# std         15.9       16.0       15.0
# min         18.0       18.0       18.0
# 25%         32.0       33.0       30.0
# 50%         40.0       41.0       38.0
# 75%         54.0       55.0       49.0
# max        102.0      102.0       99.0

# %%
plt.figure(figsize=(20,15))
grid = plt.GridSpec(3, 2, wspace=0.4, hspace=0.3)
plt.suptitle('Edad', y=0.93, fontsize=20)
mini = df.Edad.min()
maxi = df.Edad.max()

ax1 = plt.subplot(grid[0,0])
sns.boxplot(data=df, x='Edad', color=BLUE)
plt.ylabel('Todos')

ax2 = plt.subplot(grid[0,1])
plt.title('Ancho de bin = 10 años', fontsize=13)
x = np.linspace(norm.ppf(0.001, loc=df.Edad.mean(), scale=df.Edad.std()),
                norm.ppf(0.999, loc=df.Edad.mean(), scale=df.Edad.std()), 100)
sns.distplot(df.Edad, kde=False, norm_hist=True, bins=np.arange(mini, maxi+10, 10),
             color=BLUE, label='Todos', hist_kws={"alpha": 0.8})
plt.plot(x, norm.pdf(x, loc=df.Edad.mean(), scale=df.Edad.std()), 'k-', lw=5, alpha=0.8, label='Distribución Normal')
plt.legend()

ax3 = plt.subplot(grid[1,0])
sns.boxplot(data=df[Ausentes | Atendidos], y='EstadoDelTurno', x='Edad', palette=[RED, ORANGE])
plt.ylabel('')

ax4 = plt.subplot(grid[1,1])
plt.title('Ancho de bin = 1 año', fontsize=13)
sns.distplot(df.Edad[Atendidos], kde=True, norm_hist=True, bins=df.Edad[Atendidos].max(), color=RED, label='Atendidos', 
             kde_kws={"lw": 3.5} ,hist_kws={"alpha": 0.25, "linewidth": 2})
sns.distplot(df.Edad[Ausentes] , kde=True, norm_hist=True, bins=df.Edad[Ausentes].max(), color=ORANGE, label='Ausentes', 
             kde_kws={"lw": 3.5} ,hist_kws={"alpha": 0.25, "linewidth": 2})
plt.legend()

ax5 = plt.subplot(grid[2,0:])
Ausentismo = df.Edad[Ausentes].value_counts().div(df.Edad[Atendidos].value_counts())
Ausentismo.plot.bar(color=GREEN, label='Ausentismo')
plt.xticks(np.arange(mini, maxi, 5), np.arange(mini, maxi, 5), rotation=0)
plt.xlabel('Edad')
plt.legend()

plt.setp([ax2, ax4, ax5], ylabel='Frecuencia')
plt.setp([ax1, ax2, ax3, ax4, ax5], xlabel='', xlim=[mini - 0.5, + maxi + 0.5])
plt.setp([ax1, ax3], xticks=np.arange(mini, maxi + 10, 10))


plt.show()
# Out:
# /home/egianuzzi/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/egianuzzi/miniconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ### Domingo (Revisión)

# %%
OrderDS  = ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado']
Tot, Dif = Tablas(df, 'DiaSemanal', order=OrderDS)
Diferenciado            = Dif.copy()
Total                   = Tot.copy()
Diferenciado.Porcentaje = Dif.Porcentaje.apply(Porcent)
Total.Porcentaje        = Total.Porcentaje.apply(Porcent)
Total.Porcent_Acumu     = Total.Porcent_Acumu.apply(Porcent)
display_side_by_side("Diferenciado", "Total")
# Out:
# Diferenciado
#                            Cantidad Porcentaje
# DiaSemanal EstadoDelTurno
# Lunes      Atendido          156609     83.94%
#            Ausente            29953     16.06%
# Martes     Atendido          170937     83.97%
#            Ausente            32632     16.03%
# Miércoles  Atendido          172095     84.81%
#            Ausente            30817     15.19%
# Jueves     Atendido          158204     84.91%
#            Ausente            28125     15.09%
# Viernes    Atendido          144574     84.35%
#            Ausente            26833     15.65%
# Sábado     Atendido            9263     80.44%
#            Ausente             2252     19.56%
#
# Total
#             Cantidad Porcentaje  Cant_Acum Porcent_Acumu  Ausentismo
# DiaSemanal
# Lunes         186562     19.39%     186562        19.39%    0.191260
# Martes        203569     21.15%     390131        40.54%    0.190901
# Miércoles     202912     21.09%     593043        61.63%    0.179070
# ...

# %%
Ploteo(Tot, Dif, 'Día Semanal', True, order=OrderDS, yticks=True)

# %% [markdown]
# ### Sexo (Revisón)

# %%
Tot, Dif                = Tablas(df, 'Sexo')
Diferenciado            = Dif.copy()
Total                   = Tot.copy()
Diferenciado.Porcentaje = Dif.Porcentaje.apply(Porcent)
Total.Porcentaje        = Total.Porcentaje.apply(Porcent)
Total.Porcent_Acumu     = Total.Porcent_Acumu.apply(Porcent)
display_side_by_side("Diferenciado", "Total")
# Out:
# Diferenciado
#                      Cantidad Porcentaje
# Sexo EstadoDelTurno
# F    Atendido          529234     83.79%
#      Ausente           102351     16.21%
# M    Atendido          282448     85.41%
#      Ausente            48261     14.59%
#
# Total
#       Cantidad Porcentaje  Cant_Acum Porcent_Acumu  Ausentismo
# Sexo
# F       631585     65.63%     631585        65.63%    0.193395
# M       330709     34.37%     962294       100.00%    0.170867

# %%
#Ploteamos
Ploteo(Tot, Dif)

# %% [markdown]
# ### Sobre Turno (Revisón)

# %%
Tot, Dif                = Tablas(df, 'EsSobreTurno')
Diferenciado            = Dif.copy()
Total                   = Tot.copy()
Diferenciado.Porcentaje = Dif.Porcentaje.apply(Porcent)
Total.Porcentaje        = Total.Porcentaje.apply(Porcent)
Total.Porcent_Acumu     = Total.Porcent_Acumu.apply(Porcent)
display_side_by_side("Diferenciado", "Total")
# Out:
# Diferenciado
#                              Cantidad Porcentaje
# EsSobreTurno EstadoDelTurno
# NO           Atendido          633722     81.73%
#              Ausente           141654     18.27%
# SI           Atendido          177960     95.21%
#              Ausente             8958      4.79%
#
# Total
#               Cantidad Porcentaje  Cant_Acum Porcent_Acumu  Ausentismo
# EsSobreTurno
# NO              775376     80.58%     775376        80.58%    0.223527
# SI              186918     19.42%     962294       100.00%    0.050337

# %%
#Ploteamos
Ploteo(Tot, Dif)

# %% [markdown]
# ### Guardia e INF (Revisión Servicio)

# %%
Tot, Dif                = Tablas(df, 'ServicioAgrupado')
Diferenciado            = Dif.copy()
Total                   = Tot.copy()
Diferenciado.Porcentaje = Dif.Porcentaje.apply(Porcent)
Total.Porcentaje        = Total.Porcentaje.apply(Porcent)
Total.Porcent_Acumu     = Total.Porcent_Acumu.apply(Porcent)
display_side_by_side("Diferenciado", "Total")
# Out:
# Diferenciado
#                                         Cantidad Porcentaje
# ServicioAgrupado        EstadoDelTurno
# OTRO                    Atendido          323804     84.83%
#                         Ausente            57891     15.17%
# GINECO Y OBSTETRICIA    Atendido          108784     85.02%
#                         Ausente            19162     14.98%
# KINESIOL Y FISIOTERAPIA Atendido           98981     84.65%
#                         Ausente            17952     15.35%
# CLINICA MEDICA          Atendido           57969     82.99%
#                         Ausente            11884     17.01%
# ORTOPEDIA               Atendido           53959     83.71%
#                         Ausente            10503     16.29%
# CARDIOLOGIA             Atendido           49496     86.08%
#                         Ausente             8001     13.92%
# DERMATOLOGIA            Atendido           30896     78.74%
#                         Ausente             8340     21.26%
# ...

# %%
#Ploteamos
Ploteo(Tot, Dif, h=True)

# %% [markdown]
# ### Pediatría (Revisión Prestación)

# %%
Tot, Dif                = Tablas(df, 'PrestacionAgrupado')
Diferenciado            = Dif.copy()
Total                   = Tot.copy()
Diferenciado.Porcentaje = Dif.Porcentaje.apply(Porcent)
Total.Porcentaje        = Total.Porcentaje.apply(Porcent)
Total.Porcent_Acumu     = Total.Porcent_Acumu.apply(Porcent)
display_side_by_side("Diferenciado", "Total")
# Out:
# Diferenciado
#                                             Cantidad Porcentaje
# PrestacionAgrupado          EstadoDelTurno
# CONSULTA                    Atendido          511639     83.15%
#                             Ausente           103707     16.85%
# OTRA                        Atendido           72717     80.52%
#                             Ausente            17588     19.48%
# PRESTACIONES MULTIPLES      Atendido           78603     97.63%
#                             Ausente             1907      2.37%
# FISIO|KINE                  Atendido           54416     84.05%
#                             Ausente            10330     15.95%
# REHABILITACION              Atendido           21607     77.55%
#                             Ausente             6254     22.45%
# ECO                         Atendido           19137     84.96%
#                             Ausente             3388     15.04%
# CITOLOGIA                   Atendido           19765     99.92%
# ...

# %%
#Ploteamos
Ploteo(Tot, Dif, h=True)

# %% [markdown]
# ### Centros de Atención (Revisión)

# %%
Tot, Dif                = Tablas(df, 'CentroDeAtencion', order=[1,2,3,4])
Diferenciado            = Dif.copy()
Total                   = Tot.copy()
Diferenciado.Porcentaje = Dif.Porcentaje.apply(Porcent)
Total.Porcentaje        = Total.Porcentaje.apply(Porcent)
Total.Porcent_Acumu     = Total.Porcent_Acumu.apply(Porcent)
display_side_by_side("Diferenciado", "Total")
# Out:
# Diferenciado
#                                  Cantidad Porcentaje
# CentroDeAtencion EstadoDelTurno
# 1                Atendido          497070     85.09%
#                  Ausente            87095     14.91%
# 2                Atendido          138702     83.45%
#                  Ausente            27498     16.55%
# 3                Atendido           73905     80.65%
#                  Ausente            17732     19.35%
# 4                Atendido          102005     84.80%
#                  Ausente            18287     15.20%
#
# Total
#                   Cantidad Porcentaje  Cant_Acum Porcent_Acumu  Ausentismo
# CentroDeAtencion
# 1                   584165     60.71%     584165        60.71%    0.175217
# 2                   166200     17.27%     750365        77.98%    0.198252
# 3                    91637      9.52%     842002        87.50%    0.239930
# 4                   120292     12.50%     962294       100.00%    0.179276

# %%
Ploteo(Tot, Dif, name='Centro de Atención')

# %%
Memory()
# Out:
# Memoria actual utilizada: 0.87 GB

# %% [markdown]
# ## Features Nuevos

# %%
print('Cantidad de columnas en DataSet:', scol)
# Out:
# Cantidad de columnas en DataSet: 32

# %% [markdown]
# ### Mes

# %%
df['Mes'] = df['FechaDelTurno'].str[5:7].astype('uint8')

# %%
print('Cantidad de columnas en dataset luego de agregar nuevos features: {} ({:.2f}%)'.format(
    len(df.columns), len(df.columns)*100/scol))
scol = len(df.columns)
# Out:
# Cantidad de columnas en dataset luego de agregar nuevos features: 33 (103.12%)

# %% [markdown]
# ### Consulta y Particular

# %% [markdown]
# Estos featrures serán agregados al realizar *Hot-Encoding* (Sec. 2.5.3) a las columnas correspondientes

# %%
Memory()
# Out:
# Memoria actual utilizada: 0.87 GB

# %% [markdown]
# ## Curación de Columnas

# %% [markdown]
# ### Nulos

# %%
CantidadNulos(df)
# Out:
# 	Cantidad de nulos por columna:
# La columna Index_df no posee valores nulos.
# La columna CentroDeAtencion no posee valores nulos.
# La columna Prestador no posee valores nulos.
# La columna PrestadorAgrupado no posee valores nulos.
# La columna Servicio no posee valores nulos.
# La columna ServicioAgrupado no posee valores nulos.
# La columna EstadoDelTurno no posee valores nulos.
# La columna Sexo no posee valores nulos.
# La columna Edad no posee valores nulos.
# La columna Bin_Edad no posee valores nulos.
# La columna HC no posee valores nulos.
# La columna HC2 no posee valores nulos.
# La columna TipoDeTurnoAsignado no posee valores nulos.
# La columna PrestacionAsignada no posee valores nulos.
# La columna PrestacionAgrupado no posee valores nulos.
# Curación de Nulos en columna Localidad aplicada.
# 	A remover: 601217 filas. (==62.48%)
# Curación de Nulos en columna Provincia aplicada.
# 	A remover: 542930 filas. (==56.42%)
# ...

# %% [markdown]
# #### Localidad y Provincia

# %%
display(df.stb.freq(['Localidad'], style=True))
# Out:
# <style  type="text/css" >
# </style><table id="T_ddc0cf38_1ac0_11eb_bf81_533969838ef5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Localidad</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ddc0cf38_1ac0_11eb_bf81_533969838ef5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ddc0cf38_1ac0_11eb_bf81_533969838ef5row0_col0" class="data row0 col0" >No Definido</td>
#                         <td id="T_ddc0cf38_1ac0_11eb_bf81_533969838ef5row0_col1" class="data row0 col1" >601,217</td>
#                         <td id="T_ddc0cf38_1ac0_11eb_bf81_533969838ef5row0_col2" class="data row0 col2" >62.48%</td>
# ...

# %%
display(df.stb.freq(['Provincia'], style=True))
# Out:
# <style  type="text/css" >
# </style><table id="T_ddd93c62_1ac0_11eb_bf81_533969838ef5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Provincia</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ddd93c62_1ac0_11eb_bf81_533969838ef5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ddd93c62_1ac0_11eb_bf81_533969838ef5row0_col0" class="data row0 col0" >No Definido</td>
#                         <td id="T_ddd93c62_1ac0_11eb_bf81_533969838ef5row0_col1" class="data row0 col1" >542,930</td>
#                         <td id="T_ddd93c62_1ac0_11eb_bf81_533969838ef5row0_col2" class="data row0 col2" >56.42%</td>
# ...

# %%
NullPyL = ((df.Localidad == 'No Definido') | (df.Provincia == 'No Definido')).sum()
print('Cantidad de valores No Definidos Provincia y/o en Localidad: %i (=%.2f%% del total)'
     %(NullPyL, 100*NullPyL/size))
# Out:
# Cantidad de valores No Definidos Provincia y/o en Localidad: 622866 (=64.73% del total)

# %% [markdown]
# Debido a la gran cantidad de nulos en estas columnas (~64%), se eliminarán las columnas **Localidad** y **Provincia** del DasaSet

# %%
print('Cantidad de columnas en dataset:', scol)
print('----------------------------------------')
drop = ['Localidad', 'Provincia']
df.drop(columns=drop, inplace=True)
print('Columnas borradas:', drop)
print('--------------------------------------------------')
print('Cantidad de columnas en dataset: {} ({:.2f}%)'.format(
    len(df.columns), len(df.columns)*100/scol))
scol = len(df.columns)
# Out:
# Cantidad de columnas en dataset: 33
# ----------------------------------------
# Columnas borradas: ['Localidad', 'Provincia']
# --------------------------------------------------
# Cantidad de columnas en dataset: 31 (93.94%)

# %% [markdown]
# #### Nombre del Canal

# %%
display(df.stb.freq(['NombreDelCanal'], style=True))
# Out:
# <style  type="text/css" >
# </style><table id="T_de693538_1ac0_11eb_bf81_533969838ef5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >NombreDelCanal</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_de693538_1ac0_11eb_bf81_533969838ef5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_de693538_1ac0_11eb_bf81_533969838ef5row0_col0" class="data row0 col0" >No Definido</td>
#                         <td id="T_de693538_1ac0_11eb_bf81_533969838ef5row0_col1" class="data row0 col1" >365,985</td>
#                         <td id="T_de693538_1ac0_11eb_bf81_533969838ef5row0_col2" class="data row0 col2" >38.03%</td>
# ...

# %% [markdown]
# Dejaremos la categoría _No Definido_ dentro de **NombreDelCanal** porque esta feature puede ser importante

# %% [markdown]
# ### Extras

# %%
print('Cantidad de columnas en dataset:', scol)
print('----------------------------------------')
drop = ['Index_df', 'Prestador', 'Servicio', 'HC',
        'HC2', 'PrestacionAsignada', 'FechaDelTurno',
        'FechaDeOtorgado', 'Recurso', 'Recurso2']
df.drop(columns=drop, axis=1, inplace=True)
print('Columnas borradas:', drop)
print('--------------------------------------------------')
print('Cantidad de columnas en dataset: {} ({:.2f}%)'.format(
    len(df.columns), len(df.columns)*100/scol))
scol = len(df.columns)
# Out:
# Cantidad de columnas en dataset: 31
# ----------------------------------------
# Columnas borradas: ['Index_df', 'Prestador', 'Servicio', 'HC', 'HC2', 'PrestacionAsignada', 'FechaDelTurno', 'FechaDeOtorgado', 'Recurso', 'Recurso2']
# --------------------------------------------------
# Cantidad de columnas en dataset: 21 (67.74%)

# %%
CantidadNulos(df)
# Out:
# 	Cantidad de nulos por columna:
# La columna CentroDeAtencion no posee valores nulos.
# La columna PrestadorAgrupado no posee valores nulos.
# La columna ServicioAgrupado no posee valores nulos.
# La columna EstadoDelTurno no posee valores nulos.
# La columna Sexo no posee valores nulos.
# La columna Edad no posee valores nulos.
# La columna Bin_Edad no posee valores nulos.
# La columna TipoDeTurnoAsignado no posee valores nulos.
# La columna PrestacionAgrupado no posee valores nulos.
# Curación de Nulos en columna NombreDelCanal aplicada.
# 	A remover: 365985 filas. (==38.03%)
# La columna EsSobreTurno no posee valores nulos.
# La columna DifEnDias no posee valores nulos.
# La columna Bin_Diff_Dias no posee valores nulos.
# La columna DiaSemanal no posee valores nulos.
# La columna MomDelDia no posee valores nulos.
# La columna EstaciMeteor no posee valores nulos.
# La columna Prec_mm no posee valores nulos.
# La columna Lluvia no posee valores nulos.
# ...

# %%
Memory()
# Out:
# Memoria actual utilizada: 0.55 GB

# %% [markdown]
# ## Clasificación y Edición de columnas

# %%
#Aesthetic
df.MomDelDia      = ([s.replace(' - ', '_') for s in df.MomDelDia])
df.Bin_Edad       = ([s.replace('[', '').replace(')', '').replace(', ', '_') for s in df.Bin_Edad])
df.Bin_Diff_Dias  = ([s.replace('[', '').replace(')', '').replace(', ', '_') for s in df.Bin_Diff_Dias])

# %%
print('Columnas del DataSet:\n', df.columns)
# Out:
# Columnas del DataSet:
#  Index(['CentroDeAtencion', 'PrestadorAgrupado', 'ServicioAgrupado',
#        'EstadoDelTurno', 'Sexo', 'Edad', 'Bin_Edad', 'TipoDeTurnoAsignado',
#        'PrestacionAgrupado', 'NombreDelCanal', 'EsSobreTurno', 'DifEnDias',
#        'Bin_Diff_Dias', 'DiaSemanal', 'MomDelDia', 'EstaciMeteor', 'Prec_mm',
#        'Lluvia', 'Tmed', 'Temperatura', 'Mes'],
#       dtype='object')

# %%
Categoricas = ['CentroDeAtencion', 'PrestadorAgrupado', 'ServicioAgrupado', 'Bin_Edad', 'Mes',
                    'TipoDeTurnoAsignado', 'PrestacionAgrupado', 'NombreDelCanal', 'Bin_Diff_Dias',
                    'DiaSemanal', 'MomDelDia', 'EstaciMeteor','Lluvia', 'Temperatura']
Binarias    = ['Sexo', 'EstadoDelTurno', 'EsSobreTurno']
Numericas   = ['DifEnDias', 'Prec_mm', 'Tmed', 'Edad']

# %% [markdown]
# ### Binarizado (Binarias)

# %%
df = Binarizer(df, 'Sexo', 'F', name='Sexo_F', drop=True)
df = Binarizer(df, 'EsSobreTurno', 'SI', re=False, name='SobreTurno', drop=True)
df = Binarizer(df, 'EstadoDelTurno', 'Ausente', name='Ausente', drop=True)
# Out:
# Reemplazo:
#  1 = F (65.63%)
#  0 = Resto
# Columna Sexo_F creada
# Se elimina columna Sexo
# Reemplazo:
#  1 = SI (19.42%)
#  0 = Resto
# Columna SobreTurno creada
# Se elimina columna EsSobreTurno
# Reemplazo:
#  1 = Ausente (15.65%)
#  0 = Resto
# Columna Ausente creada
# Se elimina columna EstadoDelTurno

# %% [markdown]
# ### Hot Encoding  (Categorical)

# %%
#Columnas a encodear
print('Cantidad de columnas en dataset:', scol)
print('----------------------------------------')
df = BinarAll(df, Categoricas, merge=True, text=True)
print('Se aplicó Hot-Encoding a {} columnas'.format(len(Categoricas)))
print('--------------------------------------------------')
print('Cantidad de columnas en dataset: {} ({:.2f}%)'.format(
    len(df.columns), len(df.columns)*100/scol))
scol = len(df.columns)
# Out:
# Cantidad de columnas en dataset: 21
# ----------------------------------------
# Se aplicó Hot-Encoding a 14 columnas
# --------------------------------------------------
# Cantidad de columnas en dataset: 114 (542.86%)

# %% [markdown]
# ### Scaling (Numerical)

# %% [markdown]
# #### Standard Scaler

# %%
scaler_SS = StandardScaler()
scaler_SS.fit(df[Numericas])
SS_cols   = ['{}_SS'.format(element) for element in Numericas]
X_Num_SS  = pd.DataFrame(scaler_SS.transform(df[Numericas]),
                         columns=SS_cols)
print('Cantidad de columnas en dataset:', scol)
print('----------------------------------------')
df = df.merge(X_Num_SS, left_index=True, right_index=True)
print('Se aplicó Standard Scaler a las columnas: {}'.format(Numericas))
print('--------------------------------------------------')
print('Cantidad de columnas en dataset: {} ({:.2f}%)'.format(
    len(df.columns), len(df.columns)*100/scol))
scol = len(df.columns)
# Out:
# Cantidad de columnas en dataset: 114
# ----------------------------------------
# Se aplicó Standard Scaler a las columnas: ['DifEnDias', 'Prec_mm', 'Tmed', 'Edad']
# --------------------------------------------------
# Cantidad de columnas en dataset: 118 (103.51%)

# %% [markdown]
# #### MinMax Scaler

# %%
scaler_MM = MinMaxScaler()
scaler_MM.fit(df[Numericas])
MM_cols   = ['{}_MM'.format(element) for element in Numericas]
X_Num_MM  = pd.DataFrame(scaler_MM.transform(df[Numericas]),
                         columns=MM_cols)
print('Cantidad de columnas en dataset:', scol)
print('----------------------------------------')
df = df.merge(X_Num_MM, left_index=True, right_index=True)
print('Se aplicó MinMax Scaler a las columnas: {}'.format(Numericas))
print('--------------------------------------------------')
print('Cantidad de columnas en dataset: {} ({:.2f}%)'.format(
    len(df.columns), len(df.columns)*100/scol))
scol = len(df.columns)
# Out:
# Cantidad de columnas en dataset: 118
# ----------------------------------------
# Se aplicó MinMax Scaler a las columnas: ['DifEnDias', 'Prec_mm', 'Tmed', 'Edad']
# --------------------------------------------------
# Cantidad de columnas en dataset: 122 (103.39%)

# %% [markdown]
# ## Formato y Memoria

# %%
df.Edad      = df.Edad.astype('uint8')
df.DifEnDias = df.DifEnDias.astype('uint8')
df.Tmed      = df.Tmed.astype('uint8')

# %%
del Ausentismo, Atendidos, Ausentes, Categoricas, Dif, Diferenciado,
del Edad_des, NullPyL, OrderDS, Tot, Total, X_Num_MM, X_Num_SS
del ax1, ax2, ax3, ax4, ax5, drop, maxi, mini, grid
del scaler_MM, scaler_SS, x

# %%
Memory()
# Out:
# Memoria actual utilizada: 0.79 GB

# %% [markdown]
# ## Guardado

# %%
if not in_colab:
    name  = 'dataset_recurado_IAA.csv'
    df.to_csv(name, index=False)
    from zipfile import ZipFile, ZIP_DEFLATED
    zname = name[:-3]+'zip'
    with ZipFile(zname, 'w', ZIP_DEFLATED) as zf:
        zf.write(name)
    os.rename(os.path.join(os.getcwd(), zname), os.path.join(data_dir, zname))
    os.remove(name) 
    print('Dataset guardado en {}'.format(os.path.join(data_dir, zname)))
# Out:
# Dataset guardado en /home/egianuzzi/Documentos/Git/DiploDatos2020/Ausentismo-DD2020-Final/Notebooks/Aprendizaje_Automatico/../../data/dataset_recurado_IAA.zip

# %% [markdown]
# # Estudio

# %%
random_state = 0 #Reproducibilidad

# %% [markdown]
# ## División entre conjunto de entrenamiento y de evaluación

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df.drop('Ausente', axis=1), df.Ausente, test_size=0.2, random_state=random_state)
print('Tamaño X_train:', X_train.shape)
print('Tamaño X_test:', X_test.shape)
# Out:
# Tamaño X_train: (769835, 121)
# Tamaño X_test: (192459, 121)

# %% [markdown]
# ### Balance Entrenamiento

# %%
display(pd.DataFrame(y_train).stb.freq(['Ausente'], style=True))
# Out:
# <style  type="text/css" >
# </style><table id="T_0b895480_1ac1_11eb_bf81_533969838ef5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Ausente</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0b895480_1ac1_11eb_bf81_533969838ef5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0b895480_1ac1_11eb_bf81_533969838ef5row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_0b895480_1ac1_11eb_bf81_533969838ef5row0_col1" class="data row0 col1" >649,427</td>
#                         <td id="T_0b895480_1ac1_11eb_bf81_533969838ef5row0_col2" class="data row0 col2" >84.36%</td>
# ...

# %% [markdown]
# ### Balance Prueba

# %%
display(pd.DataFrame(y_test).stb.freq(['Ausente'], style=True))
# Out:
# <style  type="text/css" >
# </style><table id="T_0b9312d6_1ac1_11eb_bf81_533969838ef5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Ausente</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0b9312d6_1ac1_11eb_bf81_533969838ef5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0b9312d6_1ac1_11eb_bf81_533969838ef5row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_0b9312d6_1ac1_11eb_bf81_533969838ef5row0_col1" class="data row0 col1" >162,255</td>
#                         <td id="T_0b9312d6_1ac1_11eb_bf81_533969838ef5row0_col2" class="data row0 col2" >84.31%</td>
# ...

# %% [markdown]
# ### Balance Total

# %%
display(df.stb.freq(['Ausente'], style=True))
# Out:
# <style  type="text/css" >
# </style><table id="T_0ba77c26_1ac1_11eb_bf81_533969838ef5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Ausente</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0ba77c26_1ac1_11eb_bf81_533969838ef5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0ba77c26_1ac1_11eb_bf81_533969838ef5row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_0ba77c26_1ac1_11eb_bf81_533969838ef5row0_col1" class="data row0 col1" >811,682</td>
#                         <td id="T_0ba77c26_1ac1_11eb_bf81_533969838ef5row0_col2" class="data row0 col2" >84.35%</td>
# ...

# %%
fig, ax = plt.subplots(1,3, figsize=(25,7))
df.Ausente.value_counts(normalize=True, ascending=False).plot.bar(color=[RED, ORANGE], ax=ax[0])
y_train.value_counts(normalize=True, ascending=False).plot.bar(color=[RED, ORANGE], ax=ax[1])
y_test.value_counts(normalize=True, ascending=False).plot.bar(color=[RED, ORANGE], ax=ax[2])
plt.setp(ax[0], ylabel='Frecuencia')
plt.setp([ax[0],ax[1],ax[2]], xlabel='Estado del Turno')
ax[0].set_xticklabels(['Atendido', 'Ausente'], rotation=0)
ax[1].set_xticklabels(['Atendido', 'Ausente'], rotation=0)
ax[2].set_xticklabels(['Atendido', 'Ausente'], rotation=0)
ax[0].set_title('Dataset Completo', fontweight='bold')
ax[1].set_title('Entrenamiento', fontweight='bold')
ax[2].set_title('Prueba', fontweight='bold')
plt.show()

# %%
Memory()
# Out:
# Memoria actual utilizada: 0.79 GB

# %% [markdown]
# ## Entrenamiento de modelos sin hiperparámetros

# %% [markdown]
# ### Sin escalado

# %%
X_train_SE = X_train.drop(MM_cols + SS_cols, axis=1)
X_test_SE  = X_test.drop(MM_cols + SS_cols, axis=1)
print('Tamaño X_train_SE:', X_train_SE.shape)
print('Tamaño X_test_SE:', X_test_SE.shape)
# Out:
# Tamaño X_train_SE: (769835, 113)
# Tamaño X_test_SE: (192459, 113)

# %% [markdown]
# #### Decision Tree

# %%
dtc = DecisionTreeClassifier(random_state=random_state)
dtc.fit(X_train_SE, y_train);
y_pred_dtc_train = dtc.predict(X_train_SE)
y_pred_dtc_test  = dtc.predict(X_test_SE)
Memory()

# %% [markdown]
# **Resultados**

# %%
Entrenamiento = get_metrics(y_train, y_pred_dtc_train).T
Evaluacion    = get_metrics(y_test, y_pred_dtc_test).T
display_side_by_side("Entrenamiento", "Evaluacion")

# %%
PlotHM(y_train, y_pred_dtc_train, y_test, y_pred_dtc_test,
       Title='Decision Tree Classifier - Sin Escalado', normalize=None)

# %%
del dtc
Memory()

# %% [markdown]
# #### Random Forest

# %%
rfc = RandomForestClassifier(random_state=random_state, n_jobs=-1)
rfc.fit(X_train_SE, y_train);
y_pred_rfc_train = rfc.predict(X_train_SE)
y_pred_rfc_test  = rfc.predict(X_test_SE)
Memory()
# Out:
# Memoria actual utilizada: 5.15 GB

# %% [markdown]
# **Resulados**

# %%
Entrenamiento = get_metrics(y_train, y_pred_rfc_train).T
Evaluacion    = get_metrics(y_test, y_pred_rfc_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.999166
# Balanced Accuracy  0.997645
# Precision          0.999233
# Recall             0.995432
# F1-Score           0.997329
# AUC_ROC            0.997645
#
# Evaluacion
#                       Valor
# Accuracy           0.842476
# Balanced Accuracy  0.519362
# Precision          0.481408
# Recall             0.048437
# F1-Score           0.088019
# AUC_ROC            0.519362

# %%
PlotHM(y_train, y_pred_rfc_train, y_test, y_pred_rfc_test,
       Title='Random Forest Classifier - Sin Escalado', normalize=None)

# %%
del rfc
Memory()
# Out:
# Memoria actual utilizada: 5.15 GB

# %% [markdown]
# #### Logistic Regression

# %%
lrc = LogisticRegression(max_iter=1000, random_state=random_state, n_jobs=None)
lrc.fit(X_train_SE, y_train);
y_pred_lrc_train = lrc.predict(X_train_SE)
y_pred_lrc_test  = lrc.predict(X_test_SE)
Memory()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Memoria actual utilizada: 5.25 GB

# %% [markdown]
# **Resultados**

# %%
Entrenamiento = get_metrics(y_train, y_pred_lrc_train).T
Evaluacion    = get_metrics(y_test, y_pred_lrc_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.844043
# Balanced Accuracy  0.503237
# Precision          0.623137
# Recall             0.007292
# F1-Score           0.014415
# AUC_ROC            0.503237
#
# Evaluacion
#                       Valor
# Accuracy           0.843400
# Balanced Accuracy  0.503083
# Precision          0.589532
# Recall             0.007085
# F1-Score           0.014002
# AUC_ROC            0.503083

# %%
PlotHM(y_train, y_pred_lrc_train, y_test, y_pred_lrc_test,
       Title='Logistic Regression - Sin Escalado', normalize=None)

# %%
del lrc
Memory()
# Out:
# Memoria actual utilizada: 5.25 GB

# %% [markdown]
# #### Gaussian Naive Bayes

# %%
gnbc = GaussianNB()
gnbc.fit(X_train_SE, y_train);
y_pred_gnbc_train = gnbc.predict(X_train_SE)
y_pred_gnbc_test  = gnbc.predict(X_test_SE)
Memory()
# Out:
# Memoria actual utilizada: 5.43 GB

# %% [markdown]
# **Resultados**

# %%
Entrenamiento = get_metrics(y_train, y_pred_gnbc_train).T
Evaluacion    = get_metrics(y_test, y_pred_gnbc_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.462196
# Balanced Accuracy  0.625960
# Precision          0.207407
# Recall             0.864270
# F1-Score           0.334533
# AUC_ROC            0.625960
#
# Evaluacion
#                       Valor
# Accuracy           0.462452
# Balanced Accuracy  0.625215
# Precision          0.207810
# Recall             0.862435
# F1-Score           0.334919
# AUC_ROC            0.625215

# %%
PlotHM(y_train, y_pred_gnbc_train, y_test, y_pred_gnbc_test,
       Title='Gaussian Naive Bayes - Sin Escalado', normalize=None)

# %%
del gnbc
Memory()
# Out:
# Memoria actual utilizada: 5.43 GB

# %% [markdown]
# #### SGD Classifier

# %%
sgdc = SGDClassifier(random_state=random_state, n_jobs=-1)
sgdc.fit(X_train_SE, y_train);
y_pred_sgdc_train = sgdc.predict(X_train_SE)
y_pred_sgdc_test  = sgdc.predict(X_test_SE)
Memory()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e0693e28e790> in <module>
# ----> 1 sgdc = SGDClassifier(random_state=random_state, n_jobs=-1)
#       2 sgdc.fit(X_train_SE, y_train);
#       3 y_pred_sgdc_train = sgdc.predict(X_train_SE)
#       4 y_pred_sgdc_test  = sgdc.predict(X_test_SE)
#       5 Memory()
#
# NameError: name 'SGDClassifier' is not defined

# %% [markdown]
# **Resultados**

# %%
Entrenamiento = get_metrics(y_train, y_pred_sgdc_train).T
Evaluacion    = get_metrics(y_test, y_pred_sgdc_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.844029
# Balanced Accuracy  0.503401
# Precision          0.610381
# Recall             0.007715
# F1-Score           0.015238
# AUC_ROC            0.503401
#
# Evaluacion
#                       Valor
# Accuracy           0.843406
# Balanced Accuracy  0.503248
# Precision          0.585492
# Recall             0.007482
# F1-Score           0.014776
# AUC_ROC            0.503248

# %%
PlotHM(y_train, y_pred_sgdc_train, y_test, y_pred_sgdc_test,
       Title='SGD Classifier - Sin Escalado', normalize=None)

# %%
del sgdc
Memory()
# Out:
# Memoria actual utilizada: 5.43 GB

# %% [markdown]
# #### Perceptron

# %%
pct = Perceptron(random_state=random_state)
pct.fit(X_train_SE, y_train);
y_pred_pct_train = pct.predict(X_train_SE)
y_pred_pct_test  = pct.predict(X_test_SE)
Memory()
# Out:
# Memoria actual utilizada: 5.43 GB

# %% [markdown]
# **Resultados**

# %%
Entrenamiento = get_metrics(y_train, y_pred_pct_train).T
Evaluacion    = get_metrics(y_test, y_pred_pct_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.742445
# Balanced Accuracy  0.608711
# Precision          0.280766
# Recall             0.414100
# F1-Score           0.334641
# AUC_ROC            0.608711
#
# Evaluacion
#                       Valor
# Accuracy           0.740126
# Balanced Accuracy  0.604367
# Precision          0.276737
# Recall             0.406502
# F1-Score           0.329297
# AUC_ROC            0.604367

# %%
PlotHM(y_train, y_pred_pct_train, y_test, y_pred_pct_test,
       Title='Perceptron - Sin Escalado', normalize=None)

# %%
del pct
Memory()
# Out:
# Memoria actual utilizada: 5.43 GB

# %% [markdown]
# #### XGBoost

# %%
xgb = XGBClassifier(random_state=random_state, n_jobs=-1)
xgb.fit(np.asarray(X_train_SE), y_train);
y_pred_xgb_train = xgb.predict(np.asarray(X_train_SE))
y_pred_xgb_test  = xgb.predict(np.asarray(X_test_SE))
Memory()
# Out:
# Memoria actual utilizada: 5.99 GB

# %% [markdown]
# **Resultados**

# %%
Entrenamiento = get_metrics(y_train, y_pred_xgb_train).T
Evaluacion    = get_metrics(y_test, y_pred_xgb_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.844537
# Balanced Accuracy  0.503435
# Precision          0.873587
# Recall             0.007059
# F1-Score           0.014005
# AUC_ROC            0.503435
#
# Evaluacion
#                       Valor
# Accuracy           0.843967
# Balanced Accuracy  0.503338
# Precision          0.859504
# Recall             0.006887
# F1-Score           0.013664
# AUC_ROC            0.503338

# %%
PlotHM(y_train, y_pred_xgb_train, y_test, y_pred_xgb_test,
       Title='XGBoost - Sin Escalado', normalize=None)

# %%
del xgb
Memory()
# Out:
# Memoria actual utilizada: 5.99 GB

# %% [markdown]
# #### Resumen de modelos sin hiperparámetros (Sin escalado)

# %%
models = ['DTC', 'RFC', 'Logistic Regression',
          'Gaussian Naive Bayes', 'SGD', 'Perceptron', 'XGBoost']

# %%
predictions_train = [y_pred_dtc_train, y_pred_rfc_train,
                     y_pred_lrc_train, y_pred_gnbc_train,
                     y_pred_sgdc_train, y_pred_pct_train,
                     y_pred_xgb_train]
print('Conjunto de Entrenamiento:')
get_metrics_comparison(y_train, predictions_train, models)
print('------------------------------------------------------------------------')
predictions_test = [y_pred_dtc_test, y_pred_rfc_test,
                    y_pred_lrc_test, y_pred_gnbc_test,
                    y_pred_sgdc_test, y_pred_pct_test,
                    y_pred_xgb_test]
print('Conjunto de Evaluación:')
get_metrics_comparison(y_test, predictions_test, models)
# Out:
# Conjunto de Entrenamiento:
# <style  type="text/css" >
#     #T_b7283932_ec8b_11ea_a3dc_0242ac1c0002row0_col0 {
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_b7283932_ec8b_11ea_a3dc_0242ac1c0002row0_col1 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_b7283932_ec8b_11ea_a3dc_0242ac1c0002row0_col2 {
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_b7283932_ec8b_11ea_a3dc_0242ac1c0002row0_col3 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_b7283932_ec8b_11ea_a3dc_0242ac1c0002row0_col4 {
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_b7283932_ec8b_11ea_a3dc_0242ac1c0002row0_col5 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_b7283932_ec8b_11ea_a3dc_0242ac1c0002row1_col0 {
#             background-color:  #75c477;
# ...

# %%
del predictions_train, predictions_test
Memory()
# Out:
# Memoria actual utilizada: 5.99 GB

# %% [markdown]
# ### Standard Scaler

# %%
X_train_SS = X_train.drop(MM_cols + Numericas, axis=1)
X_test_SS  = X_test.drop(MM_cols + Numericas, axis=1)
print('Tamaño X_train_SS:', X_train_SS.shape)
print('Tamaño X_test_SS:', X_test_SS.shape)
Memory()
# Out:
# Tamaño X_train_SS: (769835, 113)
# Tamaño X_test_SS: (192459, 113)
# Memoria actual utilizada: 5.99 GB

# %% [markdown]
# #### Decision Tree

# %%
dtc = DecisionTreeClassifier(random_state=random_state)
dtc.fit(X_train_SS, y_train);
y_pred_dtc_train = dtc.predict(X_train_SS)
y_pred_dtc_test  = dtc.predict(X_test_SS)
Memory()
# Out:
# Memoria actual utilizada: 5.99 GB

# %% [markdown]
# **Resultados**

# %%
Entrenamiento = get_metrics(y_train, y_pred_dtc_train).T
Evaluacion    = get_metrics(y_test, y_pred_dtc_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.999189
# Balanced Accuracy  0.997436
# Precision          0.999933
# Recall             0.994884
# F1-Score           0.997402
# AUC_ROC            0.997436
#
# Evaluacion
#                       Valor
# Accuracy           0.756992
# Balanced Accuracy  0.561881
# Precision          0.251493
# Recall             0.277513
# F1-Score           0.263863
# AUC_ROC            0.561881

# %%
PlotHM(y_train, y_pred_dtc_train, y_test, y_pred_dtc_test,
       Title='Decision Tree Classifier - Standard Scaler', normalize=None)

# %% [markdown]
# **Feature Importance**

# %%
FI_dtc = pd.DataFrame({'Feature':X_train_SS.columns,
                       'Importancia':dtc.feature_importances_
                      })
FI_dtc.sort_values(by='Importancia', ascending=False, inplace=True)
FI_dtc.reset_index(inplace=True, drop=True)
FI_dtc['Acumulada'] = FI_dtc.Importancia.cumsum()
thresh = 0.7
lim    = FI_dtc.Acumulada <= thresh
print('Cantidad de features para llegar al {:0}%: {} (=={:.2f} %)'.format(
        thresh*100, lim.sum(), 100*lim.sum()/len(X_train_SS.columns)))

display(FI_dtc)

plt.figure(figsize=(10,7), dpi=100)
plt.title('Feature Importance - DTC \n (25 primeros)')
sns.barplot(x=FI_dtc.Importancia[lim][:25], y=FI_dtc.Feature[lim][:25], 
            orient='h')
plt.show()

# %%
del dtc
Memory()
# Out:
# Memoria actual utilizada: 5.99 GB

# %% [markdown]
# #### Random Forest

# %%
rfc = RandomForestClassifier(random_state=random_state, n_jobs=-1)
rfc.fit(X_train_SS, y_train);
y_pred_rfc_train = rfc.predict(X_train_SS)
y_pred_rfc_test  = rfc.predict(X_test_SS)
Memory()
# Out:
# Memoria actual utilizada: 6.15 GB

# %% [markdown]
# **Resulados**

# %%
Entrenamiento = get_metrics(y_train, y_pred_rfc_train).T
Evaluacion    = get_metrics(y_test, y_pred_rfc_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.999171
# Balanced Accuracy  0.997682
# Precision          0.999183
# Recall             0.995515
# F1-Score           0.997346
# AUC_ROC            0.997682
#
# Evaluacion
#                       Valor
# Accuracy           0.842860
# Balanced Accuracy  0.519954
# Precision          0.493541
# Recall             0.049331
# F1-Score           0.089697
# AUC_ROC            0.519954

# %%
PlotHM(y_train, y_pred_rfc_train, y_test, y_pred_rfc_test,
       Title='Random Forest Classifier- Standard Scaler', normalize=None)

# %% [markdown]
# **Feature Importance**

# %%
FI_rfc = pd.DataFrame({'Feature':X_train_SS.columns,
                       'Importancia':rfc.feature_importances_
                      })
FI_rfc.sort_values(by='Importancia', ascending=False, inplace=True)
FI_rfc.reset_index(inplace=True, drop=True)
FI_rfc['Acumulada'] = FI_rfc.Importancia.cumsum()
thresh = 0.7
lim    = FI_rfc.Acumulada <= thresh
print('Cantidad de features para llegar al {:0}%: {} (=={:.2f} %)'.format(
        thresh*100, lim.sum(), 100*lim.sum()/len(X_train_SS.columns)))

display(FI_rfc)

plt.figure(figsize=(10,7), dpi=100)
plt.title('Feature Importance - RFC \n (25 primeros)')
sns.barplot(x=FI_rfc.Importancia[lim][:25], y=FI_rfc.Feature[lim][:25], 
            orient='h')
plt.show()

# %%
del rfc
Memory()
# Out:
# Memoria actual utilizada: 6.15 GB

# %% [markdown]
# #### Logistic Regression

# %%
lrc = LogisticRegression(max_iter=1000, random_state=random_state, n_jobs=None)
lrc.fit(X_train_SS, y_train);
y_pred_lrc_train = lrc.predict(X_train_SS)
y_pred_lrc_test  = lrc.predict(X_test_SS)
Memory()
# Out:
# Memoria actual utilizada: 6.15 GB

# %% [markdown]
# **Resultados**

# %%
Entrenamiento = get_metrics(y_train, y_pred_lrc_train).T
Evaluacion    = get_metrics(y_test, y_pred_lrc_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.844069
# Balanced Accuracy  0.503236
# Precision          0.633067
# Recall             0.007250
# F1-Score           0.014337
# AUC_ROC            0.503236
#
# Evaluacion
#                       Valor
# Accuracy           0.843442
# Balanced Accuracy  0.503095
# Precision          0.603399
# Recall             0.007052
# F1-Score           0.013941
# AUC_ROC            0.503095

# %%
PlotHM(y_train, y_pred_lrc_train, y_test, y_pred_lrc_test,
       Title='Logistic Regression - Standard Scaler', normalize=None)

# %% [markdown]
# **Feature Importance**
#
# En regresión logísita binaria, la importancia de un feature es positiva o negativa, según si _ayuda_ a predecir 1 o 0; por eso usamos el valor absoluto.

# %%
FI_lrc = pd.DataFrame({'Feature':X_train_SS.columns,
                       'Importancia':lrc.coef_[0]
                      })
FI_lrc['Imp_Absol'] = np.abs(FI_lrc.Importancia)
FI_lrc.sort_values(by='Imp_Absol', ascending=False, inplace=True)
FI_lrc.reset_index(inplace=True, drop=True)
display(FI_lrc)
plt.figure(figsize=(10,7), dpi=100)
plt.title('Feature Importance - LR \n (25 primeros)')
sns.barplot(x=FI_lrc.Importancia[:25], y=FI_lrc.Feature[:25], 
            orient='h')
plt.show()

# %%
del lrc
Memory()
# Out:
# Memoria actual utilizada: 6.15 GB

# %% [markdown]
# #### Gaussian Naive Bayes

# %%
gnbc = GaussianNB()
gnbc.fit(X_train_SS, y_train);
y_pred_gnbc_train = gnbc.predict(X_train_SS)
y_pred_gnbc_test  = gnbc.predict(X_test_SS)
Memory()
# Out:
# Memoria actual utilizada: 6.15 GB

# %% [markdown]
# **Resultados**

# %%
Entrenamiento = get_metrics(y_train, y_pred_gnbc_train).T
Evaluacion    = get_metrics(y_test, y_pred_gnbc_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.411231
# Balanced Accuracy  0.613085
# Precision          0.198084
# Recall             0.906825
# F1-Score           0.325145
# AUC_ROC            0.613085
#
# Evaluacion
#                       Valor
# Accuracy           0.411111
# Balanced Accuracy  0.612644
# Precision          0.198542
# Recall             0.906370
# F1-Score           0.325732
# AUC_ROC            0.612644

# %%
PlotHM(y_train, y_pred_gnbc_train, y_test, y_pred_gnbc_test,
       Title='Gaussian Naive Bayes - Standard Scaler', normalize=None)

# %% [markdown]
# **Feature Importance**

# %%
FI_gnbc = pd.DataFrame({'Feature':X_train_SS.columns,
                       'Importancia':gnbc.coef_[0]
                      })
FI_gnbc['Imp_Absol'] = np.abs(FI_gnbc.Importancia)
FI_gnbc.sort_values(by='Imp_Absol', ascending=False, inplace=True)
FI_gnbc.reset_index(inplace=True, drop=True)
display(FI_gnbc)
plt.figure(figsize=(10,7), dpi=100)
plt.title('Feature Importance - GNB \n (25 primeros)')
sns.barplot(x=FI_gnbc.Importancia[:25], y=FI_gnbc.Feature[:25], 
            orient='h')
plt.show()

# %%
del gnbc
Memory()
# Out:
# Memoria actual utilizada: 6.15 GB

# %% [markdown]
# #### SGD Classifier

# %%
sgdc = SGDClassifier(random_state=random_state, n_jobs=-1)
sgdc.fit(X_train_SS, y_train);
y_pred_sgdc_train = sgdc.predict(X_train_SS)
y_pred_sgdc_test  = sgdc.predict(X_test_SS)
Memory()
# Out:
# Memoria actual utilizada: 6.15 GB

# %% [markdown]
# **Resultados**

# %%
Entrenamiento = get_metrics(y_train, y_pred_sgdc_train).T
Evaluacion    = get_metrics(y_test, y_pred_sgdc_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.843965
# Balanced Accuracy  0.503397
# Precision          0.590195
# Recall             0.007798
# F1-Score           0.015394
# AUC_ROC            0.503397
#
# Evaluacion
#                       Valor
# Accuracy           0.843338
# Balanced Accuracy  0.503235
# Precision          0.565757
# Recall             0.007549
# F1-Score           0.014899
# AUC_ROC            0.503235

# %%
PlotHM(y_train, y_pred_sgdc_train, y_test, y_pred_sgdc_test,
       Title='SGD Classifier - Standard Scaler', normalize=None)

# %% [markdown]
# **Feature Importance**

# %%
FI_sgdc = pd.DataFrame({'Feature':X_train_SS.columns,
                       'Importancia':sgdc.coef_[0]
                      })
FI_sgdc['Imp_Absol'] = np.abs(FI_sgdc.Importancia)
FI_sgdc.sort_values(by='Imp_Absol', ascending=False, inplace=True)
FI_sgdc.reset_index(inplace=True, drop=True)
display(FI_sgdc)
plt.figure(figsize=(10,7), dpi=100)
plt.title('Feature Importance - SGD \n (25 primeros)')
sns.barplot(x=FI_sgdc.Importancia[:25], y=FI_sgdc.Feature[:25], 
            orient='h')
plt.show()

# %%
del sgdc
Memory()
# Out:
# Memoria actual utilizada: 6.15 GB

# %% [markdown]
# #### Perceptron

# %%
pct = Perceptron(random_state=random_state)
pct.fit(X_train_SS, y_train);
y_pred_pct_train = pct.predict(X_train_SS)
y_pred_pct_test  = pct.predict(X_test_SS)
Memory()
# Out:
# Memoria actual utilizada: 6.15 GB

# %% [markdown]
# **Resultados**

# %%
Entrenamiento = get_metrics(y_train, y_pred_pct_train).T
Evaluacion    = get_metrics(y_test, y_pred_pct_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.713683
# Balanced Accuracy  0.583474
# Precision          0.243421
# Recall             0.393994
# F1-Score           0.300923
# AUC_ROC            0.583474
#
# Evaluacion
#                       Valor
# Accuracy           0.713913
# Balanced Accuracy  0.582785
# Precision          0.243837
# Recall             0.391670
# F1-Score           0.300559
# AUC_ROC            0.582785

# %%
PlotHM(y_train, y_pred_pct_train, y_test, y_pred_pct_test,
       Title='Perceptron - Standard Scaler', normalize=None)

# %% [markdown]
# **Feature Importance**

# %%
FI_pct = pd.DataFrame({'Feature':X_train_SS.columns,
                       'Importancia':pct.coef_[0]
                      })
FI_pct['Imp_Absol'] = np.abs(FI_pct.Importancia)
FI_pct.sort_values(by='Imp_Absol', ascending=False, inplace=True)
FI_pct.reset_index(inplace=True, drop=True)
display(FI_pct)
plt.figure(figsize=(10,7), dpi=100)
plt.title('Feature Importance - Perceptron \n (25 primeros)')
sns.barplot(x=FI_pct.Importancia[:25], y=FI_pct.Feature[:25], 
            orient='h')
plt.show()

# %%
del pct
Memory()
# Out:
# Memoria actual utilizada: 6.15 GB

# %% [markdown]
# #### XGBoost

# %%
xgb = XGBClassifier(random_state=random_state, n_jobs=-1)
xgb.fit(np.asarray(X_train_SS), y_train); #DataFrame Problems
y_pred_xgb_train = xgb.predict(np.asarray(X_train_SS))
y_pred_xgb_test  = xgb.predict(np.asarray(X_test_SS))
Memory()
# Out:
# Memoria actual utilizada: 6.15 GB

# %% [markdown]
# **Resultados**

# %%
Entrenamiento = get_metrics(y_train, y_pred_xgb_train).T
Evaluacion    = get_metrics(y_test, y_pred_xgb_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.844537
# Balanced Accuracy  0.503435
# Precision          0.873587
# Recall             0.007059
# F1-Score           0.014005
# AUC_ROC            0.503435
#
# Evaluacion
#                       Valor
# Accuracy           0.843967
# Balanced Accuracy  0.503338
# Precision          0.859504
# Recall             0.006887
# F1-Score           0.013664
# AUC_ROC            0.503338

# %%
PlotHM(y_train, y_pred_xgb_train, y_test, y_pred_xgb_test,
       Title='XGBoost - Standard Scaler', normalize=None)

# %% [markdown]
# **Feature Importance**

# %%
FI_xgb = pd.DataFrame({'Feature':X_train_SS.columns,
                       'Importancia':xgb.feature_importances_
                      })
FI_xgb.sort_values(by='Importancia', ascending=False, inplace=True)
FI_xgb.reset_index(inplace=True, drop=True)
FI_xgb['Acumulada'] = FI_xgb.Importancia.cumsum()
thresh = 0.7
lim    = FI_xgb.Acumulada <= thresh
print('Cantidad de features para llegar al {:0}%: {} (=={:.2f} %)'.format(
        thresh*100, lim.sum(), 100*lim.sum()/len(X_train_SS.columns)))

display(FI_rfc)

plt.figure(figsize=(10,7), dpi=100)
plt.title('Feature Importance - XGBoost \n (25 primeros)')
sns.barplot(x=FI_xgb.Importancia[lim][:25], y=FI_xgb.Feature[lim][:25], 
            orient='h')
plt.show()

# %%
del xgb
Memory()
# Out:
# Memoria actual utilizada: 6.15 GB

# %% [markdown]
# #### Resumen de modelos sin hiperparámetros (Standard Scaler)

# %%
models = ['DTC', 'RFC', 'Logistic Regression',
          'Gaussian Naive Bayes', 'SGD', 'Perceptron', 'XGBoost']

# %%
predictions_train = [y_pred_dtc_train, y_pred_rfc_train,
                     y_pred_lrc_train, y_pred_gnbc_train,
                     y_pred_sgdc_train, y_pred_pct_train,
                     y_pred_xgb_train]
print('Conjunto de Entrenamiento:')
get_metrics_comparison(y_train, predictions_train, models)
print('------------------------------------------------------------------------')
predictions_test = [y_pred_dtc_test, y_pred_rfc_test,
                    y_pred_lrc_test, y_pred_gnbc_test,
                    y_pred_sgdc_test, y_pred_pct_test,
                    y_pred_xgb_test]
print('Conjunto de Evaluación:')
get_metrics_comparison(y_test, predictions_test, models)
# Out:
# Conjunto de Entrenamiento:
# <style  type="text/css" >
#     #T_6429f9f8_ec8d_11ea_a3dc_0242ac1c0002row0_col0 {
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_6429f9f8_ec8d_11ea_a3dc_0242ac1c0002row0_col1 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_6429f9f8_ec8d_11ea_a3dc_0242ac1c0002row0_col2 {
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_6429f9f8_ec8d_11ea_a3dc_0242ac1c0002row0_col3 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_6429f9f8_ec8d_11ea_a3dc_0242ac1c0002row0_col4 {
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_6429f9f8_ec8d_11ea_a3dc_0242ac1c0002row0_col5 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_6429f9f8_ec8d_11ea_a3dc_0242ac1c0002row1_col0 {
#             background-color:  #75c477;
# ...

# %%
del predictions_train, predictions_test
Memory()
# Out:
# Memoria actual utilizada: 6.15 GB

# %% [markdown]
# ### MinMax Scaler

# %%
X_train_MM = X_train.drop(Numericas + SS_cols, axis=1)
X_test_MM  = X_test.drop(Numericas + SS_cols, axis=1)
print('Tamaño X_train_MM:', X_train_MM.shape)
print('Tamaño X_test_MM:', X_test_MM.shape)
Memory()
# Out:
# Tamaño X_train_MM: (769835, 113)
# Tamaño X_test_MM: (192459, 113)
# Memoria actual utilizada: 6.15 GB

# %% [markdown]
# #### Decision Tree

# %%
dtc = DecisionTreeClassifier(random_state=random_state)
dtc.fit(X_train_MM, y_train);
y_pred_dtc_train = dtc.predict(X_train_MM)
y_pred_dtc_test  = dtc.predict(X_test_MM)
Memory()
# Out:
# Memoria actual utilizada: 6.15 GB

# %% [markdown]
# **Resultados**

# %%
Entrenamiento = get_metrics(y_train, y_pred_dtc_train).T
Evaluacion    = get_metrics(y_test, y_pred_dtc_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.999189
# Balanced Accuracy  0.997436
# Precision          0.999933
# Recall             0.994884
# F1-Score           0.997402
# AUC_ROC            0.997436
#
# Evaluacion
#                       Valor
# Accuracy           0.756888
# Balanced Accuracy  0.561711
# Precision          0.251223
# Recall             0.277248
# F1-Score           0.263594
# AUC_ROC            0.561711

# %%
PlotHM(y_train, y_pred_dtc_train, y_test, y_pred_dtc_test,
       Title='Decision Tree Classifier - MinMax Scaler', normalize=None)

# %%
del dtc
Memory()
# Out:
# Memoria actual utilizada: 6.15 GB

# %% [markdown]
# #### Random Forest

# %%
rfc = RandomForestClassifier(random_state=random_state, n_jobs=-1)
rfc.fit(X_train_MM, y_train);
y_pred_rfc_train = rfc.predict(X_train_MM)
y_pred_rfc_test  = rfc.predict(X_test_MM)
Memory()
# Out:
# Memoria actual utilizada: 6.29 GB

# %% [markdown]
# **Resulados**

# %%
Entrenamiento = get_metrics(y_train, y_pred_rfc_train).T
Evaluacion    = get_metrics(y_test, y_pred_rfc_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.999170
# Balanced Accuracy  0.997678
# Precision          0.999183
# Recall             0.995507
# F1-Score           0.997342
# AUC_ROC            0.997678
#
# Evaluacion
#                       Valor
# Accuracy           0.842876
# Balanced Accuracy  0.520071
# Precision          0.494063
# Recall             0.049596
# F1-Score           0.090143
# AUC_ROC            0.520071

# %%
PlotHM(y_train, y_pred_rfc_train, y_test, y_pred_rfc_test,
       Title='Random Forest Classifier - MinMax Scaler', normalize=None)

# %%
del rfc
Memory()
# Out:
# Memoria actual utilizada: 6.29 GB

# %% [markdown]
# #### Logistic Regression

# %%
lrc = LogisticRegression(max_iter=1000, random_state=random_state, n_jobs=None)
lrc.fit(X_train_MM, y_train);
y_pred_lrc_train = lrc.predict(X_train_MM)
y_pred_lrc_test  = lrc.predict(X_test_MM)
Memory()
# Out:
# Memoria actual utilizada: 6.29 GB

# %% [markdown]
# **Resultados**

# %%
Entrenamiento = get_metrics(y_train, y_pred_lrc_train).T
Evaluacion    = get_metrics(y_test, y_pred_lrc_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.844070
# Balanced Accuracy  0.503230
# Precision          0.633916
# Recall             0.007234
# F1-Score           0.014304
# AUC_ROC            0.503230
#
# Evaluacion
#                       Valor
# Accuracy           0.843442
# Balanced Accuracy  0.503081
# Precision          0.603989
# Recall             0.007019
# F1-Score           0.013877
# AUC_ROC            0.503081

# %%
PlotHM(y_train, y_pred_lrc_train, y_test, y_pred_lrc_test,
       Title='Logistic Regression - MinMax Scaler', normalize=None)

# %%
del lrc
Memory()
# Out:
# Memoria actual utilizada: 6.29 GB

# %% [markdown]
# #### Gaussian Naive Bayes

# %%
gnbc = GaussianNB()
gnbc.fit(X_train_MM, y_train);
y_pred_gnbc_train = gnbc.predict(X_train_MM)
y_pred_gnbc_test  = gnbc.predict(X_test_MM)
Memory()
# Out:
# Memoria actual utilizada: 6.29 GB

# %% [markdown]
# **Resultados**

# %%
Entrenamiento = get_metrics(y_train, y_pred_gnbc_train).T
Evaluacion    = get_metrics(y_test, y_pred_gnbc_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.395881
# Balanced Accuracy  0.607958
# Precision          0.195198
# Recall             0.916575
# F1-Score           0.321853
# AUC_ROC            0.607958
#
# Evaluacion
#                       Valor
# Accuracy           0.395679
# Balanced Accuracy  0.607372
# Precision          0.195601
# Recall             0.915905
# F1-Score           0.322358
# AUC_ROC            0.607372

# %%
PlotHM(y_train, y_pred_gnbc_train, y_test, y_pred_gnbc_test,
       Title='Gaussian Naive Bayes - MinMax Scaler', normalize=None)

# %%
del gnbc
Memory()
# Out:
# Memoria actual utilizada: 6.29 GB

# %% [markdown]
# #### SGD Classifier

# %%
sgdc = SGDClassifier(random_state=random_state, n_jobs=-1)
sgdc.fit(X_train_MM, y_train);
y_pred_sgdc_train = sgdc.predict(X_train_MM)
y_pred_sgdc_test  = sgdc.predict(X_test_MM)
Memory()
# Out:
# Memoria actual utilizada: 6.29 GB

# %% [markdown]
# **Resultados**

# %%
Entrenamiento = get_metrics(y_train, y_pred_sgdc_train).T
Evaluacion    = get_metrics(y_test, y_pred_sgdc_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.843965
# Balanced Accuracy  0.503397
# Precision          0.590195
# Recall             0.007798
# F1-Score           0.015394
# AUC_ROC            0.503397
#
# Evaluacion
#                       Valor
# Accuracy           0.843338
# Balanced Accuracy  0.503235
# Precision          0.565757
# Recall             0.007549
# F1-Score           0.014899
# AUC_ROC            0.503235

# %%
PlotHM(y_train, y_pred_sgdc_train, y_test, y_pred_sgdc_test,
       Title='SGD Classifier - MinMax Scaler', normalize=None)

# %%
del sgdc
Memory()
# Out:
# Memoria actual utilizada: 6.29 GB

# %% [markdown]
# #### Perceptron

# %%
pct = Perceptron(random_state=random_state)
pct.fit(X_train_MM, y_train);
y_pred_pct_train = pct.predict(X_train_MM)
y_pred_pct_test  = pct.predict(X_test_MM)
Memory()
# Out:
# Memoria actual utilizada: 6.29 GB

# %% [markdown]
# **Resultados**

# %%
Entrenamiento = get_metrics(y_train, y_pred_pct_train).T
Evaluacion    = get_metrics(y_test, y_pred_pct_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.561075
# Balanced Accuracy  0.586665
# Precision          0.204284
# Recall             0.623904
# F1-Score           0.307789
# AUC_ROC            0.586665
#
# Evaluacion
#                       Valor
# Accuracy           0.562546
# Balanced Accuracy  0.587913
# Precision          0.205743
# Recall             0.624884
# F1-Score           0.309562
# AUC_ROC            0.587913

# %%
PlotHM(y_train, y_pred_pct_train, y_test, y_pred_pct_test,
       Title='Perceptron - MinMax Scaler', normalize=None)

# %%
del pct
Memory()
# Out:
# Memoria actual utilizada: 6.29 GB

# %% [markdown]
# #### XGBoost

# %%
xgb = XGBClassifier(random_state=random_state, n_jobs=-1)
xgb.fit(np.asarray(X_train_MM), y_train);
y_pred_xgb_train = xgb.predict(np.asarray(X_train_MM))
y_pred_xgb_test  = xgb.predict(np.asarray(X_test_MM))
Memory()
# Out:
# Memoria actual utilizada: 6.29 GB

# %% [markdown]
# **Resultados**

# %%
Entrenamiento = get_metrics(y_train, y_pred_xgb_train).T
Evaluacion    = get_metrics(y_test, y_pred_xgb_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.844537
# Balanced Accuracy  0.503435
# Precision          0.873587
# Recall             0.007059
# F1-Score           0.014005
# AUC_ROC            0.503435
#
# Evaluacion
#                       Valor
# Accuracy           0.843967
# Balanced Accuracy  0.503338
# Precision          0.859504
# Recall             0.006887
# F1-Score           0.013664
# AUC_ROC            0.503338

# %%
PlotHM(y_train, y_pred_xgb_train, y_test, y_pred_xgb_test,
       Title='XGBoost - MinMax Scaler', normalize=None)

# %%
del xgb
Memory()
# Out:
# Memoria actual utilizada: 6.29 GB

# %% [markdown]
# #### Resumen de modelos sin hiperparámetros (MinMax Scaler)

# %%
models = ['DTC', 'RFC', 'Logistic Regression',
          'Gaussian Naive Bayes', 'SGD', 'Perceptron', 'XGBoost']

# %%
predictions_train = [y_pred_dtc_train, y_pred_rfc_train,
                     y_pred_lrc_train, y_pred_gnbc_train,
                     y_pred_sgdc_train, y_pred_pct_train,
                     y_pred_xgb_train]
print('Conjunto de Entrenamiento:')
get_metrics_comparison(y_train, predictions_train, models)
print('------------------------------------------------------------------------')
predictions_test = [y_pred_dtc_test, y_pred_rfc_test,
                    y_pred_lrc_test, y_pred_gnbc_test,
                    y_pred_sgdc_test, y_pred_pct_test,
                    y_pred_xgb_test]
print('Conjunto de Evaluación:')
get_metrics_comparison(y_test, predictions_test, models)
# Out:
# Conjunto de Entrenamiento:
# <style  type="text/css" >
#     #T_dd9f97f6_ec8e_11ea_a3dc_0242ac1c0002row0_col0 {
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_dd9f97f6_ec8e_11ea_a3dc_0242ac1c0002row0_col1 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_dd9f97f6_ec8e_11ea_a3dc_0242ac1c0002row0_col2 {
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_dd9f97f6_ec8e_11ea_a3dc_0242ac1c0002row0_col3 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_dd9f97f6_ec8e_11ea_a3dc_0242ac1c0002row0_col4 {
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_dd9f97f6_ec8e_11ea_a3dc_0242ac1c0002row0_col5 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_dd9f97f6_ec8e_11ea_a3dc_0242ac1c0002row1_col0 {
#             background-color:  #75c477;
# ...

# %%
del predictions_train, predictions_test
Memory()
# Out:
# Memoria actual utilizada: 6.29 GB

# %% [markdown]
# ## Entrenamiento de modelos con hiperparámetros variados

# %% [markdown]
# Se analizarán el modelo con mejor _Recall_ y el modelo con mejor _Recall_Weighted_ de cada estudio, ya que es lo que se intenta optimizar en este proyecto. (Minimizar predicciones de _Atendido_ que eran _Ausente_)

# %%
scoring = ['accuracy', 'balanced_accuracy', 'precision', 'precision_weighted', 'recall', 'recall_weighted', 'f1', 'f1_weighted']
Memory()
# Out:
# Memoria actual utilizada: 6.29 GB

# %% [markdown]
# ### Sin escalado

# %% [markdown]
# #### Decision Tree (Hyperparameter tuning)

# %%
#Modelo
dtc = DecisionTreeClassifier(random_state=random_state)

# %%
#Grid
params_dtc = {
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'max_depth': [5, 10, 20, 35, 55, 75, 90, 110, None]}

# %%
#Entrenamiento
dtc_rcv = GridSearchCV(dtc, params_dtc, scoring=scoring, cv=3, refit=False, n_jobs=-1)
dtc_rcv.fit(X_train_SE, y_train);
Memory()
# Out:
# Memoria actual utilizada: 6.29 GB

# %%
#Guardado de resultados
dtc_rcv_results = pd.DataFrame(dtc_rcv.cv_results_)
del dtc_rcv

#Nos quedamos con las columnas que nos interesan
dtc_rcv_results = dtc_rcv_results[['param_splitter', 'param_max_depth', 'param_criterion', 'params',
    'mean_test_accuracy', 'rank_test_accuracy',
    'mean_test_balanced_accuracy', 'rank_test_balanced_accuracy',
    'mean_test_precision', 'rank_test_precision', 
    'mean_test_precision_weighted', 'rank_test_precision_weighted', 
    'mean_test_recall', 'rank_test_recall', 
    'mean_test_recall_weighted', 'rank_test_recall_weighted',
    'mean_test_f1', 'rank_test_f1',
    'mean_test_f1_weighted', 'rank_test_f1_weighted']]

#Renombramos columnas
dtc_rcv_results.columns = ['splitter', 'max_depth', 'criterion', 'params',
    'accuracy', 'rank_ac',
    'balanced_accuracy', 'rank_bal_acc',
    'precision', 'rank_prec', 
    'precision_weighted', 'rank_prec_we', 
    'recall', 'rank_recall', 
    'recall_weighted', 'rank_rec_we',
    'f1', 'rank_f1',
    'f1_weighted', 'rank_f1_we']

#Agregamos métrica "promedio"
dtc_rcv_results['overall'] = dtc_rcv_results.eval(
    '(accuracy + balanced_accuracy + ' \
    'precision + precision_weighted + ' \
    'recall + recall_weighted + ' \
    'f1 + f1_weighted)*0.125')
dtc_rcv_results['rank_ov'] = dtc_rcv_results.overall.rank(method='min', ascending=False).astype(int)

#Veamos la tabla ordenada
dtc_rcv_results = dtc_rcv_results.sort_values(by=['rank_ov'], ascending=True).reset_index(drop=True)
print('Resultados GridSearch')
display(dtc_rcv_results)
Memory()
# Out:
# Resultados GridSearch
#    splitter max_depth criterion  \
# 0    random         5      gini
# 1      best         5      gini
# 2      best        10   entropy
# 3    random        10   entropy
# 4    random         5   entropy
# ..      ...       ...       ...
# 31   random        20   entropy
# 32   random        20      gini
# 33     best        20      gini
# 34     best        20   entropy
# 35     best         5   entropy
#
#                                                params  accuracy  rank_ac  \
# 0   {'criterion': 'gini', 'max_depth': 5, 'splitte...  0.843947        6
# 1   {'criterion': 'gini', 'max_depth': 5, 'splitte...  0.843982        5
# 2   {'criterion': 'entropy', 'max_depth': 10, 'spl...  0.844413        2
# 3   {'criterion': 'entropy', 'max_depth': 10, 'spl...  0.844559        1
# 4   {'criterion': 'entropy', 'max_depth': 5, 'spli...  0.843829        7
# ..                                                ...       ...      ...
# ...

# %%
#Selección de modelos
dtc_cv_params_re = dtc_rcv_results.loc[dtc_rcv_results.recall.idxmax()].params
dtc_cv_params_rw = dtc_rcv_results.loc[dtc_rcv_results.recall_weighted.idxmax()].params
#Vistazo
pd.DataFrame([dtc_rcv_results.loc[dtc_rcv_results.recall.idxmax()], dtc_rcv_results.loc[dtc_rcv_results.recall_weighted.idxmax()]])
# Out:
#    splitter  max_depth criterion  \
# 13     best         90      gini
# 3    random         10   entropy
#
#                                                params  accuracy  rank_ac  \
# 13  {'criterion': 'gini', 'max_depth': 90, 'splitt...  0.754685       32
# 3   {'criterion': 'entropy', 'max_depth': 10, 'spl...  0.844559        1
#
#     balanced_accuracy  rank_bal_acc  precision  rank_prec  precision_weighted  \
# 13           0.558417             6   0.244877         26            0.765698
# 3            0.508400            30   0.597267          5            0.806945
#
#     rank_prec_we    recall  rank_recall  recall_weighted  rank_rec_we  \
# 13            15  0.272806            1         0.754685           32
# 3              5  0.019218           30         0.844559            1
#
#           f1  rank_f1  f1_weighted  rank_f1_we   overall  rank_ov
# 13  0.258088        5     0.759991          32  0.546156       14
# ...

# %% [markdown]
# **Recall**

# %%
dtc_opt = DecisionTreeClassifier(**dtc_cv_params_re, random_state=random_state)
dtc_opt.fit(X_train_SE, y_train);
y_pred_dtc_opt_train_re = dtc_opt.predict(X_train_SE)
y_pred_dtc_opt_test_re  = dtc_opt.predict(X_test_SE)
Memory()
# Out:
# Memoria actual utilizada: 6.29 GB

# %% [markdown]
# Resultados

# %%
Entrenamiento = get_metrics(y_train, y_pred_dtc_opt_train_re).T
Evaluacion    = get_metrics(y_test, y_pred_dtc_opt_test_re).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.999189
# Balanced Accuracy  0.997436
# Precision          0.999933
# Recall             0.994884
# F1-Score           0.997402
# AUC_ROC            0.997436
#
# Evaluacion
#                       Valor
# Accuracy           0.756649
# Balanced Accuracy  0.561489
# Precision          0.250787
# Recall             0.277049
# F1-Score           0.263265
# AUC_ROC            0.561489

# %%
PlotHM(y_train, y_pred_dtc_opt_train_re, y_test, y_pred_dtc_opt_test_re,
       Title='Decision Tree Classifier - Sin escalado\n Modelo "Recall"', normalize=None)

# %%
del dtc_opt
Memory()
# Out:
# Memoria actual utilizada: 6.29 GB

# %% [markdown]
# **Recall_Weighted**

# %%
dtc_opt = DecisionTreeClassifier(**dtc_cv_params_rw, random_state=random_state)
dtc_opt.fit(X_train_SE, y_train);
y_pred_dtc_opt_train_rw = dtc_opt.predict(X_train_SE)
y_pred_dtc_opt_test_rw  = dtc_opt.predict(X_test_SE)
Memory()
# Out:
# Memoria actual utilizada: 6.29 GB

# %% [markdown]
# Resultados

# %%
Entrenamiento = get_metrics(y_train, y_pred_dtc_opt_train_rw).T
Evaluacion    = get_metrics(y_test, y_pred_dtc_opt_test_rw).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.845637
# Balanced Accuracy  0.510145
# Precision          0.712244
# Recall             0.021934
# F1-Score           0.042557
# AUC_ROC            0.510145
#
# Evaluacion
#                       Valor
# Accuracy           0.844091
# Balanced Accuracy  0.508316
# Precision          0.604651
# Recall             0.018938
# F1-Score           0.036726
# AUC_ROC            0.508316

# %%
PlotHM(y_train, y_pred_dtc_opt_train_rw, y_test, y_pred_dtc_opt_test_rw,
       Title='Decision Tree Classifier - Sin escalado\n Modelo "Recall_Weighted"', normalize=None)

# %%
del dtc_opt
Memory()
# Out:
# Memoria actual utilizada: 6.29 GB

# %% [markdown]
# #### Random Forest

# %%
#Parámetros
rf_params = {'criterion': 'entropy', 'n_estimators': 200, 'max_features': 'auto', 'max_depth': 50}

# %%
#Modelo
rf_opt = RandomForestClassifier(**rf_params, random_state=random_state, n_jobs=-1)

# %%
#Entrenamiento
rf_opt.fit(X_train_SE, y_train);
y_pred_rf_opt_train = rf_opt.predict(X_train_SE)
y_pred_rf_opt_test  = rf_opt.predict(X_test_SE)
Memory()
# Out:
# Memoria actual utilizada: 9.57 GB

# %% [markdown]
# Resultados

# %%
Entrenamiento = get_metrics(y_train, y_pred_rf_opt_train).T
Evaluacion    = get_metrics(y_test, y_pred_rf_opt_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.999188
# Balanced Accuracy  0.997621
# Precision          0.999466
# Recall             0.995341
# F1-Score           0.997399
# AUC_ROC            0.997621
#
# Evaluacion
#                       Valor
# Accuracy           0.842850
# Balanced Accuracy  0.518789
# Precision          0.492804
# Recall             0.046484
# F1-Score           0.084954
# AUC_ROC            0.518789

# %%
PlotHM(y_train, y_pred_rf_opt_train, y_test, y_pred_rf_opt_test,
       Title='Random Forest Classifier - Sin escalado\n  Diff Params', normalize=None)

# %%
del rf_opt
Memory()
# Out:
# Memoria actual utilizada: 9.57 GB

# %% [markdown]
# #### XGBoost

# %%
#Parámetros
xgb_params = {'learning_rate': 0.1, 'max_depth': 5, 'alpha': 10, 'n_estimators': 10}

# %%
#Modelo
xgb_opt = XGBClassifier(**xgb_params, random_state=random_state, n_jobs=-1)

# %%
#Entrenamiento
xgb_opt.fit(np.asarray(X_train_SE), y_train);
y_pred_xgb_opt_train = xgb_opt.predict(np.asarray(X_train_SE))
y_pred_xgb_opt_test  = xgb_opt.predict(np.asarray(X_test_SE))
Memory()
# Out:
# Memoria actual utilizada: 10.21 GB

# %% [markdown]
# Resultados

# %%
Entrenamiento = get_metrics(y_train, y_pred_xgb_opt_train).T
Evaluacion    = get_metrics(y_test, y_pred_xgb_opt_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.843841
# Balanced Accuracy  0.500793
# Precision          1.000000
# Recall             0.001586
# F1-Score           0.003168
# AUC_ROC            0.500793
#
# Evaluacion
#                       Valor
# Accuracy           0.843219
# Balanced Accuracy  0.500497
# Precision          1.000000
# Recall             0.000993
# F1-Score           0.001985
# AUC_ROC            0.500497

# %%
PlotHM(y_train, y_pred_xgb_opt_train, y_test, y_pred_xgb_opt_test,
       Title='XGBoost - Sin escalado\n Diff Params', normalize=None)

# %%
del xgb_opt
Memory()
# Out:
# Memoria actual utilizada: 10.21 GB

# %% [markdown]
# #### Resumen de modelos con hiperparámetros (Sin escalado)

# %%
models = ['DTC "Recall"', 'DTC "Recall_Weighted"', 'RFC', 'XGBoost']

# %%
predictions_train = [y_pred_dtc_opt_train_re, y_pred_dtc_opt_train_rw, y_pred_rf_opt_train, y_pred_xgb_opt_train]
print('Conjunto de Entrenamiento:')
get_metrics_comparison(y_train, predictions_train, models)
print('------------------------------------------------------------------------')
predictions_test = [y_pred_dtc_opt_test_re, y_pred_dtc_opt_test_rw, y_pred_rf_opt_test, y_pred_xgb_opt_test]
print('Conjunto de Evaluación:')
get_metrics_comparison(y_test, predictions_test, models)
# Out:
# Conjunto de Entrenamiento:
# <style  type="text/css" >
#     #T_30d54836_ec93_11ea_a3dc_0242ac1c0002row0_col0 {
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_30d54836_ec93_11ea_a3dc_0242ac1c0002row0_col1 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_30d54836_ec93_11ea_a3dc_0242ac1c0002row0_col2 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_30d54836_ec93_11ea_a3dc_0242ac1c0002row0_col3 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_30d54836_ec93_11ea_a3dc_0242ac1c0002row0_col4 {
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_30d54836_ec93_11ea_a3dc_0242ac1c0002row0_col5 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_30d54836_ec93_11ea_a3dc_0242ac1c0002row1_col0 {
#             background-color:  #f6fcf4;
# ...

# %%
del predictions_train, predictions_test
Memory()
# Out:
# Memoria actual utilizada: 10.21 GB

# %% [markdown]
# ### Standard Scaler

# %% [markdown]
# #### Decision Tree (Hyperparameter tuning)

# %%
#Modelo
dtc = DecisionTreeClassifier(random_state=random_state)

# %%
#Grid
params_dtc = {
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'max_depth': [5, 10, 20, 35, 55, 75, 90, 110, None]}

# %%
#Entrenamiento
dtc_rcv = GridSearchCV(dtc, params_dtc, scoring=scoring, cv=3, refit=False, n_jobs=-1)
dtc_rcv.fit(X_train_SS, y_train);
Memory()
# Out:
# Memoria actual utilizada: 8.48 GB

# %%
#Guardado de resultados
dtc_rcv_results = pd.DataFrame(dtc_rcv.cv_results_)
del dtc_rcv

#Nos quedamos con las columnas que nos interesan
dtc_rcv_results = dtc_rcv_results[['param_splitter', 'param_max_depth', 'param_criterion', 'params',
    'mean_test_accuracy', 'rank_test_accuracy',
    'mean_test_balanced_accuracy', 'rank_test_balanced_accuracy',
    'mean_test_precision', 'rank_test_precision', 
    'mean_test_precision_weighted', 'rank_test_precision_weighted', 
    'mean_test_recall', 'rank_test_recall', 
    'mean_test_recall_weighted', 'rank_test_recall_weighted',
    'mean_test_f1', 'rank_test_f1',
    'mean_test_f1_weighted', 'rank_test_f1_weighted']]

#Renombramos columnas
dtc_rcv_results.columns = ['splitter', 'max_depth', 'criterion', 'params',
    'accuracy', 'rank_ac',
    'balanced_accuracy', 'rank_bal_acc',
    'precision', 'rank_prec', 
    'precision_weighted', 'rank_prec_we', 
    'recall', 'rank_recall', 
    'recall_weighted', 'rank_rec_we',
    'f1', 'rank_f1',
    'f1_weighted', 'rank_f1_we']

#Agregamos métrica "promedio"
dtc_rcv_results['overall'] = dtc_rcv_results.eval(
    '(accuracy + balanced_accuracy + ' \
    'precision + precision_weighted + ' \
    'recall + recall_weighted + ' \
    'f1 + f1_weighted)*0.125')
dtc_rcv_results['rank_ov'] = dtc_rcv_results.overall.rank(method='min', ascending=False).astype(int)

#Veamos la tabla ordenada
dtc_rcv_results = dtc_rcv_results.sort_values(by=['rank_ov'], ascending=True).reset_index(drop=True)
print('Resultados GridSearch')
display(dtc_rcv_results)
Memory()
# Out:
# Resultados GridSearch
#    splitter max_depth criterion  \
# 0    random         5      gini
# 1      best         5      gini
# 2    random         5   entropy
# 3    random        10   entropy
# 4      best        10   entropy
# ..      ...       ...       ...
# 31   random        20      gini
# 32   random        20   entropy
# 33     best        20      gini
# 34     best        20   entropy
# 35     best         5   entropy
#
#                                                params  accuracy  rank_ac  \
# 0   {'criterion': 'gini', 'max_depth': 5, 'splitte...  0.843951        6
# 1   {'criterion': 'gini', 'max_depth': 5, 'splitte...  0.843982        5
# 2   {'criterion': 'entropy', 'max_depth': 5, 'spli...  0.843830        7
# 3   {'criterion': 'entropy', 'max_depth': 10, 'spl...  0.844567        1
# 4   {'criterion': 'entropy', 'max_depth': 10, 'spl...  0.844421        2
# ..                                                ...       ...      ...
# ...

# %%
#Selección de modelos
dtc_cv_params_re = dtc_rcv_results.loc[dtc_rcv_results.recall.idxmax()].params
dtc_cv_params_rw = dtc_rcv_results.loc[dtc_rcv_results.recall_weighted.idxmax()].params
#Vistazo
pd.DataFrame([dtc_rcv_results.loc[dtc_rcv_results.recall.idxmax()], dtc_rcv_results.loc[dtc_rcv_results.recall_weighted.idxmax()]])
# Out:
#   splitter  max_depth criterion  \
# 7   random         55      gini
# 3   random         10   entropy
#
#                                               params  accuracy  rank_ac  \
# 7  {'criterion': 'gini', 'max_depth': 55, 'splitt...  0.755963       27
# 3  {'criterion': 'entropy', 'max_depth': 10, 'spl...  0.844567        1
#
#    balanced_accuracy  rank_bal_acc  precision  rank_prec  precision_weighted  \
# 7           0.559486             1   0.247038         14            0.766303
# 3           0.507630            31   0.610203          5            0.808795
#
#    rank_prec_we    recall  rank_recall  recall_weighted  rank_rec_we  \
# 7             9  0.273570            1         0.755963           27
# 3             5  0.017316           31         0.844567            1
#
#          f1  rank_f1  f1_weighted  rank_f1_we   overall  rank_ov
# 7  0.259628        1     0.760955          22  0.547363        8
# 3  0.033649       31     0.777560           7  0.555536        4

# %% [markdown]
# **Recall**

# %%
dtc_opt = DecisionTreeClassifier(**dtc_cv_params_re, random_state=random_state)
dtc_opt.fit(X_train_SS, y_train);
y_pred_dtc_opt_train_re = dtc_opt.predict(X_train_SS)
y_pred_dtc_opt_test_re  = dtc_opt.predict(X_test_SS)
Memory()
# Out:
# Memoria actual utilizada: 8.50 GB

# %% [markdown]
# Resultados

# %%
Entrenamiento = get_metrics(y_train, y_pred_dtc_opt_train_re).T
Evaluacion    = get_metrics(y_test, y_pred_dtc_opt_test_re).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.999097
# Balanced Accuracy  0.997195
# Precision          0.999800
# Recall             0.994427
# F1-Score           0.997106
# AUC_ROC            0.997195
#
# Evaluacion
#                       Valor
# Accuracy           0.756151
# Balanced Accuracy  0.559212
# Precision          0.247852
# Recall             0.272182
# F1-Score           0.259448
# AUC_ROC            0.559212

# %%
PlotHM(y_train, y_pred_dtc_opt_train_re, y_test, y_pred_dtc_opt_test_re,
       Title='Decision Tree Classifier - Standard Scaler\n Modelo "Recall"', normalize=None)

# %% [markdown]
# **Recall_Weighted**

# %%
dtc_opt = DecisionTreeClassifier(**dtc_cv_params_rw, random_state=random_state)
dtc_opt.fit(X_train_SS, y_train);
y_pred_dtc_opt_train_rw = dtc_opt.predict(X_train_SS)
y_pred_dtc_opt_test_rw  = dtc_opt.predict(X_test_SS)
Memory()
# Out:
# Memoria actual utilizada: 8.51 GB

# %% [markdown]
# Resultados

# %%
Entrenamiento = get_metrics(y_train, y_pred_dtc_opt_train_rw).T
Evaluacion    = get_metrics(y_test, y_pred_dtc_opt_test_rw).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.845634
# Balanced Accuracy  0.510218
# Precision          0.709377
# Recall             0.022116
# F1-Score           0.042896
# AUC_ROC            0.510218
#
# Evaluacion
#                       Valor
# Accuracy           0.844138
# Balanced Accuracy  0.508600
# Precision          0.606154
# Recall             0.019567
# F1-Score           0.037910
# AUC_ROC            0.508600

# %%
PlotHM(y_train, y_pred_dtc_opt_train_rw, y_test, y_pred_dtc_opt_test_rw,
       Title='Decision Tree Classifier - Standard Scaler\n Modelo "Recall_Weighted"', normalize=None)

# %%
del dtc_opt
Memory()
# Out:
# Memoria actual utilizada: 8.51 GB

# %% [markdown]
# #### Random Forest

# %%
#Parámetros
rf_params = {'criterion': 'entropy', 'n_estimators': 200, 'max_features': 'auto', 'max_depth': 50}

# %%
#Modelo
rf_opt = RandomForestClassifier(**rf_params, random_state=random_state, n_jobs=-1)

# %%
#Entrenamiento
rf_opt.fit(X_train_SS, y_train);
y_pred_rf_opt_train = rf_opt.predict(X_train_SS)
y_pred_rf_opt_test  = rf_opt.predict(X_test_SS)
Memory()
# Out:
# Memoria actual utilizada: 10.02 GB

# %% [markdown]
# Resultados

# %%
Entrenamiento = get_metrics(y_train, y_pred_rf_opt_train).T
Evaluacion    = get_metrics(y_test, y_pred_rf_opt_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.999189
# Balanced Accuracy  0.997612
# Precision          0.999500
# Recall             0.995316
# F1-Score           0.997403
# AUC_ROC            0.997612
#
# Evaluacion
#                       Valor
# Accuracy           0.842829
# Balanced Accuracy  0.519006
# Precision          0.492206
# Recall             0.047047
# F1-Score           0.085884
# AUC_ROC            0.519006

# %%
PlotHM(y_train, y_pred_rf_opt_train, y_test, y_pred_rf_opt_test,
       Title='Random Forest Classifier - Standard Scaler\n Diff Params', normalize=None)

# %%
del rf_opt
Memory()
# Out:
# Memoria actual utilizada: 10.03 GB

# %% [markdown]
# #### XGBoost

# %%
#Parámetros
xgb_params = {'learning_rate': 0.1, 'max_depth': 5, 'alpha': 10, 'n_estimators': 10}

# %%
#Modelo
xgb_opt = XGBClassifier(**xgb_params, random_state=random_state, n_jobs=-1)

# %%
#Entrenamiento
xgb_opt.fit(np.asarray(X_train_SS), y_train);
y_pred_xgb_opt_train = xgb_opt.predict(np.asarray(X_train_SS))
y_pred_xgb_opt_test  = xgb_opt.predict(np.asarray(X_test_SS))
Memory()
# Out:
# Memoria actual utilizada: 10.17 GB

# %% [markdown]
# Resultados

# %%
Entrenamiento = get_metrics(y_train, y_pred_xgb_opt_train).T
Evaluacion    = get_metrics(y_test, y_pred_xgb_opt_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.843841
# Balanced Accuracy  0.500793
# Precision          1.000000
# Recall             0.001586
# F1-Score           0.003168
# AUC_ROC            0.500793
#
# Evaluacion
#                       Valor
# Accuracy           0.843219
# Balanced Accuracy  0.500497
# Precision          1.000000
# Recall             0.000993
# F1-Score           0.001985
# AUC_ROC            0.500497

# %%
PlotHM(y_train, y_pred_xgb_opt_train, y_test, y_pred_xgb_opt_test,
       Title='XGBoost - Standard Scaler\n Diff Params', normalize=None)

# %%
del xgb_opt
Memory()
# Out:
# Memoria actual utilizada: 10.17 GB

# %% [markdown]
# #### Resumen de modelos con hiperparámetros (Standard Scaler)

# %%
models = ['DTC "Recall"', 'DTC "Recall_Weighted"', 'Random Forest', 'XGBoost']

# %%
predictions_train = [y_pred_dtc_opt_train_re, y_pred_dtc_opt_train_rw, y_pred_rf_opt_train, y_pred_xgb_opt_train]
print('Conjunto de Entrenamiento:')
get_metrics_comparison(y_train, predictions_train, models)
print('------------------------------------------------------------------------')
predictions_test = [y_pred_dtc_opt_test_re, y_pred_dtc_opt_test_rw, y_pred_rf_opt_test, y_pred_xgb_opt_test]
print('Conjunto de Evaluación:')
get_metrics_comparison(y_test, predictions_test, models)
# Out:
# Conjunto de Entrenamiento:
# <style  type="text/css" >
#     #T_d6bcd990_ec97_11ea_a3dc_0242ac1c0002row0_col0 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_d6bcd990_ec97_11ea_a3dc_0242ac1c0002row0_col1 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_d6bcd990_ec97_11ea_a3dc_0242ac1c0002row0_col2 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_d6bcd990_ec97_11ea_a3dc_0242ac1c0002row0_col3 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_d6bcd990_ec97_11ea_a3dc_0242ac1c0002row0_col4 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_d6bcd990_ec97_11ea_a3dc_0242ac1c0002row0_col5 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_d6bcd990_ec97_11ea_a3dc_0242ac1c0002row1_col0 {
#             background-color:  #f6fcf4;
# ...

# %%
del predictions_train, predictions_test
Memory()
# Out:
# Memoria actual utilizada: 10.17 GB

# %% [markdown]
# ### MinMax Scaler

# %% [markdown]
# #### Decision Tree (Hyperparameter tuning)

# %%
#Modelo
dtc = DecisionTreeClassifier(random_state=random_state)

# %%
#Grid
params_dtc = {
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'max_depth': [5, 10, 20, 35, 55, 75, 90, 110, None]}

# %%
#Entrenamiento
dtc_rcv = GridSearchCV(dtc, params_dtc, scoring=scoring, cv=3, refit=False, n_jobs=-1)
dtc_rcv.fit(X_train_MM, y_train);
Memory()
# Out:
# Memoria actual utilizada: 8.65 GB

# %%
#Guardado de resultados
dtc_rcv_results = pd.DataFrame(dtc_rcv.cv_results_)
del dtc_rcv

#Nos quedamos con las columnas que nos interesan
dtc_rcv_results = dtc_rcv_results[['param_splitter', 'param_max_depth', 'param_criterion', 'params',
    'mean_test_accuracy', 'rank_test_accuracy',
    'mean_test_balanced_accuracy', 'rank_test_balanced_accuracy',
    'mean_test_precision', 'rank_test_precision', 
    'mean_test_precision_weighted', 'rank_test_precision_weighted', 
    'mean_test_recall', 'rank_test_recall', 
    'mean_test_recall_weighted', 'rank_test_recall_weighted',
    'mean_test_f1', 'rank_test_f1',
    'mean_test_f1_weighted', 'rank_test_f1_weighted']]

#Renombramos columnas
dtc_rcv_results.columns = ['splitter', 'max_depth', 'criterion', 'params',
    'accuracy', 'rank_ac',
    'balanced_accuracy', 'rank_bal_acc',
    'precision', 'rank_prec', 
    'precision_weighted', 'rank_prec_we', 
    'recall', 'rank_recall', 
    'recall_weighted', 'rank_rec_we',
    'f1', 'rank_f1',
    'f1_weighted', 'rank_f1_we']

#Agregamos métrica "promedio"
dtc_rcv_results['overall'] = dtc_rcv_results.eval(
    '(accuracy + balanced_accuracy + ' \
    'precision + precision_weighted + ' \
    'recall + recall_weighted + ' \
    'f1 + f1_weighted)*0.125')
dtc_rcv_results['rank_ov'] = dtc_rcv_results.overall.rank(method='min', ascending=False).astype(int)

#Veamos la tabla ordenada
dtc_rcv_results = dtc_rcv_results.sort_values(by=['rank_ov'], ascending=True).reset_index(drop=True)
print('Resultados GridSearch')
display(dtc_rcv_results)
Memory()
# Out:
# Resultados GridSearch
#    splitter max_depth criterion  \
# 0    random         5      gini
# 1      best         5      gini
# 2    random         5   entropy
# 3    random        10   entropy
# 4      best        10   entropy
# ..      ...       ...       ...
# 31   random        20      gini
# 32   random        20   entropy
# 33     best        20      gini
# 34     best        20   entropy
# 35     best         5   entropy
#
#                                                params  accuracy  rank_ac  \
# 0   {'criterion': 'gini', 'max_depth': 5, 'splitte...  0.843951        6
# 1   {'criterion': 'gini', 'max_depth': 5, 'splitte...  0.843982        5
# 2   {'criterion': 'entropy', 'max_depth': 5, 'spli...  0.843830        7
# 3   {'criterion': 'entropy', 'max_depth': 10, 'spl...  0.844567        1
# 4   {'criterion': 'entropy', 'max_depth': 10, 'spl...  0.844421        2
# ..                                                ...       ...      ...
# ...

# %%
#Selección de modelos
dtc_cv_params_re = dtc_rcv_results.loc[dtc_rcv_results.recall.idxmax()].params
dtc_cv_params_rw = dtc_rcv_results.loc[dtc_rcv_results.recall_weighted.idxmax()].params
#Vistazo
pd.DataFrame([dtc_rcv_results.loc[dtc_rcv_results.recall.idxmax()], dtc_rcv_results.loc[dtc_rcv_results.recall_weighted.idxmax()]])
# Out:
#   splitter  max_depth criterion  \
# 7   random         55      gini
# 3   random         10   entropy
#
#                                               params  accuracy  rank_ac  \
# 7  {'criterion': 'gini', 'max_depth': 55, 'splitt...  0.755963       27
# 3  {'criterion': 'entropy', 'max_depth': 10, 'spl...  0.844567        1
#
#    balanced_accuracy  rank_bal_acc  precision  rank_prec  precision_weighted  \
# 7           0.559486             1   0.247038         14            0.766303
# 3           0.507630            31   0.610203          5            0.808795
#
#    rank_prec_we    recall  rank_recall  recall_weighted  rank_rec_we  \
# 7             9  0.273570            1         0.755963           27
# 3             5  0.017316           31         0.844567            1
#
#          f1  rank_f1  f1_weighted  rank_f1_we   overall  rank_ov
# 7  0.259628        1     0.760955          18  0.547363        8
# 3  0.033649       31     0.777560           7  0.555536        4

# %% [markdown]
# **Recall**

# %%
dtc_opt = DecisionTreeClassifier(**dtc_cv_params_re, random_state=random_state)
dtc_opt.fit(X_train_MM, y_train);
y_pred_dtc_opt_train_re = dtc_opt.predict(X_train_MM)
y_pred_dtc_opt_test_re  = dtc_opt.predict(X_test_MM)
Memory()
# Out:
# Memoria actual utilizada: 8.65 GB

# %% [markdown]
# Resultados

# %%
Entrenamiento = get_metrics(y_train, y_pred_dtc_opt_train_re).T
Evaluacion    = get_metrics(y_test, y_pred_dtc_opt_test_re).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.999097
# Balanced Accuracy  0.997195
# Precision          0.999800
# Recall             0.994427
# F1-Score           0.997106
# AUC_ROC            0.997195
#
# Evaluacion
#                       Valor
# Accuracy           0.756151
# Balanced Accuracy  0.559212
# Precision          0.247852
# Recall             0.272182
# F1-Score           0.259448
# AUC_ROC            0.559212

# %%
PlotHM(y_train, y_pred_dtc_opt_train_re, y_test, y_pred_dtc_opt_test_re,
       Title='Decision Tree Classifier - MinMax Scaler\n Modelo "Recall"', normalize=None)

# %% [markdown]
# **Recall_Weighted**

# %%
dtc_opt = DecisionTreeClassifier(**dtc_cv_params_rw, random_state=random_state)
dtc_opt.fit(X_train_MM, y_train);
y_pred_dtc_opt_train_rw = dtc_opt.predict(X_train_MM)
y_pred_dtc_opt_test_rw  = dtc_opt.predict(X_test_MM)
Memory()
# Out:
# Memoria actual utilizada: 8.65 GB

# %% [markdown]
# Resultados

# %%
Entrenamiento = get_metrics(y_train, y_pred_dtc_opt_train_rw).T
Evaluacion    = get_metrics(y_test, y_pred_dtc_opt_test_rw).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.845634
# Balanced Accuracy  0.510218
# Precision          0.709377
# Recall             0.022116
# F1-Score           0.042896
# AUC_ROC            0.510218
#
# Evaluacion
#                       Valor
# Accuracy           0.844138
# Balanced Accuracy  0.508600
# Precision          0.606154
# Recall             0.019567
# F1-Score           0.037910
# AUC_ROC            0.508600

# %%
PlotHM(y_train, y_pred_dtc_opt_train_rw, y_test, y_pred_dtc_opt_test_rw,
       Title='Decision Tree Classifier - MinMax Scaler\n Modelo "Recall_Weighted"', normalize=None)

# %%
del dtc_opt
Memory()
# Out:
# Memoria actual utilizada: 8.65 GB

# %% [markdown]
# #### Random Forest

# %%
#Parámetros
rf_params = {'criterion': 'entropy', 'n_estimators': 200, 'max_features': 'auto', 'max_depth': 50}

# %%
#Modelo
rf_opt = RandomForestClassifier(**rf_params, random_state=random_state, n_jobs=-1)

# %%
#Entrenamiento
rf_opt.fit(X_train_MM, y_train);
y_pred_rf_opt_train = rf_opt.predict(X_train_MM)
y_pred_rf_opt_test  = rf_opt.predict(X_test_MM)
Memory()
# Out:
# Memoria actual utilizada: 9.98 GB

# %% [markdown]
# Resultados

# %%
Entrenamiento = get_metrics(y_train, y_pred_rf_opt_train).T
Evaluacion    = get_metrics(y_test, y_pred_rf_opt_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.999189
# Balanced Accuracy  0.997608
# Precision          0.999508
# Recall             0.995308
# F1-Score           0.997403
# AUC_ROC            0.997608
#
# Evaluacion
#                       Valor
# Accuracy           0.842829
# Balanced Accuracy  0.519060
# Precision          0.492228
# Recall             0.047179
# F1-Score           0.086105
# AUC_ROC            0.519060

# %%
PlotHM(y_train, y_pred_rf_opt_train, y_test, y_pred_rf_opt_test,
       Title='Random Forest Classifier - MinMax Scaler\n Diff Params', normalize=None)

# %%
del rf_opt
Memory()
# Out:
# Memoria actual utilizada: 9.98 GB

# %% [markdown]
# #### XGBoost

# %%
#Parámetros
xgb_params = {'learning_rate': 0.1, 'max_depth': 5, 'alpha': 10, 'n_estimators': 10}

# %%
#Modelo
xgb_opt = XGBClassifier(**xgb_params, random_state=random_state, n_jobs=-1)

# %%
#Entrenamiento
xgb_opt.fit(np.asarray(X_train_MM), y_train);
y_pred_xgb_opt_train = xgb_opt.predict(np.asarray(X_train_MM))
y_pred_xgb_opt_test  = xgb_opt.predict(np.asarray(X_test_MM))
Memory()
# Out:
# Memoria actual utilizada: 9.98 GB

# %% [markdown]
# Resultados

# %%
Entrenamiento = get_metrics(y_train, y_pred_xgb_opt_train).T
Evaluacion    = get_metrics(y_test, y_pred_xgb_opt_test).T
display_side_by_side("Entrenamiento", "Evaluacion")
# Out:
# Entrenamiento
#                       Valor
# Accuracy           0.843841
# Balanced Accuracy  0.500793
# Precision          1.000000
# Recall             0.001586
# F1-Score           0.003168
# AUC_ROC            0.500793
#
# Evaluacion
#                       Valor
# Accuracy           0.843219
# Balanced Accuracy  0.500497
# Precision          1.000000
# Recall             0.000993
# F1-Score           0.001985
# AUC_ROC            0.500497

# %%
PlotHM(y_train, y_pred_xgb_opt_train, y_test, y_pred_xgb_opt_test,
       Title='XGBoost - MinMax Scaler\n Diff Params', normalize=None)

# %%
del xgb_opt
Memory()
# Out:
# Memoria actual utilizada: 9.98 GB

# %% [markdown]
# #### Resumen de modelos con hiperparámetros (MinMax Scaler)

# %%
models = ['DTC "Recall"', 'DTC "Recall_Weighted"', 'Random Forest', 'XGBoost']

# %%
predictions_train = [y_pred_dtc_opt_train_re, y_pred_dtc_opt_train_rw, y_pred_rf_opt_train, y_pred_xgb_opt_train]
print('Conjunto de Entrenamiento:')
get_metrics_comparison(y_train, predictions_train, models)
print('------------------------------------------------------------------------')
predictions_test = [y_pred_dtc_opt_test_re, y_pred_dtc_opt_test_rw, y_pred_rf_opt_test, y_pred_xgb_opt_test]
print('Conjunto de Evaluación:')
get_metrics_comparison(y_test, predictions_test, models)
# Out:
# Conjunto de Entrenamiento:
# <style  type="text/css" >
#     #T_b0c1ec58_ec9c_11ea_a3dc_0242ac1c0002row0_col0 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_b0c1ec58_ec9c_11ea_a3dc_0242ac1c0002row0_col1 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_b0c1ec58_ec9c_11ea_a3dc_0242ac1c0002row0_col2 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_b0c1ec58_ec9c_11ea_a3dc_0242ac1c0002row0_col3 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_b0c1ec58_ec9c_11ea_a3dc_0242ac1c0002row0_col4 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_b0c1ec58_ec9c_11ea_a3dc_0242ac1c0002row0_col5 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_b0c1ec58_ec9c_11ea_a3dc_0242ac1c0002row1_col0 {
#             background-color:  #f6fcf4;
# ...

# %%
del predictions_train, predictions_test
Memory()
# Out:
# Memoria actual utilizada: 9.98 GB

# %% [markdown]
# # Conclusión

# %% [markdown]
# - El metodo de scaler no afecta en el resultado de los modelos
# - El mejor modelo encontrado fue el de Perceptron
# - Interpretamos que se puede seguir haciendo feature engineering para mejorar la performance del modelo.
# - Podemos intentar realizar oversamples para balancear las clases Ausentes-Atendidos.
# - Incorporar Feature de tiempo (Incluir , numero de semana, franja horaria de atendido, calculo de tiempo entre pedido de turno y el turno otrogado, o incluir las feature ya calculadas )
# - Descartar variables que no ayudan al calculo de la predicción.
# - Dato: Antes de correr los modelos, esperabmos mejores resultados y nos encontramos poco porcentaje de Recall
